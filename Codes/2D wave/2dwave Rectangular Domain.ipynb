# %% [markdown]
# # 新段落

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import pandas as pd
import math

# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# torch.set_default_dtype(torch.float32)
torch.set_default_dtype(torch.float64)
torch.manual_seed(13)



# Sampling parameters etc
n_axis = 41
#n_axis = 21
n_time = 61
#n_time = 81

axis = torch.linspace(0,4,n_axis, device=device)
time = torch.linspace(0,12,n_time, device=device)
Ps = torch.cartesian_prod(axis,axis,time)
# Number of points
lP = Ps.shape[0]


# Initial dataset
data_axis = torch.linspace(0,4, 81, device=device)
data_time = torch.linspace(0,12,121, device=device)
data_Ps = torch.cartesian_prod(data_axis,data_axis,time)


mask = data_Ps[:,2] == 0.
X = data_Ps[mask]
dtX = data_Ps[mask]

mask1 = (abs((data_Ps[:,0]) - 4.) < 1e-10)
dxX = data_Ps[mask1]

mask2 = (abs(data_Ps[:,1] - 4.) < 1e-10)
dyX = data_Ps[mask2]

Y = torch.exp(-((X[:,0]-3)**2+(X[:,1]-3)**2)*10)
#Y = torch.exp(-(X[:,0]-0.5)**2*2.5)+torch.exp(-(X[:,1]-1)**2*5)
#Y = torch.cos((X[:,0]-1)*5)+torch.cos((X[:,1]-1)*5)
Y = Y.view(-1,1)

#dtY = -2*5*(X[:,0])*torch.exp(-(X[:,0])**2*5)-2*5*(X[:,1])*torch.exp(-(X[:,1])**2*5)
#dtY = -10*((X[:,0]-0.5)**2+(X[:,1]-0.5)**2)*torch.exp(-((X[:,0]-0.5)**2+(X[:,1]-0.5)**2)*10)
#dtY = -5*(torch.sin((X[:,0]-1)*5)+torch.sin((X[:,1]-1)*5))
#dtY = dtY.view(-1,1)

dxY = torch.where( ((dxX[:,0]-1).abs() < 1e-1) & (dxX[:,1].abs() < 1), 0., 0. )
dxY = dxY.view(-1,1)

dyY = torch.where( ((dyX[:,0]-1).abs() < 1e-1) & (dyX[:,1].abs() < 1), 0., 0. )
dyY = dyY.view(-1,1)

#dtX = dtX.to(torch.complex128)
dxX = dxX.to(torch.complex128)
dyX = dyX.to(torch.complex128)
dxY = dxY.to(torch.complex128)
dyY = dyY.to(torch.complex128)
X = X.to(torch.complex128)
Y = Y.to(torch.complex128)
#Y = torch.cat((Y,dtY,dxY,dyY),0)
Y = torch.cat((Y,dxY,dyY),0)

#sn.heatmap(Y.view(101, 101))
# Out:
# Using cuda device

# %%
def getVarietyPoints(base):
    x,y = base.unbind(1)
    t = torch.sqrt(x.square() + y.square())

    return torch.stack([ torch.stack([x,y,t],1), torch.stack([x,y,-t],1),torch.stack([-x,y,t],1), torch.stack([-x,y,-t],1),torch.stack([x,-y,t],1), torch.stack([x,-y,-t],1) ])

def Phi(base, X):
    pts = getVarietyPoints(base)
    # return (pts.inner(X) * 1.j).exp().mean(0)
    return (pts.inner(X)).exp().mean(0)

def dtPhi(base, X):
    pts = getVarietyPoints(base)
    return ((pts.inner(X)).exp().mul(pts[:,:,2].unsqueeze(2).repeat(1, 1, pts.inner(X).shape[2])).mean(0))

def dxPhi(base, X):
    pts = getVarietyPoints(base)
    return ((pts.inner(X)).exp().mul(pts[:,:,0].unsqueeze(2).repeat(1, 1, pts.inner(X).shape[2])).mean(0))

def dyPhi(base, X):
    pts = getVarietyPoints(base)
    return ((pts.inner(X)).exp().mul(pts[:,:,1].unsqueeze(2).repeat(1, 1, pts.inner(X).shape[2])).mean(0))


def train(N):
    for epoch in range(N):
        PhiX = Phi(MC_base * 1.j, X)
        #dtPhiX = dtPhi(MC_base * 1.j, dtX)
        dxPhiX = dxPhi(MC_base * 1.j, dxX)
        dyPhiX = dyPhi(MC_base * 1.j, dyX)
        #PhiX = torch.cat((PhiX,dtPhiX,dxPhiX,dyPhiX),1)
        PhiX = torch.cat((PhiX,dxPhiX,dyPhiX),1)
        A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
        LA = torch.linalg.cholesky(A)
        alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to(torch.complex128), upper=False)

        nlml = 1/(2*eps.exp()) * (Y.norm().square() - alpha.norm().square())
        nlml += (PhiX.shape[1] - PhiX.shape[0])/2 * eps
        nlml += LA.diag().real.log().sum()
        nlml += 0.5*S_diag.sum()

        opt.zero_grad()
        nlml.backward()
        opt.step()

        with torch.no_grad():
            train_pred = PhiX.H @ torch.linalg.solve_triangular(LA.H, alpha, upper=True)
            err = (train_pred.real - Y).square().mean().sqrt()
            print(26*"~" + f'\nepoch {epoch}\n\
nlml {nlml}\n\
err {err}\n\
eps {eps.exp()}\n\
base std {MC_base.std(0)}\n\
min,max {train_pred.real.min().detach(),train_pred.real.max().detach()}')

# %%
n_MC = 1000
# MC_axis = torch.linspace(-1,1, n_MC, device=device) * 30
MC_base = (torch.randn((n_MC, 2), device=device)).requires_grad_()
# MC_base = torch.cartesian_prod(MC_axis,MC_axis).requires_grad_()
S_diag = torch.full((n_MC,), -np.log(n_MC), requires_grad=True, device=device)
# S_diag = torch.full((n_MC**2,), -np.log(n_MC**2), requires_grad=False, device=device)
eps = torch.tensor(np.log(1e-2), requires_grad=True, device=device)

# %%
opt = torch.optim.Adam([
    {'params': MC_base, 'lr': 1e-1},
    {'params': eps, 'lr': 1e-2}])
train(10000)
opt = torch.optim.Adam([
    {'params': MC_base, 'lr': 1e-1},
    {'params': eps, 'lr': 1e-2}])
train(10000)
opt = torch.optim.Adam([
    {'params': MC_base, 'lr': 1e-2},
    {'params': [S_diag, eps], 'lr': 1e-2}])
train(1000)
opt = torch.optim.Adam([
    {'params': MC_base, 'lr': 1e-3},
    {'params': [S_diag, eps], 'lr': 1e-3}])
train(300)


torch.save({
            'MC_base': MC_base.cpu(),
            'S_diag': S_diag.cpu(),
            'eps': eps.cpu(),
    }, "state.pt")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# base std tensor([6.1508, 6.1395], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9776, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 586
# nlml -91710.19434746457
# err (0.0015956952844077951-1.0203418542738396e-19j)
# eps 3.0844508705368255e-06
# base std tensor([6.1508, 6.1395], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9776, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 587
# nlml -91779.0265886917
# err (0.0015912339323184005-1.0136523509588244e-19j)
# eps 3.0840369061725354e-06
# base std tensor([6.1508, 6.1395], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 588
# nlml -91804.61875468411
# err (0.0015912720921976878-1.0146411691633385e-19j)
# eps 3.083433821366126e-06
# base std tensor([6.1508, 6.1395], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 589
# nlml -91821.46697531377
# err (0.0015885611691932003-1.0155677106477367e-19j)
# eps 3.0826476804858277e-06
# base std tensor([6.1508, 6.1396], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 590
# nlml -91820.88137649317
# err (0.0015888950032390697-1.0138275960655754e-19j)
# eps 3.08169648497342e-06
# base std tensor([6.1508, 6.1396], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 591
# nlml -91848.74645048485
# err (0.001588242073770732-1.0129605139556226e-19j)
# eps 3.0805708533448723e-06
# base std tensor([6.1508, 6.1396], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 592
# nlml -91884.64884016238
# err (0.0015844071628525538-1.0114897561435215e-19j)
# eps 3.0792512428586177e-06
# base std tensor([6.1508, 6.1397], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 593
# nlml -91890.74395270697
# err (0.0015852182868734501-1.0121005732995674e-19j)
# eps 3.0777590719121108e-06
# base std tensor([6.1508, 6.1397], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 594
# nlml -91883.29473097308
# err (0.0015847209508004563-1.0123966320934661e-19j)
# eps 3.0761271288944217e-06
# base std tensor([6.1508, 6.1397], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 595
# nlml -91915.63488856332
# err (0.0015838746265222313-1.0099455439389927e-19j)
# eps 3.0743391152532167e-06
# base std tensor([6.1508, 6.1398], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 596
# nlml -91925.11930224359
# err (0.0015828382086340927-1.01113544663745e-19j)
# eps 3.072411210328564e-06
# base std tensor([6.1508, 6.1398], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 597
# nlml -91913.31255218865
# err (0.0015841559098392541-1.0114022481525359e-19j)
# eps 3.0703782732709177e-06
# base std tensor([6.1508, 6.1398], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 598
# nlml -91918.32477784957
# err (0.0015842137833481107-1.0090517040662891e-19j)
# eps 3.068252138700659e-06
# base std tensor([6.1508, 6.1397], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 599
# nlml -91879.28278570768
# err (0.0015887753144282401-1.0150381581339298e-19j)
# eps 3.066097043357081e-06
# base std tensor([6.1508, 6.1397], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 600
# nlml -91784.298948559
# err (0.0015931453281281443-1.0175382187981835e-19j)
# eps 3.0640282022083903e-06
# base std tensor([6.1508, 6.1397], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 601
# nlml -91705.440640279
# err (0.001599824743032773-1.0216220194832609e-19j)
# eps 3.0621261562267557e-06
# base std tensor([6.1508, 6.1396], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 602
# nlml -91564.34394659658
# err (0.0016040695154464117-1.0235979718906383e-19j)
# eps 3.060542879255244e-06
# base std tensor([6.1508, 6.1396], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9775, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 603
# nlml -91498.930076894
# err (0.0016086343431488987-1.0285437225069754e-19j)
# eps 3.059324261364345e-06
# base std tensor([6.1508, 6.1395], device='cuda:0')
# min,max (tensor(-0.0074, device='cuda:0'), tensor(0.9775, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 604
# nlml -91494.31172248143
# err (0.0016075769714142176-1.0309232880926304e-19j)
# eps 3.0584391716201494e-06
# base std tensor([6.1508, 6.1395], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9775, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 605
# nlml -91485.5755888059
# err (0.0016092704790181779-1.0265261730564206e-19j)
# eps 3.057868033720768e-06
# base std tensor([6.1508, 6.1395], device='cuda:0')
# min,max (tensor(-0.0074, device='cuda:0'), tensor(0.9775, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 606
# nlml -91712.6733354596
# err (0.0015969734947569095-1.0219900902515695e-19j)
# eps 3.057325024760303e-06
# base std tensor([6.1508, 6.1395], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9776, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 607
# nlml -91835.96120801124
# err (0.0015893023686234734-1.0174028827584514e-19j)
# eps 3.056674779392053e-06
# base std tensor([6.1508, 6.1394], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 608
# nlml -91747.8246263407
# err (0.00159223944271128-1.01867515542844e-19j)
# eps 3.056007698855218e-06
# base std tensor([6.1508, 6.1394], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 609
# nlml -91749.34724490206
# err (0.001594271609170353-1.0187707993977421e-19j)
# eps 3.0553465446702666e-06
# base std tensor([6.1508, 6.1393], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 610
# nlml -91859.9142319921
# err (0.0015872563961743585-1.0117701338388309e-19j)
# eps 3.054566818894968e-06
# base std tensor([6.1508, 6.1393], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 611
# nlml -91902.19138023151
# err (0.0015839609871115064-1.0119755747683548e-19j)
# eps 3.0536330456071708e-06
# base std tensor([6.1508, 6.1393], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 612
# nlml -91845.61328419959
# err (0.001587860078090315-1.0151832588263886e-19j)
# eps 3.052623913195431e-06
# base std tensor([6.1508, 6.1392], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 613
# nlml -91850.89529254098
# err (0.0015881092227399655-1.0141094016839344e-19j)
# eps 3.05155251451667e-06
# base std tensor([6.1508, 6.1392], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 614
# nlml -91951.42260526046
# err (0.001581902484192584-1.0104163521768697e-19j)
# eps 3.050316537416507e-06
# base std tensor([6.1507, 6.1392], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 615
# nlml -91976.14753644848
# err (0.001579981097192828-1.0111020740242501e-19j)
# eps 3.0489128034993603e-06
# base std tensor([6.1507, 6.1392], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 616
# nlml -91926.24693612511
# err (0.001583792038010543-1.0102306893118649e-19j)
# eps 3.0474216915228563e-06
# base std tensor([6.1506, 6.1392], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 617
# nlml -91973.00543414478
# err (0.0015810452606730657-1.0090655116008956e-19j)
# eps 3.0458072598435032e-06
# base std tensor([6.1506, 6.1392], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 618
# nlml -92016.04540954424
# err (0.0015766835558119715-1.0083680290270931e-19j)
# eps 3.04404392362706e-06
# base std tensor([6.1505, 6.1392], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 619
# nlml -91994.19400046914
# err (0.0015799824557964825-1.0077532692580336e-19j)
# eps 3.0421778079125166e-06
# base std tensor([6.1505, 6.1392], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 620
# nlml -91990.94405648703
# err (0.001578991285327934-1.0092199922239901e-19j)
# eps 3.0402275705718705e-06
# base std tensor([6.1505, 6.1392], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 621
# nlml -92026.07063961345
# err (0.001577255871470076-1.0059843608197289e-19j)
# eps 3.0381727198463445e-06
# base std tensor([6.1505, 6.1392], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 622
# nlml -91991.35827985425
# err (0.0015793009931114419-1.0078471235613104e-19j)
# eps 3.036050803945795e-06
# base std tensor([6.1504, 6.1392], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 623
# nlml -91971.04280730181
# err (0.0015788897488026223-1.0085558226407492e-19j)
# eps 3.0339013182630992e-06
# base std tensor([6.1505, 6.1393], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 624
# nlml -91963.73647000248
# err (0.001579602833213968-1.0077850558633612e-19j)
# eps 3.0317444082143255e-06
# base std tensor([6.1504, 6.1393], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 625
# nlml -91988.17821139185
# err (0.0015792972702707716-1.0074693748195091e-19j)
# eps 3.0295625211439957e-06
# base std tensor([6.1505, 6.1393], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 626
# nlml -91958.87469808562
# err (0.00157909538328514-1.0087803325745039e-19j)
# eps 3.0273908554474464e-06
# base std tensor([6.1504, 6.1393], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 627
# nlml -91909.1765599433
# err (0.0015839246884462714-1.010984399647273e-19j)
# eps 3.0253012101614864e-06
# base std tensor([6.1504, 6.1393], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 628
# nlml -91852.83341281881
# err (0.0015846915802272903-1.0143469353865905e-19j)
# eps 3.0233567840019974e-06
# base std tensor([6.1504, 6.1393], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 629
# nlml -91769.78054757892
# err (0.0015918485927770706-1.0158470242041245e-19j)
# eps 3.021644536244037e-06
# base std tensor([6.1504, 6.1394], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 630
# nlml -91759.5363616251
# err (0.0015921648668416597-1.0208448191395797e-19j)
# eps 3.020167902270673e-06
# base std tensor([6.1504, 6.1394], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9776, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 631
# nlml -91851.74459737288
# err (0.0015890527867207338-1.014977520731435e-19j)
# eps 3.0188008390845533e-06
# base std tensor([6.1504, 6.1394], device='cuda:0')
# min,max (tensor(-0.0075, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 632
# nlml -91918.88776454558
# err (0.0015838298390059816-1.0134513582723895e-19j)
# eps 3.017464201658385e-06
# base std tensor([6.1504, 6.1395], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 633
# nlml -91954.24453059229
# err (0.0015828838958445563-1.0108523803800666e-19j)
# eps 3.0161254349258336e-06
# base std tensor([6.1504, 6.1395], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 634
# nlml -91967.35259084555
# err (0.0015803953314552966-1.0091290134354913e-19j)
# eps 3.014775161585329e-06
# base std tensor([6.1503, 6.1395], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 635
# nlml -91988.1726932459
# err (0.0015798122115689823-1.0094791067606301e-19j)
# eps 3.0134020046168275e-06
# base std tensor([6.1502, 6.1395], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 636
# nlml -91979.25004197535
# err (0.0015807947933815605-1.0086997602355921e-19j)
# eps 3.0120242375205245e-06
# base std tensor([6.1502, 6.1395], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 637
# nlml -91896.72016013609
# err (0.001586888367683131-1.013352045700445e-19j)
# eps 3.0107444771071972e-06
# base std tensor([6.1501, 6.1395], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 638
# nlml -91821.39637394447
# err (0.0015919143178735576-1.0154653918794556e-19j)
# eps 3.0096463496176215e-06
# base std tensor([6.1501, 6.1396], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 639
# nlml -91796.89923969087
# err (0.0015947949425353081-1.019956037994121e-19j)
# eps 3.008740749400962e-06
# base std tensor([6.1501, 6.1396], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 640
# nlml -91801.46085678216
# err (0.0015916938444201032-1.0142301298144571e-19j)
# eps 3.008007623182805e-06
# base std tensor([6.1500, 6.1396], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 641
# nlml -91847.6561173018
# err (0.0015899716015227098-1.017493539268328e-19j)
# eps 3.007391854531973e-06
# base std tensor([6.1500, 6.1396], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 642
# nlml -91887.72948802695
# err (0.0015839844759817424-1.0096936089758213e-19j)
# eps 3.006836847790598e-06
# base std tensor([6.1500, 6.1396], device='cuda:0')
# min,max (tensor(-0.0075, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 643
# nlml -91926.57159429381
# err (0.001585216511833949-1.0138056281003164e-19j)
# eps 3.0062948413388146e-06
# base std tensor([6.1500, 6.1396], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 644
# nlml -91982.66135096301
# err (0.0015826196960502309-1.0086791953094922e-19j)
# eps 3.005705045419665e-06
# base std tensor([6.1500, 6.1397], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 645
# nlml -92032.51719772426
# err (0.001577984096652339-1.0082413636356699e-19j)
# eps 3.0050048062788495e-06
# base std tensor([6.1500, 6.1397], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 646
# nlml -91999.38819382185
# err (0.0015837584342752974-1.0129023944289098e-19j)
# eps 3.004257270050367e-06
# base std tensor([6.1501, 6.1398], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 647
# nlml -91981.8528019777
# err (0.0015805101607597293-1.0081955507760522e-19j)
# eps 3.0034856359686718e-06
# base std tensor([6.1501, 6.1398], device='cuda:0')
# min,max (tensor(-0.0075, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 648
# nlml -91977.1982781435
# err (0.001580506250601932-1.010097044696186e-19j)
# eps 3.00269578934602e-06
# base std tensor([6.1502, 6.1399], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 649
# nlml -91982.08499644604
# err (0.001580675297495739-1.0110442455937383e-19j)
# eps 3.001886893256544e-06
# base std tensor([6.1502, 6.1399], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 650
# nlml -92039.24494241567
# err (0.0015777870789007345-1.0070000227056621e-19j)
# eps 3.0010000446255714e-06
# base std tensor([6.1502, 6.1399], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 651
# nlml -92070.39729723983
# err (0.0015758196901480782-1.0071620411855664e-19j)
# eps 3.0000094862039253e-06
# base std tensor([6.1502, 6.1400], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 652
# nlml -92061.56802041261
# err (0.0015749585923967439-1.0053010607028726e-19j)
# eps 2.9989418052502916e-06
# base std tensor([6.1502, 6.1400], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 653
# nlml -92042.33934501775
# err (0.0015776064969974476-1.0069920574607664e-19j)
# eps 2.9978295984784245e-06
# base std tensor([6.1502, 6.1401], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 654
# nlml -92062.01835386005
# err (0.0015757054707566374-1.0058184010376384e-19j)
# eps 2.9966630714894364e-06
# base std tensor([6.1502, 6.1401], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 655
# nlml -92125.12430430292
# err (0.0015720941790324208-1.0057357951842097e-19j)
# eps 2.9953798768696784e-06
# base std tensor([6.1502, 6.1402], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 656
# nlml -92133.06812885741
# err (0.0015714141984666992-1.0033191654751069e-19j)
# eps 2.9939866227978453e-06
# base std tensor([6.1503, 6.1402], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 657
# nlml -92128.99374162838
# err (0.001572326207456736-1.0051763917805332e-19j)
# eps 2.9925076213021233e-06
# base std tensor([6.1503, 6.1402], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 658
# nlml -92129.31213395651
# err (0.00157169279436541-1.0026020099732258e-19j)
# eps 2.990956277294947e-06
# base std tensor([6.1503, 6.1403], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 659
# nlml -92133.89540629394
# err (0.0015721130177348828-1.004180194802283e-19j)
# eps 2.9893419127134714e-06
# base std tensor([6.1504, 6.1403], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 660
# nlml -92124.51268216869
# err (0.0015707749172911825-1.0023197983687058e-19j)
# eps 2.9876851381188064e-06
# base std tensor([6.1504, 6.1403], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 661
# nlml -92076.16078517544
# err (0.0015734352005976103-1.0034436293455645e-19j)
# eps 2.9860425872589755e-06
# base std tensor([6.1504, 6.1404], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 662
# nlml -91976.52772843737
# err (0.001575597588132175-1.0061515187615554e-19j)
# eps 2.984518258689603e-06
# base std tensor([6.1504, 6.1404], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 663
# nlml -91913.30849416691
# err (0.0015817768628548885-1.0093956836645884e-19j)
# eps 2.9831772579355022e-06
# base std tensor([6.1505, 6.1404], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 664
# nlml -91868.53538211659
# err (0.0015862974937718853-1.01418244371452e-19j)
# eps 2.982061099298502e-06
# base std tensor([6.1505, 6.1404], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 665
# nlml -91725.58010983438
# err (0.001596955509006192-1.0204959968392784e-19j)
# eps 2.9813186815698127e-06
# base std tensor([6.1504, 6.1404], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 666
# nlml -91625.02580705898
# err (0.0016025920041820166-1.0260804636978518e-19j)
# eps 2.9810391057932906e-06
# base std tensor([6.1504, 6.1404], device='cuda:0')
# min,max (tensor(-0.0075, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 667
# nlml -91746.52291486788
# err (0.0015946083689439923-1.0178045141930021e-19j)
# eps 2.981037512616163e-06
# base std tensor([6.1504, 6.1404], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 668
# nlml -91988.67710390757
# err (0.0015803666661817818-1.0096075695129091e-19j)
# eps 2.981007442989615e-06
# base std tensor([6.1504, 6.1404], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 669
# nlml -92055.80690298269
# err (0.0015732285143907506-1.0070208537779218e-19j)
# eps 2.980876738404284e-06
# base std tensor([6.1504, 6.1403], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 670
# nlml -91936.63613882988
# err (0.0015823227647474276-1.0100266388461581e-19j)
# eps 2.980797889706244e-06
# base std tensor([6.1503, 6.1403], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 671
# nlml -91878.04811868856
# err (0.001586549205103321-1.0148187650907271e-19j)
# eps 2.9808451757238176e-06
# base std tensor([6.1503, 6.1403], device='cuda:0')
# min,max (tensor(-0.0075, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 672
# nlml -91954.51396327004
# err (0.0015815380423520264-1.0121193692386285e-19j)
# eps 2.9809142227567645e-06
# base std tensor([6.1503, 6.1403], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 673
# nlml -91967.18983392014
# err (0.0015822027890530707-1.0117435795419006e-19j)
# eps 2.9809954294523543e-06
# base std tensor([6.1502, 6.1403], device='cuda:0')
# min,max (tensor(-0.0075, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 674
# nlml -91962.35604258454
# err (0.0015802214196436824-1.0095373176862359e-19j)
# eps 2.981098924100479e-06
# base std tensor([6.1502, 6.1403], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 675
# nlml -92009.57580234631
# err (0.0015811112791250222-1.010930661375282e-19j)
# eps 2.9811677904949584e-06
# base std tensor([6.1502, 6.1403], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 676
# nlml -92063.04547167143
# err (0.0015753386616704237-1.0083023646897112e-19j)
# eps 2.9811418367629423e-06
# base std tensor([6.1502, 6.1403], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 677
# nlml -92105.69961668104
# err (0.001573208013769497-1.0040356028299129e-19j)
# eps 2.9809845597692613e-06
# base std tensor([6.1502, 6.1404], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 678
# nlml -92167.06400793674
# err (0.0015696261884266156-1.0030601148982505e-19j)
# eps 2.980638116373008e-06
# base std tensor([6.1502, 6.1405], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 679
# nlml -92179.44635736142
# err (0.0015680451994573713-1.0031875155857043e-19j)
# eps 2.980106176441688e-06
# base std tensor([6.1503, 6.1405], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 680
# nlml -92159.77237309967
# err (0.0015708750825994037-1.0019571573812962e-19j)
# eps 2.9794392958556974e-06
# base std tensor([6.1503, 6.1405], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 681
# nlml -92160.86048751995
# err (0.0015704783951684274-1.0044109573536106e-19j)
# eps 2.978655264022443e-06
# base std tensor([6.1503, 6.1406], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 682
# nlml -92153.99205708898
# err (0.0015701564161595622-1.0038571668634517e-19j)
# eps 2.977775322207452e-06
# base std tensor([6.1503, 6.1406], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 683
# nlml -92139.5696844546
# err (0.0015706948820123983-1.0034012565452632e-19j)
# eps 2.976825250542175e-06
# base std tensor([6.1503, 6.1407], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 684
# nlml -92133.37744856521
# err (0.0015711532994634064-1.0040586664473803e-19j)
# eps 2.9758257693772504e-06
# base std tensor([6.1504, 6.1407], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 685
# nlml -92114.49074890286
# err (0.0015702123757182428-1.0034816048671223e-19j)
# eps 2.974804123367838e-06
# base std tensor([6.1504, 6.1407], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 686
# nlml -92111.5453275397
# err (0.001571979744332038-1.0034932043252047e-19j)
# eps 2.973775620680861e-06
# base std tensor([6.1504, 6.1407], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 687
# nlml -92011.48766625769
# err (0.0015745608476886355-1.0066325078482132e-19j)
# eps 2.972862398359477e-06
# base std tensor([6.1504, 6.1407], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 688
# nlml -91780.79966210866
# err (0.0015923160976366354-1.018071215332377e-19j)
# eps 2.9723361703543647e-06
# base std tensor([6.1504, 6.1407], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 689
# nlml -91499.01015423733
# err (0.0016016715156843202-1.0221741310851005e-19j)
# eps 2.972499510465112e-06
# base std tensor([6.1504, 6.1407], device='cuda:0')
# min,max (tensor(-0.0072, device='cuda:0'), tensor(0.9775, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 690
# nlml -91383.70172471143
# err (0.0016158748447329728-1.0358922147073816e-19j)
# eps 2.97341335264108e-06
# base std tensor([6.1504, 6.1408], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9775, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 691
# nlml -92021.83814872551
# err (0.0015777497111425438-1.0105848782035353e-19j)
# eps 2.974252827291713e-06
# base std tensor([6.1504, 6.1408], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 692
# nlml -91939.53298242841
# err (0.0015830941156597582-1.0117843015683254e-19j)
# eps 2.975126945045999e-06
# base std tensor([6.1504, 6.1408], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 693
# nlml -91827.61992464439
# err (0.0015929914099723733-1.0207530403445742e-19j)
# eps 2.976162893204524e-06
# base std tensor([6.1504, 6.1409], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 694
# nlml -91982.64253217002
# err (0.0015809534670462853-1.0103627690058279e-19j)
# eps 2.977163231361963e-06
# base std tensor([6.1505, 6.1409], device='cuda:0')
# min,max (tensor(-0.0075, device='cuda:0'), tensor(0.9777, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 695
# nlml -92041.4798552228
# err (0.0015803581269603637-1.0081413192495846e-19j)
# eps 2.9780637897495447e-06
# base std tensor([6.1505, 6.1410], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 696
# nlml -92037.35203727757
# err (0.001580496930081066-1.0098053291589306e-19j)
# eps 2.9788742051619886e-06
# base std tensor([6.1504, 6.1410], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 697
# nlml -92060.60306973285
# err (0.0015765518315155524-1.006994117023464e-19j)
# eps 2.979575838643893e-06
# base std tensor([6.1504, 6.1411], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 698
# nlml -92113.29840001841
# err (0.001576998672478573-1.0051608886320669e-19j)
# eps 2.980105856284052e-06
# base std tensor([6.1504, 6.1411], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 699
# nlml -92107.99158900381
# err (0.00157545020630093-1.0062707850804865e-19j)
# eps 2.9804827678477474e-06
# base std tensor([6.1504, 6.1410], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 700
# nlml -92120.58076833464
# err (0.0015726159118109701-1.00495420350876e-19j)
# eps 2.98070755165697e-06
# base std tensor([6.1504, 6.1410], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 701
# nlml -92134.46610126528
# err (0.0015745469073328063-1.004001927550557e-19j)
# eps 2.9807734830802834e-06
# base std tensor([6.1504, 6.1410], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 702
# nlml -92109.38928810185
# err (0.0015763256825142588-1.0082309519057746e-19j)
# eps 2.9807298140821254e-06
# base std tensor([6.1504, 6.1410], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 703
# nlml -92095.9727631358
# err (0.0015772020322841972-1.0087349760696691e-19j)
# eps 2.9806019415184185e-06
# base std tensor([6.1504, 6.1410], device='cuda:0')
# min,max (tensor(-0.0075, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 704
# nlml -92078.53578627772
# err (0.0015785696064342834-1.0095009170314157e-19j)
# eps 2.980427766401633e-06
# base std tensor([6.1505, 6.1411], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 705
# nlml -92010.42808565656
# err (0.00158249409127559-1.0098013553252967e-19j)
# eps 2.980289886356795e-06
# base std tensor([6.1505, 6.1411], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 706
# nlml -91960.46522052475
# err (0.0015842520062224529-1.0111155917859269e-19j)
# eps 2.9802538146063947e-06
# base std tensor([6.1505, 6.1412], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 707
# nlml -91970.77481644865
# err (0.0015826633683225669-1.0104417577194007e-19j)
# eps 2.9802792394594318e-06
# base std tensor([6.1506, 6.1412], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9778, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 708
# nlml -91958.49013985053
# err (0.00158235404817009-1.0124740267376396e-19j)
# eps 2.9803759430511675e-06
# base std tensor([6.1506, 6.1412], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 709
# nlml -92093.33297296104
# err (0.0015742319696812749-1.005714195420496e-19j)
# eps 2.98035563129037e-06
# base std tensor([6.1506, 6.1412], device='cuda:0')
# min,max (tensor(-0.0075, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 710
# nlml -92180.29235604656
# err (0.0015673404929546061-1.0002450246076184e-19j)
# eps 2.9801332050805987e-06
# base std tensor([6.1506, 6.1411], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 711
# nlml -92182.48421144533
# err (0.001569286200917531-1.0038951837533252e-19j)
# eps 2.9797210350996e-06
# base std tensor([6.1507, 6.1412], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 712
# nlml -92175.83492787741
# err (0.0015693281178936888-1.0050322287846183e-19j)
# eps 2.9791509731067657e-06
# base std tensor([6.1507, 6.1412], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 713
# nlml -92139.42898226535
# err (0.001572122591599302-1.003348199646255e-19j)
# eps 2.9784890926811138e-06
# base std tensor([6.1508, 6.1412], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 714
# nlml -92186.85186140916
# err (0.001570997111293648-1.0033524229635545e-19j)
# eps 2.9776862516986045e-06
# base std tensor([6.1508, 6.1412], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 715
# nlml -92239.90441409514
# err (0.001564591198430433-1.0016246136702808e-19j)
# eps 2.976697243389754e-06
# base std tensor([6.1508, 6.1412], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 716
# nlml -92255.80961497402
# err (0.0015650441832081542-9.980080337480207e-20j)
# eps 2.975527242567093e-06
# base std tensor([6.1508, 6.1412], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 717
# nlml -92241.9630862734
# err (0.001565355422264684-9.9947435306809e-20j)
# eps 2.974215602532447e-06
# base std tensor([6.1508, 6.1412], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 718
# nlml -92211.18855136314
# err (0.0015667957630672714-1.000784114276733e-19j)
# eps 2.9728176190834266e-06
# base std tensor([6.1508, 6.1413], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 719
# nlml -92218.45906277931
# err (0.001566858534480606-1.0006292501769484e-19j)
# eps 2.9713399165865913e-06
# base std tensor([6.1507, 6.1413], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 720
# nlml -92184.89231652577
# err (0.0015677684707770482-1.0022683177617373e-19j)
# eps 2.969834310961826e-06
# base std tensor([6.1507, 6.1413], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 721
# nlml -92197.06009753866
# err (0.001566440883988908-9.971539077322308e-20j)
# eps 2.9682899719182483e-06
# base std tensor([6.1507, 6.1414], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 722
# nlml -92187.4694597934
# err (0.001564408911716603-9.995869297147714e-20j)
# eps 2.966713234858763e-06
# base std tensor([6.1507, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 723
# nlml -92154.2721599387
# err (0.0015688736343672115-1.0011300266765252e-19j)
# eps 2.965167906023328e-06
# base std tensor([6.1508, 6.1415], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 724
# nlml -92150.1164910061
# err (0.0015686204550747053-1.0026594844985858e-19j)
# eps 2.9636502281075295e-06
# base std tensor([6.1508, 6.1416], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 725
# nlml -92105.46728893596
# err (0.0015698143862730323-1.0013956695302363e-19j)
# eps 2.9622190683422355e-06
# base std tensor([6.1508, 6.1416], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 726
# nlml -92025.13178402004
# err (0.0015723744203334827-1.004872044390321e-19j)
# eps 2.9609717189774593e-06
# base std tensor([6.1508, 6.1417], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 727
# nlml -91941.02279825068
# err (0.0015797171235041947-1.0071712431820277e-19j)
# eps 2.9600044167800665e-06
# base std tensor([6.1508, 6.1417], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 728
# nlml -91800.35168757656
# err (0.001583863451379927-1.0110433331168114e-19j)
# eps 2.95946627877907e-06
# base std tensor([6.1508, 6.1418], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 729
# nlml -91776.63188236649
# err (0.001589887767890015-1.0147496888412387e-19j)
# eps 2.9593593707033514e-06
# base std tensor([6.1507, 6.1418], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 730
# nlml -91886.38083388926
# err (0.0015808377653664409-1.0110857606014164e-19j)
# eps 2.959499736204115e-06
# base std tensor([6.1507, 6.1418], device='cuda:0')
# min,max (tensor(-0.0076, device='cuda:0'), tensor(0.9779, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 731
# nlml -91966.77243791762
# err (0.0015809322283859483-1.010121314771951e-19j)
# eps 2.9597706102837377e-06
# base std tensor([6.1508, 6.1419], device='cuda:0')
# min,max (tensor(-0.0082, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 732
# nlml -91923.50744470349
# err (0.0015860259628844272-1.0113974281503515e-19j)
# eps 2.9602151636682693e-06
# base std tensor([6.1508, 6.1419], device='cuda:0')
# min,max (tensor(-0.0075, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 733
# nlml -91933.65495107564
# err (0.0015821767227895698-1.0132908707164551e-19j)
# eps 2.960808058612099e-06
# base std tensor([6.1508, 6.1420], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 734
# nlml -92108.68288557214
# err (0.0015749495052245117-1.004591203576064e-19j)
# eps 2.9613215049962175e-06
# base std tensor([6.1508, 6.1420], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 735
# nlml -92202.74573210374
# err (0.0015675525840431674-1.0002207656977381e-19j)
# eps 2.961647656834733e-06
# base std tensor([6.1507, 6.1420], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 736
# nlml -92138.66728787997
# err (0.0015728851321760399-1.0072640137441952e-19j)
# eps 2.9618729414063327e-06
# base std tensor([6.1507, 6.1420], device='cuda:0')
# min,max (tensor(-0.0082, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 737
# nlml -92164.13472147007
# err (0.0015698660802060972-9.992689389700326e-20j)
# eps 2.961983748075096e-06
# base std tensor([6.1507, 6.1420], device='cuda:0')
# min,max (tensor(-0.0077, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 738
# nlml -92223.11502153586
# err (0.0015660507611338725-1.0034697439144884e-19j)
# eps 2.961921140787205e-06
# base std tensor([6.1507, 6.1419], device='cuda:0')
# min,max (tensor(-0.0082, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 739
# nlml -92227.02209741682
# err (0.0015683115256583079-1.0035104501897259e-19j)
# eps 2.9616979174292847e-06
# base std tensor([6.1507, 6.1419], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 740
# nlml -92220.50891536933
# err (0.0015669952114871926-9.978035280782856e-20j)
# eps 2.961341086735708e-06
# base std tensor([6.1507, 6.1419], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 741
# nlml -92217.7409840577
# err (0.0015673016025931346-1.0030283244808062e-19j)
# eps 2.9608688705722955e-06
# base std tensor([6.1507, 6.1420], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 742
# nlml -92242.51595737043
# err (0.0015656464692891876-1.0009630231353022e-19j)
# eps 2.9602659125580463e-06
# base std tensor([6.1508, 6.1420], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 743
# nlml -92206.5723314795
# err (0.0015677739549412805-9.979370136924126e-20j)
# eps 2.959586046683669e-06
# base std tensor([6.1508, 6.1420], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 744
# nlml -92218.89791108666
# err (0.0015664256571871129-1.0039481000176398e-19j)
# eps 2.9588239445899864e-06
# base std tensor([6.1509, 6.1420], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 745
# nlml -92287.85270382125
# err (0.0015627784195051946-9.973427137842777e-20j)
# eps 2.957912986251567e-06
# base std tensor([6.1509, 6.1420], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 746
# nlml -92307.60404230525
# err (0.0015617454073881233-9.970225588554855e-20j)
# eps 2.95685074443779e-06
# base std tensor([6.1509, 6.1420], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 747
# nlml -92308.82382663543
# err (0.0015616158491354054-9.999109599710795e-20j)
# eps 2.955659539631012e-06
# base std tensor([6.1509, 6.1420], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 748
# nlml -92344.49933735329
# err (0.0015596973948835708-9.942420250895476e-20j)
# eps 2.9543091752639526e-06
# base std tensor([6.1509, 6.1420], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 749
# nlml -92374.01130187977
# err (0.0015582852548980542-9.955385310852002e-20j)
# eps 2.9527913674563462e-06
# base std tensor([6.1509, 6.1420], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 750
# nlml -92365.77260955216
# err (0.0015584598496129847-9.970766878151065e-20j)
# eps 2.951143672451657e-06
# base std tensor([6.1509, 6.1420], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 751
# nlml -92381.68340102365
# err (0.0015580034230217382-9.93247503161566e-20j)
# eps 2.94936418003376e-06
# base std tensor([6.1509, 6.1421], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 752
# nlml -92398.44511271875
# err (0.0015574064547407567-9.927529314660628e-20j)
# eps 2.947454647763382e-06
# base std tensor([6.1509, 6.1421], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 753
# nlml -92386.86120997029
# err (0.0015572018752979147-9.958357145854261e-20j)
# eps 2.945454465292088e-06
# base std tensor([6.1508, 6.1421], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 754
# nlml -92367.73463070957
# err (0.0015596562298103355-9.948648849335355e-20j)
# eps 2.9434022327270784e-06
# base std tensor([6.1508, 6.1421], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 755
# nlml -92327.19556688504
# err (0.0015615415504258339-9.959671692552042e-20j)
# eps 2.941361729332422e-06
# base std tensor([6.1508, 6.1421], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 756
# nlml -92302.56357832292
# err (0.0015647311044723112-9.996011638169455e-20j)
# eps 2.9393686765471672e-06
# base std tensor([6.1508, 6.1421], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 757
# nlml -92252.77143191668
# err (0.0015656812919052953-9.990053051773517e-20j)
# eps 2.9374770108578712e-06
# base std tensor([6.1508, 6.1421], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 758
# nlml -92207.93165631215
# err (0.001570947406077947-1.0021454359651836e-19j)
# eps 2.9357425915931807e-06
# base std tensor([6.1508, 6.1421], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 759
# nlml -92159.72998267235
# err (0.0015700904053018408-1.0056995601861294e-19j)
# eps 2.934223546098147e-06
# base std tensor([6.1508, 6.1421], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9780, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 760
# nlml -92199.28387824807
# err (0.0015698991582471895-9.995886427916894e-20j)
# eps 2.9328449260272836e-06
# base std tensor([6.1508, 6.1422], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 761
# nlml -92248.55981601457
# err (0.0015643081969730684-1.0030307098636696e-19j)
# eps 2.9315435642711554e-06
# base std tensor([6.1509, 6.1421], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 762
# nlml -92294.59361582655
# err (0.0015617146530004422-9.963111439589709e-20j)
# eps 2.9302459235646217e-06
# base std tensor([6.1509, 6.1421], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 763
# nlml -92323.02063945521
# err (0.0015591282057091187-9.962327137673284e-20j)
# eps 2.928929374136226e-06
# base std tensor([6.1509, 6.1422], device='cuda:0')
# min,max (tensor(-0.0078, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 764
# nlml -92295.89219181398
# err (0.001562514746731524-1.0002115093744873e-19j)
# eps 2.927633478770383e-06
# base std tensor([6.1509, 6.1422], device='cuda:0')
# min,max (tensor(-0.0079, device='cuda:0'), tensor(0.9782, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 765
# nlml -92247.78487234228
# err (0.0015659896940781333-9.988883831230177e-20j)
# eps 2.926420431954604e-06
# base std tensor([6.1508, 6.1421], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9781, device='cuda:0'))
# ...
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 240
# nlml -93267.89759410647
# err (0.0015175802070071245-9.679122724876416e-20j)
# eps 2.6785163795858343e-06
# base std tensor([6.1514, 6.1416], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 241
# nlml -93268.9483249598
# err (0.0015173738205629334-9.677246751240417e-20j)
# eps 2.678155246155903e-06
# base std tensor([6.1514, 6.1416], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 242
# nlml -93268.17234250944
# err (0.0015174963078908186-9.676650628109896e-20j)
# eps 2.6778046751571993e-06
# base std tensor([6.1514, 6.1416], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 243
# nlml -93264.20376180769
# err (0.001517645097665375-9.676802377687392e-20j)
# eps 2.6774819497174414e-06
# base std tensor([6.1514, 6.1416], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 244
# nlml -93258.37592996316
# err (0.0015178369284362767-9.677443896875861e-20j)
# eps 2.6772088146792653e-06
# base std tensor([6.1514, 6.1416], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 245
# nlml -93253.32311666943
# err (0.0015181173120998954-9.682434332396892e-20j)
# eps 2.6770038524821802e-06
# base std tensor([6.1514, 6.1416], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 246
# nlml -93253.98816365488
# err (0.0015180274889846678-9.678398354595806e-20j)
# eps 2.6768576731749875e-06
# base std tensor([6.1514, 6.1416], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 247
# nlml -93260.39209167197
# err (0.0015175069156005234-9.679228137367218e-20j)
# eps 2.6767458311832713e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 248
# nlml -93269.49345107749
# err (0.0015173073596762509-9.674372722390345e-20j)
# eps 2.676627660556367e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 249
# nlml -93270.61489339081
# err (0.0015171626234200739-9.676989410755535e-20j)
# eps 2.676502918578715e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 250
# nlml -93268.28713991132
# err (0.001517288174068645-9.675285646332501e-20j)
# eps 2.6763831591226765e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 251
# nlml -93272.80119960678
# err (0.0015170127419287798-9.674811976519963e-20j)
# eps 2.676250010990576e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 252
# nlml -93277.70539477217
# err (0.0015167221893110131-9.67279659442156e-20j)
# eps 2.6760907045209408e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 253
# nlml -93275.71324804617
# err (0.0015168660716817098-9.672030307623275e-20j)
# eps 2.675917074059344e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 254
# nlml -93275.53635259731
# err (0.0015167806031195872-9.675027748081023e-20j)
# eps 2.6757330485537847e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 255
# nlml -93280.30318172096
# err (0.0015165210639378496-9.671195884971607e-20j)
# eps 2.6755252557756982e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 256
# nlml -93281.94572765371
# err (0.0015164943483648944-9.670946814587263e-20j)
# eps 2.675292568760174e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 257
# nlml -93281.00550098644
# err (0.001516545385382202-9.671689657358709e-20j)
# eps 2.6750447893832197e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 258
# nlml -93282.92660897279
# err (0.0015163068894772141-9.66722360440162e-20j)
# eps 2.6747784124723905e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 259
# nlml -93286.32858423023
# err (0.0015162463044168838-9.668856004212967e-20j)
# eps 2.674489379836491e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 260
# nlml -93287.38848754369
# err (0.001516151369991765-9.6689114581304e-20j)
# eps 2.6741799218964527e-06
# base std tensor([6.1514, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 261
# nlml -93286.82930460558
# err (0.0015160255017777943-9.665608196459517e-20j)
# eps 2.673855481903191e-06
# base std tensor([6.1513, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 262
# nlml -93287.34747688958
# err (0.001516161652340414-9.668564920389995e-20j)
# eps 2.673521290256807e-06
# base std tensor([6.1513, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 263
# nlml -93289.54280799946
# err (0.0015158900024810572-9.66559219227129e-20j)
# eps 2.6731742581632166e-06
# base std tensor([6.1513, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 264
# nlml -93290.75035790063
# err (0.001515899439083634-9.665171800914902e-20j)
# eps 2.67281577542329e-06
# base std tensor([6.1513, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 265
# nlml -93291.83186716269
# err (0.0015158369949098297-9.666491937338299e-20j)
# eps 2.672447056311962e-06
# base std tensor([6.1513, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 266
# nlml -93293.13150933414
# err (0.0015156710657502235-9.663880929806097e-20j)
# eps 2.672068668287177e-06
# base std tensor([6.1513, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 267
# nlml -93294.7059671458
# err (0.0015157497764326988-9.663685769384074e-20j)
# eps 2.671682175412461e-06
# base std tensor([6.1513, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 268
# nlml -93295.67367349121
# err (0.0015155229121853817-9.663976540232942e-20j)
# eps 2.671288811196302e-06
# base std tensor([6.1513, 6.1415], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 269
# nlml -93296.15487704286
# err (0.0015155603591519961-9.66389561839704e-20j)
# eps 2.6708924444586847e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 270
# nlml -93295.43298799617
# err (0.0015154277984131197-9.662302748373972e-20j)
# eps 2.67049524606804e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 271
# nlml -93296.70349925345
# err (0.0015153451764722203-9.662559755022477e-20j)
# eps 2.6701016286448043e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 272
# nlml -93298.17535986647
# err (0.0015154059010864095-9.6623390217353e-20j)
# eps 2.6697114345832226e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 273
# nlml -93299.88464905742
# err (0.001515158709823659-9.661055658614365e-20j)
# eps 2.6693233362744738e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 274
# nlml -93302.34121358424
# err (0.0015150783535984673-9.660865777619379e-20j)
# eps 2.6689326411193153e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 275
# nlml -93303.47182581623
# err (0.0015150534039685478-9.65989325074703e-20j)
# eps 2.6685415031739215e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 276
# nlml -93304.03983466842
# err (0.00151492991291934-9.65946572468646e-20j)
# eps 2.6681531319377502e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 277
# nlml -93303.69065967939
# err (0.0015150321641652965-9.660228490815456e-20j)
# eps 2.6677724223415167e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 278
# nlml -93304.11527978844
# err (0.0015148819568584816-9.660178841018366e-20j)
# eps 2.6674018446053338e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 279
# nlml -93305.14575139151
# err (0.0015148645781673169-9.656874997383664e-20j)
# eps 2.6670410276884374e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 280
# nlml -93305.47500319724
# err (0.0015147740808443397-9.658127981821187e-20j)
# eps 2.6666921874309157e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 281
# nlml -93304.75362925345
# err (0.0015149341141995774-9.656595299259156e-20j)
# eps 2.6663626701856814e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 282
# nlml -93303.32356075481
# err (0.001514878425370366-9.659764455045032e-20j)
# eps 2.6660604383959214e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 283
# nlml -93300.49333224987
# err (0.0015152480429935738-9.65875510664711e-20j)
# eps 2.665801442126598e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 284
# nlml -93288.56497016967
# err (0.0015148683137965761-9.659745904845072e-20j)
# eps 2.6656148970046672e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 285
# nlml -93290.56186899342
# err (0.0015151197808246923-9.659304404139275e-20j)
# eps 2.66546987376232e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 286
# nlml -93294.4728659589
# err (0.0015146449911415283-9.659344867900694e-20j)
# eps 2.6653455073680923e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 287
# nlml -93298.83233006367
# err (0.0015146966647737194-9.657731874325594e-20j)
# eps 2.6652342855139106e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 288
# nlml -93302.24162847863
# err (0.0015144954537752813-9.656522725610712e-20j)
# eps 2.6651264747429095e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 289
# nlml -93305.23402296288
# err (0.0015143440774811-9.656174957264647e-20j)
# eps 2.665016579337839e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 290
# nlml -93307.09722410682
# err (0.0015143095225927659-9.653588157462042e-20j)
# eps 2.664900645591402e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 291
# nlml -93307.51368483358
# err (0.0015142012680058837-9.65564717190192e-20j)
# eps 2.664781150234453e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 292
# nlml -93308.14110106703
# err (0.0015142804408724074-9.653506677935281e-20j)
# eps 2.6646579820254787e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 293
# nlml -93309.56250424442
# err (0.0015141374456968607-9.655054151902844e-20j)
# eps 2.6645296005328467e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9788, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 294
# nlml -93313.33198738907
# err (0.0015139641518989743-9.653888747889123e-20j)
# eps 2.6643849352638507e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 295
# nlml -93316.14404060235
# err (0.0015139272433253189-9.651017114741778e-20j)
# eps 2.6642188379518515e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 296
# nlml -93316.75517720802
# err (0.0015137445867834686-9.6516571920417e-20j)
# eps 2.6640351137355944e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 297
# nlml -93317.32571809077
# err (0.0015139164208997588-9.652148544817293e-20j)
# eps 2.663836572323289e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0081, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 298
# nlml -93320.4460777022
# err (0.0015136233802777285-9.650137175305295e-20j)
# eps 2.6636155822066902e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 299
# nlml -93323.20316064628
# err (0.0015135405206794413-9.648027574355772e-20j)
# eps 2.6633662818039623e-06
# base std tensor([6.1513, 6.1414], device='cuda:0')
# min,max (tensor(-0.0080, device='cuda:0'), tensor(0.9789, device='cuda:0'))

# %%
st = torch.load("state.pt")
MC_base = st['MC_base']
S_diag = st['S_diag']
eps = st['eps']
# Prediction
#Phi_ = Phi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
#PhiX = Phi(MC_base * 1.j, X.to("cpu"))
#A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
#LA = torch.linalg.cholesky(A)
#alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to(torch.complex128).to("cpu"), upper=False)
#pred = Phi_.H @ torch.linalg.solve_triangular(LA.H, alpha, upper=True)
#pred = pred.real


#pred.detach().cpu().numpy().tofile("pred.dat")
#axis.cpu().numpy().tofile("axis.dat")
#time.cpu().numpy().tofile("time.dat")
# Out:
# <ipython-input-6-fda9fdf5842a>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   st = torch.load("state.pt")

# %%
# Prediction
#Phi_ = Phi(MC_base * 1.j, Ps.to(torch.complex128)).to(device)
#Phi_ = Phi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#dtPhi_ = dtPhi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#dxPhi_ = dxPhi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#dyPhi_ = dyPhi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#Phi_ = torch.cat((Phi_,dtPhi_,dxPhi_,dyPhi_),1)
#Phi_ = torch.cat((Phi_,dtPhi_),1)
PhiX = Phi(MC_base * 1.j, X.to("cpu"))
#dtPhiX = dtPhi(MC_base * 1.j, dtX.to("cpu"))
dxPhiX = dxPhi(MC_base * 1.j, dxX.to("cpu"))
dyPhiX = dyPhi(MC_base * 1.j, dyX.to("cpu"))
PhiX = torch.cat((PhiX,dxPhiX,dyPhiX),1)
#PhiX = torch.cat((PhiX,dtPhiX),1)
A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
LA = torch.linalg.cholesky(A)
alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to("cpu").to(torch.complex128), upper=False)
Phi_ = Phi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
predwave = Phi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
predwave = predwave.real
predwave.detach().cpu().numpy().tofile("predwave.dat")
del Phi_, predwave
dtPhi_ = dtPhi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
preddt = dtPhi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
preddt = preddt.real
preddt.detach().cpu().numpy().tofile("preddt.dat")
del dtPhi_, preddt
dxPhi_ = dxPhi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
preddx = dxPhi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
preddx = preddx.real
preddx.detach().cpu().numpy().tofile("preddx.dat")
del dxPhi_, preddx
dyPhi_ = dyPhi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
preddy = dyPhi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
preddy = preddy.real
preddy.detach().cpu().numpy().tofile("preddy.dat")
del dyPhi_, preddy

#predwave.detach().cpu().numpy().tofile("predwave.dat")
#preddt.detach().cpu().numpy().tofile("preddt.dat")
#preddx.detach().cpu().numpy().tofile("preddx.dat")
#preddy.detach().cpu().numpy().tofile("preddy.dat")
axis.cpu().numpy().tofile("axis.dat")
time.cpu().numpy().tofile("time.dat")

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !cp predwave.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp preddt.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp preddx.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp preddy.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp axis.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp time.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp state.pt "/content/drive/MyDrive/Colab Notebooks"

# %%
PhiX.shape
# Out:
# torch.Size([1000, 16443])
