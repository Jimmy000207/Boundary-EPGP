# %% [markdown]
# # Mount with Google Drive

# %%
# %reset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Main part

# %%
## Imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import pandas as pd
import math

# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# torch.set_default_dtype(torch.float32)
torch.set_default_dtype(torch.float64)
torch.manual_seed(13)



# Sampling parameters etc
#n_axis = 51
n_axis = 41
#n_time = 131
n_time = 81

axis = torch.linspace(0,4,n_axis, device=device)
time = torch.linspace(0,4,n_time, device=device)
Ps = torch.cartesian_prod(axis,axis,time)
# Number of points
lP = Ps.shape[0]


# Initial dataset
data_axis = torch.linspace(0,4, 81, device=device)
data_time = torch.linspace(0,4,81, device=device)
data_Ps = torch.cartesian_prod(data_axis,data_axis,data_time)
#data_Ps = torch.cartesian_prod(axis,axis,time)

mask = torch.logical_and(data_Ps[:,2] == 0. , data_Ps[:,0]**2+data_Ps[:,1]**2<=16.0)
X = data_Ps[mask]
dtX = data_Ps[mask]

mask1 = abs(data_Ps[:,0]) == 0.
dxX = data_Ps[mask1]

mask2 = abs(data_Ps[:,1]) == 0.
dyX = data_Ps[mask2]

#maskBC = (data_Ps[:,0]+data_Ps[:,1]==4.) or (data_Ps[:,0] ==0.) or (data_Ps[:,1] ==0.)
maskBC = (data_Ps[:,0]**2+data_Ps[:,1]**2==16.0)
Xbc = data_Ps[maskBC]

#Y = torch.exp(-(X[:,0]-0.5)**2*10)+torch.exp(-(X[:,1]+X[:,0]-6)**2*5)
Y = torch.exp(-((X[:,0]-1)**2+(X[:,1]-1)**2)*10)
#Y = torch.cos((X[:,0]-1)*5)+torch.cos((X[:,1]-1)*5)
Y = Y.view(-1,1)
Ybc = torch.where( ((Xbc[:,0]-1).abs() < 1e-1) & (Xbc[:,1].abs() < 1), 0., 0. ) # Create a bunch of 0
Ybc = Ybc.view(-1,1)

dtY = torch.where( ((dtX[:,0]-1).abs() < 1e-1) & (dtX[:,1].abs() < 1), 0., 0. )
#dtY = -2*5*(X[:,0]-3)*torch.exp(-(X[:,0]-3)**2*5)-2*5*(X[:,1]+X[:,0]-6)*torch.exp(-(X[:,1]+X[:,0]-6)**2*5)
#dtY = -5*(torch.sin((X[:,0]-1)*5)+torch.sin((X[:,1]-1)*5))
dtY = dtY.view(-1,1)

#dxY = torch.where( ((dxX[:,0]-1).abs() < 1e-1) & (dxX[:,1].abs() < 1), 0., 0. )
#dxY = dxY.view(-1,1)

#dyY = torch.where( ((dyX[:,0]-1).abs() < 1e-1) & (dyX[:,1].abs() < 1), 0., 0. )
#dyY = dyY.view(-1,1)

Xbc = Xbc.to(torch.complex128)
#dxX = dxX.to(torch.complex128)
#dyX = dyX.to(torch.complex128)
Ybc = Ybc.to(torch.complex128)
#dtX = dtX.to(torch.complex128)
#dtY = dtY.to(torch.complex128)
#dxY = dxY.to(torch.complex128)
#dyY = dyY.to(torch.complex128)
X = X.to(torch.complex128)
Y = Y.to(torch.complex128)
X = torch.cat((X,Xbc),0)
Y = torch.cat((Y,Ybc),0)
# Out:
# Using cuda device

# %%
Xbc.shape
# Out:
# torch.Size([19440, 3])

# %%
def getVarietyPoints(base1,base2):
    x1,y1 = base1.unbind(1)
    t1 = torch.sqrt(x1.square() + y1.square())
    #x2,y2 = base2.unbind(1)
    #t2 = torch.sqrt(x2.square() + y2.square())

    return torch.stack([ torch.stack([x1,y1,t1],1),torch.stack([x1,y1,-t1],1), torch.stack([-x1,y1,t1],1),torch.stack([-x1,y1,-t1],1),torch.stack([x1,-y1,t1],1),torch.stack([x1,-y1,-t1],1),torch.stack([-x1,-y1,t1],1),torch.stack([-x1,-y1,-t1],1) ])

def Phi(base1, base2, X):
    pts = getVarietyPoints(base1,base2)
    # return (pts.inner(X) * 1.j).exp().mean(0)
    return (pts.inner(X)).exp().mean(0)

def dtPhi(base1,base2, X):
    pts = getVarietyPoints(base1,base2)
    return ((pts.inner(X)).exp().mul(pts[:,:,2].unsqueeze(2).repeat(1, 1, pts.inner(X).shape[2])).mean(0))

def dxPhi(base1,base2, X):
    pts = getVarietyPoints(base1,base2)
    return ((pts.inner(X)).exp().mul(pts[:,:,0].unsqueeze(2).repeat(1, 1, pts.inner(X).shape[2])).mean(0))

def dyPhi(base1,base2, X):
    pts = getVarietyPoints(base1,base2)
    return ((pts.inner(X)).exp().mul(pts[:,:,1].unsqueeze(2).repeat(1, 1, pts.inner(X).shape[2])).mean(0))

def randomMask(n_pts=2000):
    mask = torch.zeros(X.shape[0]).bool()
    mask[torch.randperm(X.shape[0])[:n_pts]] = True
    return mask


def train(N):
    for epoch in range(N):
        PhiX = Phi(MC_base1 * 1.j, MC_base2 * 1.j, X)
        #dtPhiX = dtPhi(MC_base1 * 1.j, MC_base2 * 1.j, dtX)
        #dxPhiX = dxPhi(MC_base1 * 1.j, MC_base2 * 1.j, dxX)
        #dyPhiX = dyPhi(MC_base1 * 1.j, MC_base2 * 1.j, dyX)
        PhiX = torch.cat((PhiX,dtPhiX),1)
        A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
        LA = torch.linalg.cholesky(A)
        alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to(torch.complex128), upper=False)
        #print(PhiX.shape)
        #print(Y.shape)
        #print(A.shape)


        nlml = 1/(2*eps.exp()) * (Y.norm().square() - alpha.norm().square())
        nlml += (PhiX.shape[1] - PhiX.shape[0])/2 * eps
        nlml += LA.diag().real.log().sum()
        nlml += 0.5*S_diag.sum()

        opt.zero_grad()
        nlml.backward()
        opt.step()

        with torch.no_grad():
            train_pred = PhiX.H @ torch.linalg.solve_triangular(LA.H, alpha, upper=True)
            err = (train_pred.real - Y).square().mean().sqrt()
            print(26*"~" + f'\nepoch {epoch}\n\
nlml {nlml}\n\
err {err}\n\
eps {eps.exp()}\n\
base1 std {MC_base1.std(0)}\n\
min,max {train_pred.real.min().detach(),train_pred.real.max().detach()}')

# %%
n_MC = 1000
# MC_axis = torch.linspace(-1,1, n_MC, device=device) * 30
MC_base1 = (torch.randn((n_MC, 2), device=device)).requires_grad_()
MC_base2 = (torch.randn((n_MC, 2), device=device)).requires_grad_()
# MC_base = torch.cartesian_prod(MC_axis,MC_axis).requires_grad_()
S_diag = torch.full((n_MC,), -np.log(n_MC), requires_grad=True, device=device)
# S_diag = torch.full((n_MC**2,), -np.log(n_MC**2), requires_grad=False, device=device)
eps = torch.tensor(np.log(1e-2), requires_grad=True, device=device)

# %%
opt = torch.optim.Adam([
    {'params': [MC_base1,MC_base2], 'lr': 1e-1},
    {'params': eps, 'lr': 1e-2}])
#train(100000)
train(10000)
opt = torch.optim.Adam([
    {'params': [MC_base1,MC_base2], 'lr': 1e-2},
    {'params': eps, 'lr': 1e-2}])
#train(100000)
train(10000)
opt = torch.optim.Adam([
    {'params': [MC_base1,MC_base2], 'lr': 1e-2},
    {'params': [S_diag,eps], 'lr': 1e-2}])
train(1000)
opt = torch.optim.Adam([
    {'params': [MC_base1,MC_base2], 'lr': 1e-3},
    {'params': [S_diag,eps], 'lr': 1e-3}])
train(300)
torch.save({
            'MC_base1': MC_base1.cpu(),
            'MC_base2': MC_base2.cpu(),
            'S_diag': S_diag.cpu(),
            'eps': eps.cpu(),
    }, "state.pt")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 586
# nlml -207055.2452695943
# err (0.00014341068672208066-8.99034531330958e-21j)
# eps 2.7842409467970507e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 587
# nlml -207058.1413404597
# err (0.00014340583485936143-8.9777478907626e-21j)
# eps 2.783718847444027e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 588
# nlml -207060.51445546755
# err (0.00014338118039241375-8.975784635443376e-21j)
# eps 2.7831878754437633e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 589
# nlml -207065.03904606454
# err (0.00014338368991391025-8.984886119986682e-21j)
# eps 2.782648748692456e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 590
# nlml -207073.8371417499
# err (0.00014336837996461123-8.978997669875054e-21j)
# eps 2.782101153044494e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 591
# nlml -207076.90396527012
# err (0.00014336996911120775-8.976690135822745e-21j)
# eps 2.7815460851543992e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 592
# nlml -207079.97372901268
# err (0.00014342349722961883-8.982358139579464e-21j)
# eps 2.7809844461184163e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 593
# nlml -207083.3953373979
# err (0.00014335997724983105-8.980130479660469e-21j)
# eps 2.780416982685867e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 594
# nlml -207085.94615743466
# err (0.0001433562341475367-8.978601520275488e-21j)
# eps 2.7798445766646703e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 595
# nlml -207087.15593390135
# err (0.00014336831001245367-8.982521457074169e-21j)
# eps 2.7792683175530126e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 596
# nlml -207089.24844513324
# err (0.00014332759568741718-8.97689079164893e-21j)
# eps 2.7786890105580133e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 597
# nlml -207092.41846771742
# err (0.00014332976141306702-8.9739545851525e-21j)
# eps 2.7781071308428736e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 598
# nlml -207095.85511313088
# err (0.00014333411824458424-8.979676017202378e-21j)
# eps 2.7775230700522406e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 599
# nlml -207099.3486320171
# err (0.00014336879915699424-8.981489788333182e-21j)
# eps 2.776937138002386e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 600
# nlml -207101.23589294372
# err (0.0001433203120000266-8.977277267341345e-21j)
# eps 2.776350008882202e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 601
# nlml -207105.02196675466
# err (0.00014331478627912895-8.974894478330348e-21j)
# eps 2.7757618400833722e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 602
# nlml -207106.64844134537
# err (0.0001433182792678877-8.975291626731659e-21j)
# eps 2.775173285952888e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 603
# nlml -207109.2870502675
# err (0.0001432898392603296-8.974292292354659e-21j)
# eps 2.7745847072383078e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 604
# nlml -207110.62466683323
# err (0.00014330595241770407-8.975474734549252e-21j)
# eps 2.7739967372584953e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 605
# nlml -207113.37221815175
# err (0.000143285226960022-8.977043713434817e-21j)
# eps 2.773409632101871e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 606
# nlml -207116.52839142465
# err (0.00014330099129565238-8.975312139893291e-21j)
# eps 2.77282356433683e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 607
# nlml -207118.95311029215
# err (0.00014329113248415015-8.975986635708197e-21j)
# eps 2.772238895604466e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 608
# nlml -207121.4778003515
# err (0.00014331647632449145-8.977856052479446e-21j)
# eps 2.7716558403889593e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 609
# nlml -207119.01077243077
# err (0.00014331341699652707-8.974687825733963e-21j)
# eps 2.771075709523128e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 610
# nlml -207089.77373927453
# err (0.0001434682589645593-8.979666703319813e-21j)
# eps 2.7705055700472497e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 611
# nlml -207093.72104537018
# err (0.0001433395947681856-8.977739824580778e-21j)
# eps 2.7699441303987347e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 612
# nlml -207101.0163085482
# err (0.00014337677702430028-8.987925906281372e-21j)
# eps 2.769389586815293e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 613
# nlml -207101.43588910243
# err (0.0001433799431143054-8.983786904572624e-21j)
# eps 2.7688419368324985e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 614
# nlml -207105.49611127767
# err (0.00014339507309108263-8.977706572652873e-21j)
# eps 2.7683003260575424e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 615
# nlml -207111.4442543614
# err (0.00014333251936767276-8.981174748216495e-21j)
# eps 2.7677635889087e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 616
# nlml -207115.24159117945
# err (0.0001433535913490343-8.973594334009054e-21j)
# eps 2.767231204135479e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 617
# nlml -207119.9583464425
# err (0.00014335060402193126-8.977333532477443e-21j)
# eps 2.7667024266646885e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 618
# nlml -207119.48477090662
# err (0.0001432857173238321-8.978643875845674e-21j)
# eps 2.7661778410482802e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 619
# nlml -207119.66599726508
# err (0.00014340706944033658-8.978220269242613e-21j)
# eps 2.765657759829817e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 620
# nlml -207125.93013121758
# err (0.0001433239938115837-8.977746349023972e-21j)
# eps 2.765141125050214e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 621
# nlml -207130.635555327
# err (0.00014332343960925798-8.978290922541689e-21j)
# eps 2.764627297583386e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 622
# nlml -207133.1831001524
# err (0.0001432823215173178-8.974231260542646e-21j)
# eps 2.7641162357924434e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 623
# nlml -207136.27344642105
# err (0.0001432961588660026-8.978944870269907e-21j)
# eps 2.763607708926752e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 624
# nlml -207137.58198122127
# err (0.00014328138388244201-8.973594647993467e-21j)
# eps 2.76310200681942e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 625
# nlml -207137.8957129594
# err (0.0001432822719863946-8.976825964757834e-21j)
# eps 2.7625995559313686e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 626
# nlml -207136.44766421765
# err (0.0001432772653112518-8.97291630687144e-21j)
# eps 2.762101182747909e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 627
# nlml -207134.55403421677
# err (0.00014328559199773167-8.973439690941195e-21j)
# eps 2.7616076960027568e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 628
# nlml -207130.661636244
# err (0.00014331659163172811-8.979830820050401e-21j)
# eps 2.7611203562346904e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 629
# nlml -207122.56764689725
# err (0.00014337553958589054-8.980343205540864e-21j)
# eps 2.760641183171619e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 630
# nlml -207105.93465978294
# err (0.00014337829247187988-8.980351794543725e-21j)
# eps 2.7601740379746325e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 631
# nlml -207076.75705369035
# err (0.00014356354047395458-8.988800555866884e-21j)
# eps 2.7597252988731937e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 632
# nlml -207026.03713408648
# err (0.0001436386571075408-9.002812798428426e-21j)
# eps 2.7593058026338886e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 633
# nlml -206943.05659533842
# err (0.00014409004399097605-9.019072139226283e-21j)
# eps 2.758932698056194e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 634
# nlml -206809.79874097696
# err (0.00014437443667775416-9.053369597914895e-21j)
# eps 2.7586333492905442e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 635
# nlml -206615.8922326246
# err (0.0001453359702213046-9.095567526835637e-21j)
# eps 2.7584464033795106e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 636
# nlml -206366.292686347
# err (0.00014593110334424144-9.155830380450864e-21j)
# eps 2.7584199427352654e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 637
# nlml -206143.35635100762
# err (0.00014704266677438284-9.199615962181044e-21j)
# eps 2.758590742570768e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 638
# nlml -206073.5766797485
# err (0.00014698541798118287-9.219623034558743e-21j)
# eps 2.758956249424385e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0005, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 639
# nlml -206322.4783251745
# err (0.0001464387191990774-9.165370519592112e-21j)
# eps 2.759438770743407e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 640
# nlml -206770.29938478902
# err (0.00014461140874040123-9.065537153570396e-21j)
# eps 2.7599215402961046e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 641
# nlml -207097.80686324663
# err (0.0001435491744287035-8.992289811487153e-21j)
# eps 2.76032709853308e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 642
# nlml -207056.01390131333
# err (0.00014373255666872605-9.003882754879403e-21j)
# eps 2.760672859079627e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 643
# nlml -206817.29311786816
# err (0.000144372977608867-9.053335020713904e-21j)
# eps 2.7610210736112495e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 644
# nlml -206749.95403131566
# err (0.00014483549740908363-9.062950681101255e-21j)
# eps 2.7613873932918975e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 645
# nlml -206945.10658736233
# err (0.0001439617216053217-9.02770630279837e-21j)
# eps 2.7617238798522134e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 646
# nlml -207113.30461868522
# err (0.0001434912817521902-8.988814955952363e-21j)
# eps 2.7619935768714204e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 647
# nlml -207053.00307460246
# err (0.0001437737494079492-9.005815403416243e-21j)
# eps 2.7622173569842818e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 648
# nlml -206940.37138732977
# err (0.00014399848452122872-9.029800657471693e-21j)
# eps 2.7624266684988456e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0005, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 649
# nlml -206994.46799402943
# err (0.00014403853304228675-9.019978257178768e-21j)
# eps 2.7626101139142153e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 650
# nlml -207118.7711908693
# err (0.00014336711918395086-8.982637738464331e-21j)
# eps 2.7627408459579587e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 651
# nlml -207128.33882056864
# err (0.00014346031600485982-8.990348156093517e-21j)
# eps 2.7628219249959285e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 652
# nlml -207072.69404787233
# err (0.0001436400168874531-8.989827239738916e-21j)
# eps 2.762871720414156e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 653
# nlml -207092.25126368995
# err (0.000143505754244432-8.994085746504026e-21j)
# eps 2.7628889612650993e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 654
# nlml -207153.67692965703
# err (0.00014337732035589357-8.981408172104194e-21j)
# eps 2.7628623979579152e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 655
# nlml -207153.86781454936
# err (0.00014333738285840882-8.970868559360821e-21j)
# eps 2.762796662285465e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 656
# nlml -207123.98220735064
# err (0.00014346739713205298-8.993164512236839e-21j)
# eps 2.762703172429776e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 657
# nlml -207135.64631569086
# err (0.00014343374825990845-8.980372497175393e-21j)
# eps 2.7625822071888922e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 658
# nlml -207161.67622167896
# err (0.00014337763920589991-8.981240925508885e-21j)
# eps 2.762430734104818e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 659
# nlml -207159.91562857214
# err (0.00014333078929488433-8.987360619666002e-21j)
# eps 2.7622525719778118e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 660
# nlml -207157.36411581002
# err (0.0001434300073294114-8.977046704648744e-21j)
# eps 2.7620514829511942e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 661
# nlml -207174.14060790912
# err (0.00014328794708153738-8.982010778692672e-21j)
# eps 2.7618262346461103e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 662
# nlml -207181.10384556223
# err (0.00014328866208604017-8.9808789861379e-21j)
# eps 2.7615779936575467e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 663
# nlml -207171.8465661139
# err (0.00014334913862701034-8.97374138128862e-21j)
# eps 2.7613118923866705e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 664
# nlml -207175.3806728179
# err (0.00014328619793029123-8.987007607394018e-21j)
# eps 2.7610293671306332e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 665
# nlml -207188.72099671516
# err (0.0001433028997069993-8.97390355411027e-21j)
# eps 2.7607294290904805e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 666
# nlml -207185.7688240018
# err (0.0001432853085413517-8.97513445367138e-21j)
# eps 2.7604151352318804e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 667
# nlml -207175.85942147768
# err (0.00014333773494141916-8.987034286242586e-21j)
# eps 2.760090919685631e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 668
# nlml -206892.85991356088
# err (0.0001445528409679001-9.043648857284906e-21j)
# eps 2.7598264409747266e-08
# base1 std tensor([6.4079, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 669
# nlml -206811.47876684333
# err (0.00014487873900534117-9.094897106691217e-21j)
# eps 2.7596362449103464e-08
# base1 std tensor([6.4080, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 670
# nlml -204014.9198295214
# err (0.00015470373040197836-9.671972538978521e-21j)
# eps 2.7601918403360443e-08
# base1 std tensor([6.4080, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 671
# nlml -202933.17867327703
# err (0.0001570521391307654-9.682548336970818e-21j)
# eps 2.7616835765522956e-08
# base1 std tensor([6.4081, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 672
# nlml -201462.06727518066
# err (0.00016257452470303652-1.0206282024851713e-20j)
# eps 2.7643770323715265e-08
# base1 std tensor([6.4081, 6.4722], device='cuda:0')
# min,max (tensor(-0.0008, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 673
# nlml -202320.59539625095
# err (0.00016068641084685887-1.0018477597208146e-20j)
# eps 2.7679462661192292e-08
# base1 std tensor([6.4081, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 674
# nlml -201875.80868999314
# err (0.00016176063796210155-1.0131401372997947e-20j)
# eps 2.7724144095602826e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0007, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 675
# nlml -203200.95832770993
# err (0.00015826677288578893-9.986999025366653e-21j)
# eps 2.777367383043215e-08
# base1 std tensor([6.4082, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9971, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 676
# nlml -203811.98106288188
# err (0.00015585126821456995-9.777999987012436e-21j)
# eps 2.7826063745327978e-08
# base1 std tensor([6.4082, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9971, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 677
# nlml -204156.2722735187
# err (0.00015508143090084495-9.660922260371563e-21j)
# eps 2.7880159587736823e-08
# base1 std tensor([6.4082, 6.4722], device='cuda:0')
# min,max (tensor(-0.0005, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 678
# nlml -204170.5829559909
# err (0.00015499997494617673-9.652288509511064e-21j)
# eps 2.7935724329028655e-08
# base1 std tensor([6.4082, 6.4722], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 679
# nlml -205031.52265873674
# err (0.0001518439160557835-9.547539777125608e-21j)
# eps 2.7990449503999617e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 680
# nlml -204975.95145949363
# err (0.0001520183421436389-9.611377094967018e-21j)
# eps 2.8044509470418928e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0007, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 681
# nlml -205220.38704598867
# err (0.00015018737011092683-9.404593371628827e-21j)
# eps 2.8097314442647157e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 682
# nlml -205529.42827817547
# err (0.00014929880344102505-9.296644835731161e-21j)
# eps 2.8148168829670776e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 683
# nlml -205687.9218155097
# err (0.0001497118383523014-9.361330597835267e-21j)
# eps 2.8196815561107687e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 684
# nlml -205784.36885193715
# err (0.00014928310195094774-9.396881685500837e-21j)
# eps 2.8243181977256615e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 685
# nlml -206029.22449487075
# err (0.00014820832995911753-9.309903520470955e-21j)
# eps 2.8286830683269254e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 686
# nlml -206071.25598992853
# err (0.00014793202750295668-9.260553867287773e-21j)
# eps 2.8327873900428806e-08
# base1 std tensor([6.4081, 6.4723], device='cuda:0')
# min,max (tensor(-0.0007, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 687
# nlml -206288.94067637564
# err (0.00014629536074532118-9.156849776209601e-21j)
# eps 2.8365970547984866e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 688
# nlml -206181.65663374116
# err (0.0001475652625908995-9.224335131273735e-21j)
# eps 2.840164214045468e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 689
# nlml -206555.9909005106
# err (0.00014591765504693775-9.116203121854751e-21j)
# eps 2.8434139414522803e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 690
# nlml -206414.57863080947
# err (0.00014663388536797595-9.187339541398584e-21j)
# eps 2.846409987043904e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 691
# nlml -206578.7808230669
# err (0.00014616395048159468-9.214528705866378e-21j)
# eps 2.849131925309492e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 692
# nlml -206662.4770736601
# err (0.0001458925322638329-9.165959125075973e-21j)
# eps 2.851582108427723e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 693
# nlml -206657.3720959874
# err (0.00014562886658692691-9.112664141813201e-21j)
# eps 2.8537859680851712e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 694
# nlml -206773.21973598606
# err (0.00014489445726596013-9.052978906432022e-21j)
# eps 2.8557357891119586e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 695
# nlml -206762.53307613157
# err (0.00014530469647186666-9.089918071729218e-21j)
# eps 2.857457449910625e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0005, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 696
# nlml -206863.88215605993
# err (0.00014498287285025807-9.10398602768425e-21j)
# eps 2.858945468053474e-08
# base1 std tensor([6.4082, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 697
# nlml -206868.05509493503
# err (0.000144823328196889-9.096563468798229e-21j)
# eps 2.8602202072574126e-08
# base1 std tensor([6.4083, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 698
# nlml -206916.96117148543
# err (0.000144631008500751-9.071792016784251e-21j)
# eps 2.8612887645151727e-08
# base1 std tensor([6.4083, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 699
# nlml -206944.89928789716
# err (0.00014466491466866893-9.059226001634967e-21j)
# eps 2.862163149033956e-08
# base1 std tensor([6.4083, 6.4723], device='cuda:0')
# min,max (tensor(-0.0005, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 700
# nlml -206975.61716044298
# err (0.0001446312196143881-9.03946666408595e-21j)
# eps 2.8628538172253338e-08
# base1 std tensor([6.4083, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 701
# nlml -206432.6560419002
# err (0.00014645973377522612-9.136741114319977e-21j)
# eps 2.8635190393264383e-08
# base1 std tensor([6.4083, 6.4723], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 702
# nlml -206005.99192551576
# err (0.00014756470722617352-9.268840144832785e-21j)
# eps 2.8642724127156882e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 703
# nlml -205870.21987922193
# err (0.00014922442709144526-9.299545804861172e-21j)
# eps 2.8651399668124426e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0005, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 704
# nlml -206196.1169860096
# err (0.00014703907764561177-9.228953119478077e-21j)
# eps 2.8660248849914364e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 705
# nlml -206592.207597494
# err (0.00014621083342506862-9.12652159728269e-21j)
# eps 2.8668218377477112e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 706
# nlml -206782.10616804805
# err (0.0001454342796213258-9.117800120241399e-21j)
# eps 2.8674893974767818e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 707
# nlml -206556.85159356834
# err (0.00014611973156730072-9.19999109596276e-21j)
# eps 2.868098479043656e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 708
# nlml -206581.87852046153
# err (0.00014633130771004557-9.142900167328975e-21j)
# eps 2.8686478418637054e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 709
# nlml -206702.1135585878
# err (0.00014569139046203614-9.115636795450656e-21j)
# eps 2.8691117678848106e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 710
# nlml -206952.75213936757
# err (0.00014476277955067645-9.064839404344233e-21j)
# eps 2.869432853588883e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9972, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 711
# nlml -206858.91766912752
# err (0.00014530655679504718-9.082584368879522e-21j)
# eps 2.869649832739171e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 712
# nlml -206829.12052563965
# err (0.00014472646636975683-9.081469730379702e-21j)
# eps 2.869780907618502e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 713
# nlml -206922.11830145845
# err (0.00014500812353855243-9.094593758071393e-21j)
# eps 2.86981015878771e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 714
# nlml -206964.93029554424
# err (0.00014497263943727054-9.064858061447679e-21j)
# eps 2.8697364309241438e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 715
# nlml -207032.65154612443
# err (0.0001442218904318897-9.027507461518448e-21j)
# eps 2.8695523158549286e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 716
# nlml -206956.83832152004
# err (0.00014458729387773918-9.057259255480691e-21j)
# eps 2.869289467094947e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 717
# nlml -207028.35365752844
# err (0.00014438570529047538-9.04294343869706e-21j)
# eps 2.8689373575595088e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 718
# nlml -207108.4000842339
# err (0.0001441480662768029-9.02595726728262e-21j)
# eps 2.8684841801564004e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 719
# nlml -207066.00247600785
# err (0.00014425841645862258-9.031225633714058e-21j)
# eps 2.867952040560511e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 720
# nlml -207079.0213432051
# err (0.00014414239667645513-9.034652267983871e-21j)
# eps 2.8673462978447313e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 721
# nlml -207130.90215391645
# err (0.00014411214833031578-9.043778790933643e-21j)
# eps 2.8666614261300205e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 722
# nlml -207147.63182016235
# err (0.0001439363127712558-9.012603111955665e-21j)
# eps 2.8659019012030698e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 723
# nlml -207129.66376860614
# err (0.00014387946153081467-9.008762229194036e-21j)
# eps 2.8650810317647012e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 724
# nlml -207154.5555971855
# err (0.00014388089141801412-9.026129457386947e-21j)
# eps 2.86419947252906e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 725
# nlml -207187.4400877276
# err (0.0001437565164027602-9.005701406902475e-21j)
# eps 2.8632557568724096e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 726
# nlml -207174.36077095717
# err (0.00014379992025649968-9.004842350889858e-21j)
# eps 2.86226078984216e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 727
# nlml -207174.92684544812
# err (0.00014381594697747313-9.023439658856445e-21j)
# eps 2.8612209407765097e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 728
# nlml -207213.54486270374
# err (0.0001436066827599815-8.995876523099866e-21j)
# eps 2.8601318141093164e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 729
# nlml -207212.12137425144
# err (0.000143611936657023-8.979667587748793e-21j)
# eps 2.8590002313521834e-08
# base1 std tensor([6.4082, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 730
# nlml -207205.91767486857
# err (0.00014366597414476208-9.00560072977611e-21j)
# eps 2.857833548699449e-08
# base1 std tensor([6.4082, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 731
# nlml -207221.70508607736
# err (0.0001435560140387277-9.003211499305534e-21j)
# eps 2.856632534290343e-08
# base1 std tensor([6.4082, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 732
# nlml -207235.72047789788
# err (0.00014354856780135028-8.984347827231841e-21j)
# eps 2.855398456939187e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 733
# nlml -207235.44149198337
# err (0.00014354878491090118-8.994914052618694e-21j)
# eps 2.854136311653976e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 734
# nlml -207238.8899643839
# err (0.00014348810125235147-9.001790898996763e-21j)
# eps 2.8528495889846533e-08
# base1 std tensor([6.4083, 6.4724], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 735
# nlml -207245.2634717129
# err (0.000143565032412586-8.993374674092641e-21j)
# eps 2.8515407638082563e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 736
# nlml -207250.97399137795
# err (0.00014357595572375213-8.98777793214112e-21j)
# eps 2.850212242667149e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 737
# nlml -207259.13569095466
# err (0.00014350503628672603-8.990869856421606e-21j)
# eps 2.848865570530302e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 738
# nlml -207258.95882982205
# err (0.00014350207848954093-8.992320114287463e-21j)
# eps 2.847504402006731e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 739
# nlml -207261.9844172502
# err (0.00014347996018950962-8.984330957249672e-21j)
# eps 2.8461311367968522e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 740
# nlml -207269.21761473574
# err (0.00014345463196743175-8.985756224448665e-21j)
# eps 2.8447469207891744e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 741
# nlml -207273.34332870174
# err (0.00014343497174081643-8.99220608172538e-21j)
# eps 2.8433535727711587e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 742
# nlml -207274.08744408243
# err (0.00014342636405827148-8.983106350059987e-21j)
# eps 2.841953635110233e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 743
# nlml -207277.83143455474
# err (0.00014347455907918715-8.98281486693236e-21j)
# eps 2.8405486685890522e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 744
# nlml -207282.81486299762
# err (0.0001434129729044127-8.98782025570368e-21j)
# eps 2.8391397150035217e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 745
# nlml -207286.2827111472
# err (0.00014334309836678145-8.980177521174998e-21j)
# eps 2.8377281456356547e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 746
# nlml -207285.58494838665
# err (0.00014343386668363262-8.980170878481208e-21j)
# eps 2.8363163123870627e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 747
# nlml -207289.73648432866
# err (0.00014338653836846308-8.982229525777384e-21j)
# eps 2.8349050465199885e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 748
# nlml -207295.6361881455
# err (0.00014330018408767833-8.979185344951663e-21j)
# eps 2.8334946676152016e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 749
# nlml -207296.05413850734
# err (0.00014332392644429172-8.978315003311266e-21j)
# eps 2.83208691496513e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 750
# nlml -207296.88557949456
# err (0.00014334261619839485-8.9815030121323e-21j)
# eps 2.8306831750359028e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 751
# nlml -207186.7411959654
# err (0.00014367945758350854-8.996012741023989e-21j)
# eps 2.8293144199624493e-08
# base1 std tensor([6.4083, 6.4725], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 752
# nlml -207130.07470404837
# err (0.00014389597956475576-9.01986847311578e-21j)
# eps 2.8279945940561026e-08
# base1 std tensor([6.4083, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 753
# nlml -207190.4923135221
# err (0.00014387040560453522-9.003715262555445e-21j)
# eps 2.826703759058231e-08
# base1 std tensor([6.4083, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 754
# nlml -207197.98756425214
# err (0.00014366549462241598-8.999196634324899e-21j)
# eps 2.825438359924811e-08
# base1 std tensor([6.4083, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 755
# nlml -207204.39520322788
# err (0.00014362849168806543-8.994894404861786e-21j)
# eps 2.824195976886309e-08
# base1 std tensor([6.4083, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 756
# nlml -207218.29910437888
# err (0.00014373300671352093-8.999528305579934e-21j)
# eps 2.8229722960874793e-08
# base1 std tensor([6.4083, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 757
# nlml -207230.11898963325
# err (0.0001436103137041962-8.997544969464946e-21j)
# eps 2.8217639362226648e-08
# base1 std tensor([6.4084, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 758
# nlml -207245.30387710503
# err (0.0001436102882842828-8.99164675396138e-21j)
# eps 2.8205667256358235e-08
# base1 std tensor([6.4084, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 759
# nlml -207251.16263812452
# err (0.00014357847992254783-8.995131508466787e-21j)
# eps 2.819379405913097e-08
# base1 std tensor([6.4084, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 760
# nlml -207252.91727026438
# err (0.00014346933112231229-8.989727242196032e-21j)
# eps 2.8182020986045454e-08
# base1 std tensor([6.4083, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 761
# nlml -207241.1727747479
# err (0.00014371404242131844-8.999569165596087e-21j)
# eps 2.8170386628772195e-08
# base1 std tensor([6.4084, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 762
# nlml -207274.6590450944
# err (0.00014344672540321404-8.987997556716784e-21j)
# eps 2.8158802002539637e-08
# base1 std tensor([6.4084, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 763
# nlml -207287.95591328692
# err (0.00014341377908636427-8.982077335384348e-21j)
# eps 2.814724145698484e-08
# base1 std tensor([6.4084, 6.4726], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 764
# nlml -207278.80690333794
# err (0.0001435025524337485-8.976336702289592e-21j)
# eps 2.81357428765796e-08
# ...
# eps 2.7043514683159066e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 241
# nlml -207621.3822121304
# err (0.00014266987031993943-8.937969910813204e-21j)
# eps 2.7038911589742987e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 242
# nlml -207621.67437136648
# err (0.000142669141899195-8.93779584739465e-21j)
# eps 2.703459452389267e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 243
# nlml -207622.04271028348
# err (0.0001426679784575931-8.937268543104813e-21j)
# eps 2.7030554924863896e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 244
# nlml -207622.39049280956
# err (0.00014266707721855373-8.936859478949382e-21j)
# eps 2.7026783935139066e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 245
# nlml -207622.7013470894
# err (0.00014266779623713655-8.936921314455521e-21j)
# eps 2.702327279946874e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 246
# nlml -207623.02388650924
# err (0.0001426697572205689-8.937246454080881e-21j)
# eps 2.702001246979752e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 247
# nlml -207623.31764636902
# err (0.0001426708264085159-8.937388119835057e-21j)
# eps 2.701699402118357e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 248
# nlml -207623.6403463041
# err (0.00014266951576175126-8.937237699028674e-21j)
# eps 2.7014207775016498e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 249
# nlml -207623.9674020816
# err (0.00014266759545506394-8.937112406614637e-21j)
# eps 2.7011643579630862e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 250
# nlml -207624.25734274235
# err (0.00014266750802627865-8.937240207687361e-21j)
# eps 2.700929148213913e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 251
# nlml -207624.5487944803
# err (0.00014266882084370977-8.937450138142016e-21j)
# eps 2.7007141481689764e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 252
# nlml -207624.8485303533
# err (0.00014266918297559198-8.937464103671661e-21j)
# eps 2.7005183514560453e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 253
# nlml -207625.14330973048
# err (0.00014266767241390545-8.937247815947762e-21j)
# eps 2.7003407520162888e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 254
# nlml -207625.43782280144
# err (0.00014266568470192305-8.93695849493602e-21j)
# eps 2.700180334970666e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 255
# nlml -207625.72250569586
# err (0.0001426646874996201-8.936728373213619e-21j)
# eps 2.7000361003327006e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 256
# nlml -207626.01675525293
# err (0.00014266415715449124-8.936590036871699e-21j)
# eps 2.6999070567069402e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 257
# nlml -207626.30466001437
# err (0.00014266287418017922-8.936547274268204e-21j)
# eps 2.6997922472043768e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 258
# nlml -207626.58741147447
# err (0.0001426607892745394-8.936558041954113e-21j)
# eps 2.6996907457122245e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 259
# nlml -207626.88118706702
# err (0.00014265882843027684-8.93650286783418e-21j)
# eps 2.6996016355260902e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 260
# nlml -207627.15287852963
# err (0.00014265756854152045-8.936316035143986e-21j)
# eps 2.6995240466375052e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 261
# nlml -207627.43826135143
# err (0.00014265673399390695-8.936107322577936e-21j)
# eps 2.699457110379919e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 262
# nlml -207627.72891549452
# err (0.00014265642109675361-8.936085390493698e-21j)
# eps 2.6993999744305354e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 263
# nlml -207628.0036511256
# err (0.00014265667517775432-8.936283396831895e-21j)
# eps 2.6993518372683262e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 264
# nlml -207628.2841675788
# err (0.00014265661963889636-8.936492572022247e-21j)
# eps 2.6993119286203037e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 265
# nlml -207628.5621621781
# err (0.00014265562631950786-8.936533854516467e-21j)
# eps 2.69927951842053e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 266
# nlml -207628.84459498923
# err (0.00014265446631872488-8.936459328638942e-21j)
# eps 2.699253901025463e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 267
# nlml -207629.12545299617
# err (0.00014265447065138807-8.93643979951861e-21j)
# eps 2.699234398607572e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 268
# nlml -207629.40187818927
# err (0.00014265531688629533-8.936507965269962e-21j)
# eps 2.6992203659611016e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 269
# nlml -207629.6810014674
# err (0.0001426551227985233-8.936522885694001e-21j)
# eps 2.6992111859872402e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 270
# nlml -207629.96066685452
# err (0.00014265317470539337-8.936380723778058e-21j)
# eps 2.6992062775675127e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 271
# nlml -207630.23879274854
# err (0.00014265109364230798-8.936155059055325e-21j)
# eps 2.6992051011196393e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 272
# nlml -207630.5190487627
# err (0.00014265050413091128-8.935987834198473e-21j)
# eps 2.699207151110135e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 273
# nlml -207630.79683415714
# err (0.00014265077246815888-8.935915877694428e-21j)
# eps 2.6992119543694232e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 274
# nlml -207631.0739238029
# err (0.00014265011305371878-8.935870073301604e-21j)
# eps 2.6992190637356832e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 275
# nlml -207631.35359946557
# err (0.00014264831078140877-8.935818840736783e-21j)
# eps 2.6992280569756342e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 276
# nlml -207631.6319049248
# err (0.0001426468807561023-8.935813956898028e-21j)
# eps 2.6992385457103525e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 277
# nlml -207631.91183446575
# err (0.00014264669938126649-8.93587326227689e-21j)
# eps 2.699250170532257e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 278
# nlml -207632.19152220557
# err (0.00014264701469361528-8.935916868340694e-21j)
# eps 2.6992625999072048e-08
# base1 std tensor([6.4082, 6.4735], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 279
# nlml -207632.47063669702
# err (0.00014264684299797288-8.935867888072279e-21j)
# eps 2.6992755302518363e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 280
# nlml -207632.75108241074
# err (0.00014264623781886255-8.935758887605647e-21j)
# eps 2.6992886848285053e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 281
# nlml -207633.03136095643
# err (0.00014264570244343618-8.935670361084035e-21j)
# eps 2.6993018133451008e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 282
# nlml -207633.31252910674
# err (0.000142645141014951-8.935605660501303e-21j)
# eps 2.699314685924957e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 283
# nlml -207633.59324086338
# err (0.00014264417571130804-8.935517894721152e-21j)
# eps 2.6993270937860623e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 284
# nlml -207633.87410595999
# err (0.00014264298289530536-8.935430622444601e-21j)
# eps 2.6993388521081636e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 285
# nlml -207634.15600899345
# err (0.0001426421170008138-8.935425398031916e-21j)
# eps 2.6993498014835572e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 286
# nlml -207634.43806797132
# err (0.00014264167485607225-8.93549763479603e-21j)
# eps 2.6993598059803753e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 287
# nlml -207634.7207541398
# err (0.00014264117120984688-8.935523403829287e-21j)
# eps 2.6993687460739756e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 288
# nlml -207635.0040869578
# err (0.0001426402613323836-8.9354172528461e-21j)
# eps 2.6993765142765045e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 289
# nlml -207635.2877505813
# err (0.0001426391797782652-8.935253294101199e-21j)
# eps 2.6993830157943582e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 290
# nlml -207635.57146406977
# err (0.00014263837331768463-8.935169955712951e-21j)
# eps 2.6993881716099523e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 291
# nlml -207635.8558456104
# err (0.00014263794087707561-8.935196754706302e-21j)
# eps 2.6993919190820344e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 292
# nlml -207636.14075312778
# err (0.00014263756371228566-8.935238677729621e-21j)
# eps 2.699394210606486e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 293
# nlml -207636.42617882628
# err (0.000142636875337159-8.93521133972975e-21j)
# eps 2.69939501076036e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 294
# nlml -207636.71200385634
# err (0.00014263582735578933-8.93513023847051e-21j)
# eps 2.6993942946264112e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 295
# nlml -207636.9982350334
# err (0.00014263471060452435-8.935059283294003e-21j)
# eps 2.699392047456746e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 296
# nlml -207637.28498164914
# err (0.00014263383295579573-8.935019059873592e-21j)
# eps 2.6993882645757202e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 297
# nlml -207637.5719765375
# err (0.0001426331936764513-8.934977317627749e-21j)
# eps 2.6993829513455446e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 298
# nlml -207637.8595060362
# err (0.00014263252770101183-8.934909839846505e-21j)
# eps 2.699376121656289e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 299
# nlml -207638.1475171852
# err (0.00014263166370173918-8.93483401307492e-21j)
# eps 2.6993677958330863e-08
# base1 std tensor([6.4082, 6.4736], device='cuda:0')
# min,max (tensor(-0.0006, device='cuda:0'), tensor(0.9973, device='cuda:0'))

# %%
#torch.save({
#            'MC_base1': MC_base1.cpu(),
#            'MC_base2': MC_base2.cpu(),
#            'S_diag': S_diag.cpu(),
#            'eps': eps.cpu(),
#    }, "state.pt")


st = torch.load("state.pt")
MC_base1 = st['MC_base1']
MC_base2 = st['MC_base2']
S_diag = st['S_diag']
eps = st['eps']

# Prediction
#Phi_ = Phi(MC_base * 1.j, Ps.to(torch.complex128)).to(device)
#Phi_ = Phi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#dtPhi_ = dtPhi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#dxPhi_ = dxPhi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#dyPhi_ = dyPhi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#Phi_ = torch.cat((Phi_,dtPhi_,dxPhi_,dyPhi_),1)
#Phi_ = torch.cat((Phi_,dtPhi_),1)
#Y = torch.cat((Y,dtY),0)
PhiX = Phi(MC_base1 * 1.j,MC_base2 * 1.j, X.to("cpu"))
dtPhiX = dtPhi(MC_base1 * 1.j, MC_base2 * 1.j, dtX.to("cpu"))
#dxPhiX = dxPhi(MC_base1 * 1.j,MC_base2 * 1.j, dxX.to("cpu"))
#dyPhiX = dyPhi(MC_base1 * 1.j,MC_base2 * 1.j, dyX.to("cpu"))
#PhiX = torch.cat((PhiX,dtPhiX,dxPhiX,dyPhiX),1)
PhiX = torch.cat((PhiX,dtPhiX),1)
A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
LA = torch.linalg.cholesky(A)
alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to("cpu").to(torch.complex128), upper=False)
Phi_ = Phi(MC_base1 * 1.j,MC_base2 * 1.j,  Ps.to(torch.complex128).to("cpu"))
predwave = Phi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
predwave = predwave.real
predwave.detach().cpu().numpy().tofile("predwave.dat")
del Phi_
dtPhi_ = dtPhi(MC_base1 * 1.j,MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
preddt = dtPhi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
preddt = preddt.real
preddt.detach().cpu().numpy().tofile("preddt.dat")
del dtPhi_, preddt
dxPhi_ = dxPhi(MC_base1 * 1.j,MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
preddx = dxPhi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
preddx = preddx.real
preddx.detach().cpu().numpy().tofile("preddx.dat")
del dxPhi_, preddx
dyPhi_ = dyPhi(MC_base1 * 1.j,MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
preddy = dyPhi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
preddy = preddy.real
preddy.detach().cpu().numpy().tofile("preddy.dat")
del dyPhi_, preddy

axis.cpu().numpy().tofile("axis.dat")
time.cpu().numpy().tofile("time.dat")
# Out:
# <ipython-input-8-2af1dd4e518c>:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   st = torch.load("state.pt")

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !cp predwave.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp preddt.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp preddx.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp preddy.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp axis.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp time.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp state.pt "/content/drive/MyDrive/Colab Notebooks"

# %%
predwave1=predwave.reshape(n_axis,n_axis,n_time)
predwave1.shape
# Out:
# torch.Size([41, 41, 81])

# %%
for i in range(0,41,1):
  for j in range(0,41,1):
    if (axis[i]+axis[j]>4.0):
      predwave1[i,j,:]=0.

# %%
axis[1]
# Out:
# tensor(0.1000, device='cuda:0')

# %%
predwave1.view_as(predwave).detach().cpu().numpy().tofile("predwedge.dat")
# !cp predwedge.dat "/content/drive/MyDrive/Colab Notebooks"

# %%
plt.ion()
f, ax = plt.subplots()
sn.kdeplot(x = MC_base1.detach().numpy()[:,0], y = MC_base1.detach().numpy()[:,1], fill=True)
sn.scatterplot(x = MC_base1.detach().numpy()[:,0], y = MC_base1.detach().numpy()[:,1], s=10)
sn.kdeplot(x = MC_base1.detach().numpy()[:,0], y = MC_base1.detach().numpy()[:,1], bw_adjust=0.5, fill=True)
plt.title("Positive t")
plt.show()
