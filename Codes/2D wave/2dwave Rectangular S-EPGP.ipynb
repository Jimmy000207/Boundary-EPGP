# %% [markdown]
# # 新段落

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import pandas as pd
import math

# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# torch.set_default_dtype(torch.float32)
torch.set_default_dtype(torch.float64)
torch.manual_seed(13)



# Sampling parameters etc
n_axis = 41
#n_axis = 21
n_time = 61
#n_time = 81

axis = torch.linspace(-2,2,n_axis, device=device)
time = torch.linspace(0,12,n_time, device=device)
Ps = torch.cartesian_prod(axis,axis,time)
# Number of points
lP = Ps.shape[0]


# Initial dataset
data_axis = torch.linspace(-2,2, 101, device=device)
data_time = torch.linspace(0,12,121, device=device)
data_Ps = torch.cartesian_prod(data_axis,data_axis,time)


mask = data_Ps[:,2] == 0.
X = data_Ps[mask]
dtX = data_Ps[mask]

mask1 = (abs(abs(data_Ps[:,0]) - 2.) < 1e-10)
dxX = data_Ps[mask1]

mask2 = (abs(abs(data_Ps[:,1]) - 2.) < 1e-10)
dyX = data_Ps[mask2]

Y = torch.exp(-(4*(X[:,0]-0.5)**2+(X[:,1]-1)**2)*10)
#Y = torch.exp(-(X[:,0]-0.5)**2*2.5)+torch.exp(-(X[:,1]-1)**2*5)
#Y = torch.cos((X[:,0]-1)*5)+torch.cos((X[:,1]-1)*5)
Y = Y.view(-1,1)

#dtY = -2*5*(X[:,0])*torch.exp(-(X[:,0])**2*5)-2*5*(X[:,1])*torch.exp(-(X[:,1])**2*5)
#dtY = -10*((X[:,0]-0.5)**2+(X[:,1]-0.5)**2)*torch.exp(-((X[:,0]-0.5)**2+(X[:,1]-0.5)**2)*10)
#dtY = -5*(torch.sin((X[:,0]-1)*5)+torch.sin((X[:,1]-1)*5))
#dtY = dtY.view(-1,1)

dxY = torch.where( ((dxX[:,0]-1).abs() < 1e-1) & (dxX[:,1].abs() < 1), 0., 0. )
dxY = dxY.view(-1,1)

dyY = torch.where( ((dyX[:,0]-1).abs() < 1e-1) & (dyX[:,1].abs() < 1), 0., 0. )
dyY = dyY.view(-1,1)

#dtX = dtX.to(torch.complex128)
dxX = dxX.to(torch.complex128)
dyX = dyX.to(torch.complex128)
dxY = dxY.to(torch.complex128)
dyY = dyY.to(torch.complex128)
X = X.to(torch.complex128)
Y = Y.to(torch.complex128)
#Y = torch.cat((Y,dtY,dxY,dyY),0)
Y = torch.cat((Y,dxY,dyY),0)

#sn.heatmap(Y.view(101, 101))
# Out:
# Using cuda device

# %%
def getVarietyPoints(base):
    x,y = base.unbind(1)
    t = torch.sqrt(x.square() + y.square())

    return torch.stack([ torch.stack([x,y,t],1), torch.stack([x,y,-t],1) ])

def Phi(base, X):
    pts = getVarietyPoints(base)
    # return (pts.inner(X) * 1.j).exp().mean(0)
    return (pts.inner(X)).exp().mean(0)

def dtPhi(base, X):
    pts = getVarietyPoints(base)
    return ((pts.inner(X)).exp().mul(pts[:,:,2].unsqueeze(2).repeat(1, 1, pts.inner(X).shape[2])).mean(0))

def dxPhi(base, X):
    pts = getVarietyPoints(base)
    return ((pts.inner(X)).exp().mul(pts[:,:,0].unsqueeze(2).repeat(1, 1, pts.inner(X).shape[2])).mean(0))

def dyPhi(base, X):
    pts = getVarietyPoints(base)
    return ((pts.inner(X)).exp().mul(pts[:,:,1].unsqueeze(2).repeat(1, 1, pts.inner(X).shape[2])).mean(0))


def train(N):
    for epoch in range(N):
        PhiX = Phi(MC_base * 1.j, X)
        #dtPhiX = dtPhi(MC_base * 1.j, dtX)
        dxPhiX = dxPhi(MC_base * 1.j, dxX)
        dyPhiX = dyPhi(MC_base * 1.j, dyX)
        #PhiX = torch.cat((PhiX,dtPhiX,dxPhiX,dyPhiX),1)
        PhiX = torch.cat((PhiX,dxPhiX,dyPhiX),1)
        A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
        LA = torch.linalg.cholesky(A)
        alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to(torch.complex128), upper=False)

        nlml = 1/(2*eps.exp()) * (Y.norm().square() - alpha.norm().square())
        nlml += (PhiX.shape[1] - PhiX.shape[0])/2 * eps
        nlml += LA.diag().real.log().sum()
        nlml += 0.5*S_diag.sum()

        opt.zero_grad()
        nlml.backward()
        opt.step()

        with torch.no_grad():
            train_pred = PhiX.H @ torch.linalg.solve_triangular(LA.H, alpha, upper=True)
            err = (train_pred.real - Y).square().mean().sqrt()
            print(26*"~" + f'\nepoch {epoch}\n\
nlml {nlml}\n\
err {err}\n\
eps {eps.exp()}\n\
base std {MC_base.std(0)}\n\
min,max {train_pred.real.min().detach(),train_pred.real.max().detach()}')

# %%
n_MC = 2000
# MC_axis = torch.linspace(-1,1, n_MC, device=device) * 30
MC_base = (torch.randn((n_MC, 2), device=device)).requires_grad_()
# MC_base = torch.cartesian_prod(MC_axis,MC_axis).requires_grad_()
S_diag = torch.full((n_MC,), -np.log(n_MC), requires_grad=True, device=device)
# S_diag = torch.full((n_MC**2,), -np.log(n_MC**2), requires_grad=False, device=device)
eps = torch.tensor(np.log(1e-2), requires_grad=True, device=device)

# %%
opt = torch.optim.Adam([
    {'params': MC_base, 'lr': 1e-1},
    {'params': eps, 'lr': 1e-2}])
train(10000)
opt = torch.optim.Adam([
    {'params': MC_base, 'lr': 1e-1},
    {'params': eps, 'lr': 1e-2}])
train(10000)
opt = torch.optim.Adam([
    {'params': MC_base, 'lr': 1e-2},
    {'params': [S_diag, eps], 'lr': 1e-2}])
train(1000)
opt = torch.optim.Adam([
    {'params': MC_base, 'lr': 1e-3},
    {'params': [S_diag, eps], 'lr': 1e-3}])
train(300)


torch.save({
            'MC_base': MC_base.cpu(),
            'S_diag': S_diag.cpu(),
            'eps': eps.cpu(),
    }, "state.pt")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# base std tensor([8.2178, 4.3762], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 586
# nlml -369387.68352593196
# err (0.008796892683699969-5.897526836506838e-19j)
# eps 8.726231560601091e-05
# base std tensor([8.2178, 4.3762], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8308, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 587
# nlml -369359.6570145212
# err (0.008799575330280474-5.89779740287917e-19j)
# eps 8.723532119135064e-05
# base std tensor([8.2178, 4.3762], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8308, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 588
# nlml -369353.1858896251
# err (0.00880088816924334-5.899089020200187e-19j)
# eps 8.721742701947462e-05
# base std tensor([8.2178, 4.3763], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8308, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 589
# nlml -369447.34987588995
# err (0.008792840912904996-5.896268516705202e-19j)
# eps 8.720116924947807e-05
# base std tensor([8.2178, 4.3763], device='cuda:0')
# min,max (tensor(-0.0272, device='cuda:0'), tensor(0.8309, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 590
# nlml -369501.0944975889
# err (0.008789634969194538-5.89053898864584e-19j)
# eps 8.718303297009151e-05
# base std tensor([8.2177, 4.3763], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 591
# nlml -369464.5312862928
# err (0.008790473234229162-5.891791110177649e-19j)
# eps 8.716690149548952e-05
# base std tensor([8.2177, 4.3764], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 592
# nlml -369460.738370682
# err (0.00879163419015892-5.895993534216205e-19j)
# eps 8.715374138404466e-05
# base std tensor([8.2177, 4.3764], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8309, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 593
# nlml -369503.2854884985
# err (0.008791381076015055-5.892774021335951e-19j)
# eps 8.714058890929562e-05
# base std tensor([8.2177, 4.3764], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 594
# nlml -369479.9004417262
# err (0.008792416425151113-5.891668616174556e-19j)
# eps 8.712955313064851e-05
# base std tensor([8.2176, 4.3764], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 595
# nlml -369435.3055757399
# err (0.008796151205370684-5.899906862402359e-19j)
# eps 8.712476046913131e-05
# base std tensor([8.2176, 4.3765], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8308, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 596
# nlml -369463.38111374236
# err (0.008798066620210456-5.897395438477715e-19j)
# eps 8.712383930269799e-05
# base std tensor([8.2177, 4.3765], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8309, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 597
# nlml -369507.508646454
# err (0.008794623064954831-5.893323535150832e-19j)
# eps 8.712337805589479e-05
# base std tensor([8.2176, 4.3765], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 598
# nlml -369481.5784776427
# err (0.008795422227675055-5.895194123968762e-19j)
# eps 8.712544686178877e-05
# base std tensor([8.2176, 4.3766], device='cuda:0')
# min,max (tensor(-0.0272, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 599
# nlml -369515.3203387386
# err (0.008792384266320305-5.893063006399295e-19j)
# eps 8.71272596352202e-05
# base std tensor([8.2177, 4.3766], device='cuda:0')
# min,max (tensor(-0.0272, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 600
# nlml -369554.1456663869
# err (0.008788815327017063-5.88969634566102e-19j)
# eps 8.712587381169592e-05
# base std tensor([8.2177, 4.3767], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 601
# nlml -369542.1434329548
# err (0.008786962710673401-5.889411500163526e-19j)
# eps 8.712244276306877e-05
# base std tensor([8.2177, 4.3767], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 602
# nlml -369539.4819897011
# err (0.008787248928983155-5.889478196283665e-19j)
# eps 8.711784191236765e-05
# base std tensor([8.2177, 4.3767], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 603
# nlml -369560.7710526642
# err (0.008784720903574064-5.886749954988073e-19j)
# eps 8.71107255990309e-05
# base std tensor([8.2177, 4.3767], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 604
# nlml -369576.27707054955
# err (0.008786071402227149-5.888935190337185e-19j)
# eps 8.710076928285048e-05
# base std tensor([8.2177, 4.3767], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 605
# nlml -369578.4563463977
# err (0.00878578492830628-5.886843023266039e-19j)
# eps 8.708861785693746e-05
# base std tensor([8.2177, 4.3767], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 606
# nlml -369582.60545748123
# err (0.008784470754521554-5.887054223742757e-19j)
# eps 8.70746674806569e-05
# base std tensor([8.2177, 4.3767], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 607
# nlml -369600.4153801025
# err (0.008786149972156768-5.889239122674663e-19j)
# eps 8.705852002110108e-05
# base std tensor([8.2177, 4.3767], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 608
# nlml -369620.03729497246
# err (0.00878398036300787-5.885891247048437e-19j)
# eps 8.703987588613476e-05
# base std tensor([8.2176, 4.3767], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 609
# nlml -369615.3049599708
# err (0.008782024458362988-5.885989317664684e-19j)
# eps 8.701998294458119e-05
# base std tensor([8.2176, 4.3766], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 610
# nlml -369615.3935930304
# err (0.008786039533424796-5.888926954473844e-19j)
# eps 8.699998943660894e-05
# base std tensor([8.2176, 4.3766], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 611
# nlml -369625.1624181676
# err (0.008781060268428943-5.883523653224237e-19j)
# eps 8.698018247935133e-05
# base std tensor([8.2176, 4.3767], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 612
# nlml -369638.1085301531
# err (0.008783634228576155-5.886550231683109e-19j)
# eps 8.696066982188305e-05
# base std tensor([8.2176, 4.3767], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 613
# nlml -369650.3520431511
# err (0.008783303306230068-5.885834767238935e-19j)
# eps 8.69414182632838e-05
# base std tensor([8.2176, 4.3767], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 614
# nlml -369655.5879182583
# err (0.00878151771352194-5.884943338537832e-19j)
# eps 8.69230294035236e-05
# base std tensor([8.2176, 4.3767], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 615
# nlml -369649.57748696266
# err (0.008785901382495211-5.889011727483508e-19j)
# eps 8.690704217982624e-05
# base std tensor([8.2176, 4.3768], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 616
# nlml -369657.3641918067
# err (0.00877958462839439-5.8827670634429515e-19j)
# eps 8.68933879896446e-05
# base std tensor([8.2176, 4.3768], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 617
# nlml -369660.71856943704
# err (0.008781209756442004-5.884806050009355e-19j)
# eps 8.688236038570256e-05
# base std tensor([8.2177, 4.3768], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 618
# nlml -369659.31580069644
# err (0.008780592002810794-5.884180670044533e-19j)
# eps 8.687436586212084e-05
# base std tensor([8.2176, 4.3769], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 619
# nlml -369658.1864316313
# err (0.008782616382747447-5.88518345479e-19j)
# eps 8.686966814565423e-05
# base std tensor([8.2176, 4.3769], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 620
# nlml -369649.75876682124
# err (0.008782731490245704-5.886369113141345e-19j)
# eps 8.68692027869562e-05
# base std tensor([8.2176, 4.3769], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 621
# nlml -369661.9164094915
# err (0.008785493192951624-5.887441072344197e-19j)
# eps 8.687196129618883e-05
# base std tensor([8.2177, 4.3769], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 622
# nlml -369652.8466337851
# err (0.008782842098842088-5.884120043232563e-19j)
# eps 8.687841117666326e-05
# base std tensor([8.2177, 4.3770], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 623
# nlml -369643.8176440564
# err (0.008787377022131528-5.889890247893902e-19j)
# eps 8.68886600131724e-05
# base std tensor([8.2177, 4.3770], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 624
# nlml -369640.9029805812
# err (0.008786587066747294-5.889422468852167e-19j)
# eps 8.690268727264421e-05
# base std tensor([8.2177, 4.3771], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 625
# nlml -369649.7029351678
# err (0.008786006779468367-5.888226885274921e-19j)
# eps 8.691879292971228e-05
# base std tensor([8.2177, 4.3771], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 626
# nlml -369646.57808966475
# err (0.008787055196037117-5.888032007702105e-19j)
# eps 8.693620971414768e-05
# base std tensor([8.2178, 4.3771], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 627
# nlml -369628.3142609083
# err (0.008785858282402404-5.888455646256526e-19j)
# eps 8.695576729464339e-05
# base std tensor([8.2178, 4.3771], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 628
# nlml -369614.1166823925
# err (0.008788807039228148-5.890406223322879e-19j)
# eps 8.697760015867682e-05
# base std tensor([8.2178, 4.3771], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 629
# nlml -369602.43060721795
# err (0.008786212803290542-5.88915380735702e-19j)
# eps 8.700156499821702e-05
# base std tensor([8.2178, 4.3771], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 630
# nlml -369594.51785837946
# err (0.008787318096244702-5.888076536133615e-19j)
# eps 8.702721433959501e-05
# base std tensor([8.2178, 4.3772], device='cuda:0')
# min,max (tensor(-0.0272, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 631
# nlml -369554.3395249811
# err (0.008790940671194757-5.893382896088331e-19j)
# eps 8.705649323059619e-05
# base std tensor([8.2178, 4.3772], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8309, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 632
# nlml -369518.34087360953
# err (0.008793023184775019-5.895159499126162e-19j)
# eps 8.709072754121967e-05
# base std tensor([8.2177, 4.3772], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8309, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 633
# nlml -369487.1699607085
# err (0.008792503177168834-5.891551237913686e-19j)
# eps 8.713043833455336e-05
# base std tensor([8.2177, 4.3772], device='cuda:0')
# min,max (tensor(-0.0272, device='cuda:0'), tensor(0.8309, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 634
# nlml -369427.3911606609
# err (0.008799738978070945-5.899417774300435e-19j)
# eps 8.717849521880872e-05
# base std tensor([8.2177, 4.3772], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8307, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 635
# nlml -369555.75744161307
# err (0.008789685667573923-5.894929636786492e-19j)
# eps 8.72211426884296e-05
# base std tensor([8.2176, 4.3772], device='cuda:0')
# min,max (tensor(-0.0272, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 636
# nlml -369459.0410715484
# err (0.008796448194748003-5.895617845960929e-19j)
# eps 8.726470054762349e-05
# base std tensor([8.2176, 4.3772], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8309, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 637
# nlml -369428.90376033605
# err (0.008796474297860965-5.899090814501516e-19j)
# eps 8.731006310175393e-05
# base std tensor([8.2176, 4.3773], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8308, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 638
# nlml -369484.1827237799
# err (0.008795138179330744-5.90168615164306e-19j)
# eps 8.735051309016585e-05
# base std tensor([8.2176, 4.3773], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8309, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 639
# nlml -369414.6673882689
# err (0.008801741311278472-5.901773288240174e-19j)
# eps 8.738996008411755e-05
# base std tensor([8.2175, 4.3772], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8307, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 640
# nlml -369494.89746396197
# err (0.008795829747326974-5.895365407177143e-19j)
# eps 8.74203515373944e-05
# base std tensor([8.2175, 4.3773], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8309, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 641
# nlml -369537.2292474465
# err (0.008791904343595091-5.89669132784099e-19j)
# eps 8.743773053600953e-05
# base std tensor([8.2175, 4.3773], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 642
# nlml -369499.05948040774
# err (0.008793740041177896-5.895356444842616e-19j)
# eps 8.744543692760674e-05
# base std tensor([8.2174, 4.3773], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8309, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 643
# nlml -369512.59417254204
# err (0.008792633029113392-5.893784404152622e-19j)
# eps 8.744345799278838e-05
# base std tensor([8.2174, 4.3773], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 644
# nlml -369595.8057347138
# err (0.008787177056182816-5.892046662368566e-19j)
# eps 8.742608367232963e-05
# base std tensor([8.2175, 4.3773], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 645
# nlml -369551.33285117074
# err (0.0087903287951179-5.893779542690039e-19j)
# eps 8.739910317137584e-05
# base std tensor([8.2175, 4.3773], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8310, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 646
# nlml -369600.36002989206
# err (0.008785388997124912-5.889352216827519e-19j)
# eps 8.736093939006446e-05
# base std tensor([8.2174, 4.3773], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 647
# nlml -369614.1755045484
# err (0.008789160527347857-5.892563684572406e-19j)
# eps 8.73135431342841e-05
# base std tensor([8.2175, 4.3774], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 648
# nlml -369616.35408129287
# err (0.008786084711588496-5.891239491093376e-19j)
# eps 8.725986535529207e-05
# base std tensor([8.2175, 4.3774], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 649
# nlml -369648.5121240354
# err (0.008777689291919254-5.885515766719499e-19j)
# eps 8.720035385032096e-05
# base std tensor([8.2174, 4.3774], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 650
# nlml -369660.5989776901
# err (0.00878157956884647-5.885674198562293e-19j)
# eps 8.713738407322047e-05
# base std tensor([8.2175, 4.3774], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 651
# nlml -369669.6025519842
# err (0.008780201434199502-5.884204962091974e-19j)
# eps 8.707311706052888e-05
# base std tensor([8.2175, 4.3774], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 652
# nlml -369678.70998903544
# err (0.008778915718500658-5.883715741699993e-19j)
# eps 8.700994113947468e-05
# base std tensor([8.2175, 4.3775], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 653
# nlml -369689.8482272887
# err (0.008779073493124208-5.884491607745167e-19j)
# eps 8.694983589920296e-05
# base std tensor([8.2175, 4.3775], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 654
# nlml -369684.0577188378
# err (0.008780118268650881-5.885486041372323e-19j)
# eps 8.689547474744254e-05
# base std tensor([8.2175, 4.3775], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 655
# nlml -369667.3336238672
# err (0.008780958694173613-5.887097550466625e-19j)
# eps 8.684989348544787e-05
# base std tensor([8.2175, 4.3775], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 656
# nlml -369662.07296740485
# err (0.008779607724788108-5.883394516646082e-19j)
# eps 8.681496209992504e-05
# base std tensor([8.2175, 4.3775], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 657
# nlml -369696.62562792853
# err (0.008779446819153242-5.885681908228595e-19j)
# eps 8.678853799525292e-05
# base std tensor([8.2175, 4.3776], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 658
# nlml -369719.5218266053
# err (0.008777845211484801-5.883960665722529e-19j)
# eps 8.676925614136388e-05
# base std tensor([8.2175, 4.3776], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 659
# nlml -369713.7190967419
# err (0.00877548684521051-5.882523035751537e-19j)
# eps 8.675748467581482e-05
# base std tensor([8.2175, 4.3776], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 660
# nlml -369733.8277045784
# err (0.00877345530487169-5.879810911644266e-19j)
# eps 8.675210500074842e-05
# base std tensor([8.2175, 4.3777], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 661
# nlml -369717.816081175
# err (0.00877838591232458-5.883936707389225e-19j)
# eps 8.675420975362814e-05
# base std tensor([8.2175, 4.3777], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 662
# nlml -369710.1583646819
# err (0.008778475146211884-5.886295581065379e-19j)
# eps 8.67634841040379e-05
# base std tensor([8.2175, 4.3777], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8311, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 663
# nlml -369710.62752900284
# err (0.008778830012527624-5.8839022506509e-19j)
# eps 8.677870713612392e-05
# base std tensor([8.2175, 4.3777], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 664
# nlml -369681.77831140993
# err (0.008780837752700148-5.88576893250828e-19j)
# eps 8.68014583478348e-05
# base std tensor([8.2175, 4.3777], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 665
# nlml -369690.57699776
# err (0.00878311382929592-5.887935807569312e-19j)
# eps 8.68294301743857e-05
# base std tensor([8.2174, 4.3777], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 666
# nlml -369678.41647749173
# err (0.008779912678785893-5.883482638310341e-19j)
# eps 8.686186367225364e-05
# base std tensor([8.2174, 4.3777], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 667
# nlml -369709.50452788477
# err (0.008779264360917749-5.885218602669987e-19j)
# eps 8.689335480985414e-05
# base std tensor([8.2174, 4.3777], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 668
# nlml -369708.14352789597
# err (0.008778855450821847-5.883866157930973e-19j)
# eps 8.692296535589505e-05
# base std tensor([8.2174, 4.3776], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 669
# nlml -369709.5196389702
# err (0.008777915597198859-5.881839574958899e-19j)
# eps 8.694966692676677e-05
# base std tensor([8.2174, 4.3776], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 670
# nlml -369718.2463814447
# err (0.008777625392507385-5.884065912954095e-19j)
# eps 8.697191567836299e-05
# base std tensor([8.2174, 4.3776], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 671
# nlml -369727.94374065805
# err (0.008776388529856025-5.88279070715546e-19j)
# eps 8.698805108393897e-05
# base std tensor([8.2174, 4.3776], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 672
# nlml -369751.2852307739
# err (0.008773217200530573-5.879368887920575e-19j)
# eps 8.699585124417533e-05
# base std tensor([8.2174, 4.3776], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 673
# nlml -369763.07286201726
# err (0.008777876049669977-5.882554068274983e-19j)
# eps 8.69949820338374e-05
# base std tensor([8.2174, 4.3775], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 674
# nlml -369770.24351306725
# err (0.008774816421421364-5.878462390454353e-19j)
# eps 8.69857803830682e-05
# base std tensor([8.2174, 4.3775], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 675
# nlml -369777.4251137826
# err (0.00877081566559705-5.876604061533489e-19j)
# eps 8.696884931963174e-05
# base std tensor([8.2174, 4.3775], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 676
# nlml -369782.39845725463
# err (0.008774739599048304-5.880355299722652e-19j)
# eps 8.69457837879876e-05
# base std tensor([8.2174, 4.3775], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8314, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 677
# nlml -369788.6583975381
# err (0.008774162839507564-5.880379484591349e-19j)
# eps 8.69181165516527e-05
# base std tensor([8.2174, 4.3774], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 678
# nlml -369799.49356056773
# err (0.008771926954959895-5.878573043922805e-19j)
# eps 8.688692039893217e-05
# base std tensor([8.2174, 4.3774], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 679
# nlml -369784.01598062477
# err (0.008772345669877888-5.878127583137714e-19j)
# eps 8.685545616905348e-05
# base std tensor([8.2173, 4.3774], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8314, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 680
# nlml -369756.4622679834
# err (0.008771001408938318-5.876362472062198e-19j)
# eps 8.682782530132064e-05
# base std tensor([8.2174, 4.3774], device='cuda:0')
# min,max (tensor(-0.0272, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 681
# nlml -369710.76123511186
# err (0.008781507228588909-5.886163644707483e-19j)
# eps 8.680925656729478e-05
# base std tensor([8.2174, 4.3774], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 682
# nlml -369782.42901981657
# err (0.008773478673955374-5.878924614979025e-19j)
# eps 8.679356806186948e-05
# base std tensor([8.2174, 4.3775], device='cuda:0')
# min,max (tensor(-0.0272, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 683
# nlml -369786.4812282105
# err (0.008772876677661677-5.875242658278097e-19j)
# eps 8.678102685706237e-05
# base std tensor([8.2174, 4.3775], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 684
# nlml -369753.14830658474
# err (0.008776868262085501-5.882564400010075e-19j)
# eps 8.677498863386207e-05
# base std tensor([8.2174, 4.3775], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 685
# nlml -369723.1107716505
# err (0.008781445614480573-5.884958352178559e-19j)
# eps 8.677751241843372e-05
# base std tensor([8.2174, 4.3775], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 686
# nlml -369737.5377361469
# err (0.008777946400195483-5.880916987149266e-19j)
# eps 8.678633413145061e-05
# base std tensor([8.2174, 4.3775], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8312, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 687
# nlml -369798.0620231952
# err (0.008773854906633944-5.879922542064733e-19j)
# eps 8.67956301069072e-05
# base std tensor([8.2175, 4.3775], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 688
# nlml -369823.6672605591
# err (0.00877008536597846-5.876759175194915e-19j)
# eps 8.680260696344415e-05
# base std tensor([8.2175, 4.3775], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8314, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 689
# nlml -369837.67134335253
# err (0.008765933863418528-5.871843162475339e-19j)
# eps 8.680628533514923e-05
# base std tensor([8.2175, 4.3776], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8315, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 690
# nlml -369837.59625025245
# err (0.008766797553612331-5.87352373982584e-19j)
# eps 8.680703944580513e-05
# base std tensor([8.2175, 4.3776], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8314, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 691
# nlml -369853.59443818446
# err (0.008762392238707983-5.870321634085937e-19j)
# eps 8.680081336972018e-05
# base std tensor([8.2176, 4.3777], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8315, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 692
# nlml -369807.5701711526
# err (0.008763594765541706-5.87376411800613e-19j)
# eps 8.679314809445454e-05
# base std tensor([8.2176, 4.3778], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8315, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 693
# nlml -369740.7769375063
# err (0.008771539440349288-5.879137622771748e-19j)
# eps 8.679167561359213e-05
# base std tensor([8.2177, 4.3780], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8313, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 694
# nlml -369710.1397604814
# err (0.008774461363852147-5.883531774037967e-19j)
# eps 8.679815826325912e-05
# base std tensor([8.2177, 4.3781], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8314, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 695
# nlml -369749.5475773256
# err (0.008768685018570463-5.881113738222739e-19j)
# eps 8.680787008776469e-05
# base std tensor([8.2177, 4.3782], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8314, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 696
# nlml -369752.1711779216
# err (0.00877060468550223-5.878800421818564e-19j)
# eps 8.682045056199204e-05
# base std tensor([8.2177, 4.3782], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8314, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 697
# nlml -369750.1691065009
# err (0.008771931903941753-5.880804288835198e-19j)
# eps 8.683539831443896e-05
# base std tensor([8.2177, 4.3783], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8315, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 698
# nlml -369795.22233675385
# err (0.008765213662936222-5.877686860208039e-19j)
# eps 8.684794447187963e-05
# base std tensor([8.2177, 4.3782], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8316, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 699
# nlml -369848.39964386215
# err (0.008763183476240586-5.877664500912495e-19j)
# eps 8.685357879343698e-05
# base std tensor([8.2177, 4.3782], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8316, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 700
# nlml -369873.367938096
# err (0.008761921462215544-5.876837707963164e-19j)
# eps 8.685081414820892e-05
# base std tensor([8.2178, 4.3782], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8317, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 701
# nlml -369927.9403773837
# err (0.008753644457842838-5.868917465518756e-19j)
# eps 8.683584844615462e-05
# base std tensor([8.2178, 4.3782], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8317, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 702
# nlml -369976.6715226777
# err (0.008751706712080205-5.869218121656883e-19j)
# eps 8.680616282579291e-05
# base std tensor([8.2178, 4.3781], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8318, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 703
# nlml -370026.34985183674
# err (0.008749376198868751-5.865057576291798e-19j)
# eps 8.676062073690344e-05
# base std tensor([8.2178, 4.3781], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8320, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 704
# nlml -370075.96513352374
# err (0.00874344667598495-5.860417716733379e-19j)
# eps 8.66985282698392e-05
# base std tensor([8.2179, 4.3781], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8321, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 705
# nlml -370097.70177262597
# err (0.008737241926363359-5.856689026647767e-19j)
# eps 8.662168032565936e-05
# base std tensor([8.2179, 4.3781], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8322, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 706
# nlml -370100.3141498614
# err (0.008740239955574793-5.85921867924714e-19j)
# eps 8.653540190765382e-05
# base std tensor([8.2179, 4.3781], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8322, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 707
# nlml -370130.86052661785
# err (0.008735898862467577-5.8524869231062565e-19j)
# eps 8.644203900110724e-05
# base std tensor([8.2179, 4.3781], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8323, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 708
# nlml -370125.3002723802
# err (0.008737164331932102-5.859075808107573e-19j)
# eps 8.634714597309477e-05
# base std tensor([8.2179, 4.3781], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8323, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 709
# nlml -370115.66974479164
# err (0.008738413141540705-5.858078750563826e-19j)
# eps 8.625621496542257e-05
# base std tensor([8.2179, 4.3782], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8323, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 710
# nlml -370110.8810072205
# err (0.008741645201936021-5.860045841512818e-19j)
# eps 8.61736812076088e-05
# base std tensor([8.2179, 4.3783], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8322, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 711
# nlml -370137.2605666989
# err (0.00874188300169407-5.859282446798987e-19j)
# eps 8.610015844540501e-05
# base std tensor([8.2179, 4.3783], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8322, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 712
# nlml -370079.92821859615
# err (0.00874621676878513-5.862555420673994e-19j)
# eps 8.604307606462137e-05
# base std tensor([8.2179, 4.3784], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8322, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 713
# nlml -370090.95314169605
# err (0.00874781419224986-5.864228289193152e-19j)
# eps 8.600270067907361e-05
# base std tensor([8.2179, 4.3785], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8322, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 714
# nlml -370114.94459696696
# err (0.008736779336920174-5.859719865598314e-19j)
# eps 8.597685100310039e-05
# base std tensor([8.2179, 4.3786], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8323, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 715
# nlml -370011.1324912791
# err (0.008752740017985787-5.864778880311487e-19j)
# eps 8.59750609017019e-05
# base std tensor([8.2179, 4.3787], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8321, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 716
# nlml -370064.71110585897
# err (0.008742495576663624-5.863214196804987e-19j)
# eps 8.599011479050374e-05
# base std tensor([8.2179, 4.3787], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8322, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 717
# nlml -370164.20614388096
# err (0.00873828587915189-5.858145150528658e-19j)
# eps 8.601107368417038e-05
# base std tensor([8.2179, 4.3787], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8324, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 718
# nlml -370110.8843996999
# err (0.008742716181980787-5.860855659572604e-19j)
# eps 8.604068969834407e-05
# base std tensor([8.2179, 4.3788], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8322, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 719
# nlml -370177.48843203636
# err (0.008731192795795092-5.853343688597183e-19j)
# eps 8.607137469384779e-05
# base std tensor([8.2179, 4.3788], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8324, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 720
# nlml -370193.2214123292
# err (0.008740971274641374-5.860826688384764e-19j)
# eps 8.610015116446576e-05
# base std tensor([8.2179, 4.3788], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8324, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 721
# nlml -370207.30775921064
# err (0.008734421943700563-5.853714458118967e-19j)
# eps 8.612487618276376e-05
# base std tensor([8.2179, 4.3788], device='cuda:0')
# min,max (tensor(-0.0273, device='cuda:0'), tensor(0.8324, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 722
# nlml -370206.65048637806
# err (0.008737417052264981-5.860780528568701e-19j)
# eps 8.614510344371416e-05
# base std tensor([8.2180, 4.3788], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8324, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 723
# nlml -370187.21961924754
# err (0.0087349266574341-5.855650453878085e-19j)
# eps 8.616161237341239e-05
# base std tensor([8.2179, 4.3788], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 724
# nlml -370219.67466586904
# err (0.008730022275458424-5.85038482338886e-19j)
# eps 8.617125047491561e-05
# base std tensor([8.2179, 4.3788], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 725
# nlml -370204.0024790147
# err (0.008734969253314597-5.85812287628836e-19j)
# eps 8.61752873953721e-05
# base std tensor([8.2179, 4.3788], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 726
# nlml -370207.7911175632
# err (0.0087337736330162-5.85624361157304e-19j)
# eps 8.617378784352146e-05
# base std tensor([8.2179, 4.3788], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 727
# nlml -370268.2559825855
# err (0.008728512938070407-5.85370738018097e-19j)
# eps 8.616191754957379e-05
# base std tensor([8.2178, 4.3788], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 728
# nlml -370179.0670317167
# err (0.008733287609178193-5.856541535750661e-19j)
# eps 8.614880389205731e-05
# base std tensor([8.2178, 4.3788], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 729
# nlml -370210.33143413
# err (0.00873191846178032-5.854455330961102e-19j)
# eps 8.613231189227421e-05
# base std tensor([8.2178, 4.3788], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 730
# nlml -370258.9839418604
# err (0.008732689214101388-5.856095697705753e-19j)
# eps 8.610971903785287e-05
# base std tensor([8.2177, 4.3788], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 731
# nlml -370266.0360127626
# err (0.008729228152188647-5.854303980116666e-19j)
# eps 8.608208937102799e-05
# base std tensor([8.2177, 4.3788], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 732
# nlml -370295.6968624379
# err (0.00872927866087243-5.852422441050829e-19j)
# eps 8.604876910760781e-05
# base std tensor([8.2177, 4.3788], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 733
# nlml -370308.9120467228
# err (0.008728564545443728-5.851097115581916e-19j)
# eps 8.601094233918307e-05
# base std tensor([8.2176, 4.3788], device='cuda:0')
# min,max (tensor(-0.0278, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 734
# nlml -370322.7153328411
# err (0.00872535735559343-5.847624338917777e-19j)
# eps 8.596962369462369e-05
# base std tensor([8.2175, 4.3788], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 735
# nlml -370350.65187068575
# err (0.008725732679825108-5.848141082992115e-19j)
# eps 8.592478389017345e-05
# base std tensor([8.2175, 4.3788], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 736
# nlml -370358.4919675454
# err (0.008722759496476148-5.84704504093117e-19j)
# eps 8.587825034085763e-05
# base std tensor([8.2175, 4.3788], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 737
# nlml -370366.75017703045
# err (0.00872502322654584-5.847755453959489e-19j)
# eps 8.583197116410565e-05
# base std tensor([8.2174, 4.3788], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 738
# nlml -370373.2929064462
# err (0.008723701897311127-5.848122612380469e-19j)
# eps 8.578741739685397e-05
# base std tensor([8.2174, 4.3788], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8328, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 739
# nlml -370352.297068407
# err (0.008723624758044238-5.847609695440136e-19j)
# eps 8.574758176626747e-05
# base std tensor([8.2174, 4.3788], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 740
# nlml -370283.9851531307
# err (0.008731081430635602-5.854919527383676e-19j)
# eps 8.57201022167869e-05
# base std tensor([8.2174, 4.3789], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 741
# nlml -370257.40140915115
# err (0.008731372791090432-5.853002571250758e-19j)
# eps 8.570658424932382e-05
# base std tensor([8.2174, 4.3789], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 742
# nlml -370239.166301065
# err (0.008729818294818786-5.854773093420018e-19j)
# eps 8.570822560918731e-05
# base std tensor([8.2174, 4.3790], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 743
# nlml -370215.8152681529
# err (0.008735902858482107-5.858439854705937e-19j)
# eps 8.572465935559949e-05
# base std tensor([8.2174, 4.3790], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 744
# nlml -370184.01012041216
# err (0.008732301197087584-5.856974683000523e-19j)
# eps 8.575540398267288e-05
# base std tensor([8.2174, 4.3791], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 745
# nlml -370251.1554212243
# err (0.008732002891943482-5.853776137745778e-19j)
# eps 8.579312836467697e-05
# base std tensor([8.2174, 4.3791], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 746
# nlml -370286.14917206543
# err (0.008727572499216135-5.850307127312865e-19j)
# eps 8.58322409575959e-05
# base std tensor([8.2174, 4.3792], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 747
# nlml -370287.38451606693
# err (0.00872726097077209-5.849505612943831e-19j)
# eps 8.587057467366392e-05
# base std tensor([8.2174, 4.3792], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 748
# nlml -370287.0339369728
# err (0.008728230092487304-5.848162586382512e-19j)
# eps 8.590669561552696e-05
# base std tensor([8.2174, 4.3792], device='cuda:0')
# min,max (tensor(-0.0274, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 749
# nlml -370324.226786616
# err (0.008724897651793252-5.849061068849926e-19j)
# eps 8.593584047433643e-05
# base std tensor([8.2174, 4.3792], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 750
# nlml -370336.2102976529
# err (0.008728136120639702-5.850098965896014e-19j)
# eps 8.595631177335689e-05
# base std tensor([8.2174, 4.3792], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 751
# nlml -370351.82402564917
# err (0.0087273791700871-5.847388399941075e-19j)
# eps 8.596686912365729e-05
# base std tensor([8.2173, 4.3793], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 752
# nlml -370356.89731515304
# err (0.008728364229635804-5.84844519384722e-19j)
# eps 8.596763464630813e-05
# base std tensor([8.2173, 4.3792], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8328, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 753
# nlml -370349.65651632997
# err (0.00872501227850816-5.847737779991104e-19j)
# eps 8.596007001589118e-05
# base std tensor([8.2173, 4.3792], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 754
# nlml -370360.8499834333
# err (0.008726992216923779-5.849187817591798e-19j)
# eps 8.594491758452343e-05
# base std tensor([8.2172, 4.3792], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 755
# nlml -370297.4797902151
# err (0.00873159010325776-5.853275429891983e-19j)
# eps 8.592988285753194e-05
# base std tensor([8.2172, 4.3792], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 756
# nlml -370329.52735317266
# err (0.008726712339787345-5.848149924080693e-19j)
# eps 8.591296972613346e-05
# base std tensor([8.2171, 4.3791], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 757
# nlml -370301.82284941146
# err (0.008729040546157906-5.851599096866108e-19j)
# eps 8.589762430370127e-05
# base std tensor([8.2171, 4.3791], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 758
# nlml -370281.1668136768
# err (0.008732108153232521-5.854227254503924e-19j)
# eps 8.588661379293924e-05
# base std tensor([8.2171, 4.3790], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 759
# nlml -370233.4344569778
# err (0.00873339805172824-5.855222447981018e-19j)
# eps 8.588444292872363e-05
# base std tensor([8.2170, 4.3790], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 760
# nlml -370234.8522351834
# err (0.008734157494651226-5.855909256305682e-19j)
# eps 8.589002539536778e-05
# base std tensor([8.2170, 4.3790], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 761
# nlml -370264.92772678554
# err (0.00873386816550566-5.855348625231988e-19j)
# eps 8.589970015160211e-05
# base std tensor([8.2170, 4.3789], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8325, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 762
# nlml -370309.1934863704
# err (0.008730830061977583-5.851662424885701e-19j)
# eps 8.59087706541564e-05
# base std tensor([8.2169, 4.3789], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8326, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 763
# nlml -370362.09709860926
# err (0.008728785977239542-5.851548376857697e-19j)
# eps 8.59120049200022e-05
# base std tensor([8.2168, 4.3789], device='cuda:0')
# min,max (tensor(-0.0275, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 764
# nlml -370382.1594416343
# err (0.008725849710338757-5.848721338782093e-19j)
# eps 8.590825576560399e-05
# base std tensor([8.2168, 4.3789], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8327, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 765
# nlml -370396.0988531246
# err (0.008723280958225926-5.845780125411517e-19j)
# eps 8.589716259731106e-05
# base std tensor([8.2167, 4.3788], device='cuda:0')
# min,max (tensor(-0.0276, device='cuda:0'), tensor(0.8328, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 766
# nlml -370419.2228313818
# err (0.008723663759888213-5.846064737208421e-19j)
# eps 8.587779353775815e-05
# base std tensor([8.2167, 4.3788], device='cuda:0')
# min,max (tensor(-0.0277, device='cuda:0'), tensor(0.8328, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 767
# nlml -370412.8665390402
# ...
# eps 8.480518086601548e-05
# base std tensor([8.2124, 4.3814], device='cuda:0')
# min,max (tensor(-0.0270, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 240
# nlml -371204.85021642875
# err (0.00869445685136846-5.823918963511431e-19j)
# eps 8.480303729245337e-05
# base std tensor([8.2124, 4.3814], device='cuda:0')
# min,max (tensor(-0.0270, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 241
# nlml -371205.2575015414
# err (0.008694377977885841-5.823887940116649e-19j)
# eps 8.480073864925457e-05
# base std tensor([8.2124, 4.3814], device='cuda:0')
# min,max (tensor(-0.0270, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 242
# nlml -371205.853200034
# err (0.008694453294574777-5.823879959014102e-19j)
# eps 8.479849152666381e-05
# base std tensor([8.2124, 4.3814], device='cuda:0')
# min,max (tensor(-0.0270, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 243
# nlml -371206.2254119562
# err (0.008694528667182372-5.823820449740098e-19j)
# eps 8.479651339561138e-05
# base std tensor([8.2124, 4.3814], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 244
# nlml -371206.6996096698
# err (0.008694490456998955-5.823871422494147e-19j)
# eps 8.479497560852347e-05
# base std tensor([8.2124, 4.3815], device='cuda:0')
# min,max (tensor(-0.0270, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 245
# nlml -371207.07152562216
# err (0.008694472407533047-5.823872759305487e-19j)
# eps 8.479402343599749e-05
# base std tensor([8.2124, 4.3815], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 246
# nlml -371207.4504053549
# err (0.00869463594292555-5.8241052931884885e-19j)
# eps 8.479361930403454e-05
# base std tensor([8.2124, 4.3815], device='cuda:0')
# min,max (tensor(-0.0270, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 247
# nlml -371207.850846487
# err (0.008694446233578637-5.823655839595964e-19j)
# eps 8.479376867115419e-05
# base std tensor([8.2124, 4.3815], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 248
# nlml -371208.20985845017
# err (0.008694674565894093-5.824342166618726e-19j)
# eps 8.479431584822255e-05
# base std tensor([8.2124, 4.3815], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 249
# nlml -371208.7656373845
# err (0.008694538159553943-5.8235367162399e-19j)
# eps 8.479512860317815e-05
# base std tensor([8.2124, 4.3815], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 250
# nlml -371208.7395010537
# err (0.008694663819555902-5.824474772998416e-19j)
# eps 8.479603069375278e-05
# base std tensor([8.2124, 4.3815], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 251
# nlml -371209.0693900281
# err (0.008694613177960012-5.823644596801864e-19j)
# eps 8.479694781474179e-05
# base std tensor([8.2124, 4.3815], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 252
# nlml -371210.354025407
# err (0.008694377832817811-5.824063981108037e-19j)
# eps 8.479748435470053e-05
# base std tensor([8.2124, 4.3815], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 253
# nlml -371211.57491542044
# err (0.008694674632412486-5.824051559927944e-19j)
# eps 8.479738176707369e-05
# base std tensor([8.2124, 4.3816], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 254
# nlml -371211.6265706372
# err (0.00869444648035675-5.823615163681167e-19j)
# eps 8.479676473369701e-05
# base std tensor([8.2124, 4.3816], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 255
# nlml -371212.0435748746
# err (0.008694695827980641-5.8242541587819935e-19j)
# eps 8.479567962250743e-05
# base std tensor([8.2124, 4.3816], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 256
# nlml -371213.6681782649
# err (0.00869455253860937-5.823699909499733e-19j)
# eps 8.479403432251963e-05
# base std tensor([8.2124, 4.3816], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 257
# nlml -371214.02010165213
# err (0.008694459147910954-5.823927188787615e-19j)
# eps 8.479197886123928e-05
# base std tensor([8.2124, 4.3816], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 258
# nlml -371214.27947766957
# err (0.00869447128713007-5.823962625750111e-19j)
# eps 8.478987769032724e-05
# base std tensor([8.2124, 4.3816], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 259
# nlml -371215.22147116426
# err (0.008694320613573723-5.823714183283291e-19j)
# eps 8.478779883878786e-05
# base std tensor([8.2124, 4.3816], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 260
# nlml -371216.0868964298
# err (0.00869454354672748-5.823857207954073e-19j)
# eps 8.47858723323849e-05
# base std tensor([8.2124, 4.3816], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 261
# nlml -371216.51678422926
# err (0.008694395342025216-5.823880176966055e-19j)
# eps 8.478428771353635e-05
# base std tensor([8.2124, 4.3817], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 262
# nlml -371217.6446938361
# err (0.008694299859752674-5.823691845153687e-19j)
# eps 8.478298850782548e-05
# base std tensor([8.2124, 4.3817], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 263
# nlml -371217.9866238331
# err (0.008694371818102595-5.823753317894573e-19j)
# eps 8.478211255642173e-05
# base std tensor([8.2124, 4.3817], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 264
# nlml -371218.45423800166
# err (0.008694344183356356-5.82396177101091e-19j)
# eps 8.478165339391448e-05
# base std tensor([8.2124, 4.3817], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 265
# nlml -371219.13290827366
# err (0.008694317481892302-5.8236135544285545e-19j)
# eps 8.478156386497159e-05
# base std tensor([8.2124, 4.3817], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 266
# nlml -371219.9200723239
# err (0.008694330287420723-5.823819586921244e-19j)
# eps 8.478164217428995e-05
# base std tensor([8.2124, 4.3817], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 267
# nlml -371220.3516041711
# err (0.008694321865178314-5.823840425210512e-19j)
# eps 8.478184162870805e-05
# base std tensor([8.2124, 4.3817], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 268
# nlml -371221.03781661286
# err (0.008694421951703377-5.823782038279088e-19j)
# eps 8.478198885397615e-05
# base std tensor([8.2124, 4.3817], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 269
# nlml -371221.5102374034
# err (0.008694290415841004-5.82366952545672e-19j)
# eps 8.47820022459015e-05
# base std tensor([8.2124, 4.3817], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 270
# nlml -371221.985726842
# err (0.008694563530551383-5.823918647725393e-19j)
# eps 8.47818797818913e-05
# base std tensor([8.2124, 4.3818], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 271
# nlml -371222.8492934489
# err (0.008694336447246242-5.823799228725445e-19j)
# eps 8.47814092180665e-05
# base std tensor([8.2124, 4.3818], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 272
# nlml -371223.69427490514
# err (0.008694378668947263-5.823591435783209e-19j)
# eps 8.478061556174582e-05
# base std tensor([8.2124, 4.3818], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 273
# nlml -371224.2712888715
# err (0.008694442795029738-5.824009542569532e-19j)
# eps 8.477952346670103e-05
# base std tensor([8.2124, 4.3818], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 274
# nlml -371224.93990718573
# err (0.00869429794945693-5.823526781960796e-19j)
# eps 8.47782120693066e-05
# base std tensor([8.2124, 4.3818], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 275
# nlml -371225.51041901007
# err (0.008694351129804078-5.823819432164652e-19j)
# eps 8.477680221544504e-05
# base std tensor([8.2124, 4.3818], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 276
# nlml -371225.95620616927
# err (0.008694273721747196-5.82373419822091e-19j)
# eps 8.477546127403722e-05
# base std tensor([8.2124, 4.3818], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 277
# nlml -371226.30050105206
# err (0.008694405675268222-5.823665338808757e-19j)
# eps 8.477436230067926e-05
# base std tensor([8.2124, 4.3818], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 278
# nlml -371227.0712817794
# err (0.008694183571115744-5.823768566017028e-19j)
# eps 8.477344982149317e-05
# base std tensor([8.2124, 4.3818], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 279
# nlml -371227.9227936629
# err (0.00869437856385413-5.823581077100769e-19j)
# eps 8.477272538782372e-05
# base std tensor([8.2124, 4.3819], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 280
# nlml -371228.84891086083
# err (0.008694308923037292-5.8238200262740785e-19j)
# eps 8.477206287224069e-05
# base std tensor([8.2124, 4.3819], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 281
# nlml -371229.4806515438
# err (0.008694192369776258-5.823544656880881e-19j)
# eps 8.477144222994191e-05
# base std tensor([8.2124, 4.3819], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 282
# nlml -371230.0166854743
# err (0.00869436075093843-5.823787499195225e-19j)
# eps 8.477089453349451e-05
# base std tensor([8.2124, 4.3819], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 283
# nlml -371230.45984051854
# err (0.00869421727424395-5.823577979730315e-19j)
# eps 8.477047698201074e-05
# base std tensor([8.2124, 4.3819], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 284
# nlml -371230.9659274766
# err (0.008694356047701796-5.823836988210114e-19j)
# eps 8.477011755757427e-05
# base std tensor([8.2124, 4.3819], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 285
# nlml -371231.64606184047
# err (0.008694212491921531-5.823523099555669e-19j)
# eps 8.47698536631142e-05
# base std tensor([8.2124, 4.3819], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 286
# nlml -371232.313359459
# err (0.008694524831288993-5.823925338337172e-19j)
# eps 8.47695482209704e-05
# base std tensor([8.2124, 4.3819], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 287
# nlml -371232.9066877159
# err (0.00869430701110771-5.82368541889171e-19j)
# eps 8.476922074794981e-05
# base std tensor([8.2124, 4.3819], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 288
# nlml -371233.8031116265
# err (0.008694277126878201-5.823722255258047e-19j)
# eps 8.476855265632463e-05
# base std tensor([8.2124, 4.3820], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 289
# nlml -371234.108341357
# err (0.008694693092276343-5.823852928633928e-19j)
# eps 8.476763829008913e-05
# base std tensor([8.2124, 4.3820], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 290
# nlml -371234.1618666068
# err (0.008694152871425559-5.823614341977482e-19j)
# eps 8.476657432814783e-05
# base std tensor([8.2124, 4.3820], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 291
# nlml -371235.0509916189
# err (0.008694408914894956-5.8236735404749095e-19j)
# eps 8.476525175197263e-05
# base std tensor([8.2124, 4.3820], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 292
# nlml -371235.51702612126
# err (0.00869434564349189-5.823774538271287e-19j)
# eps 8.476388583691901e-05
# base std tensor([8.2124, 4.3820], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 293
# nlml -371236.2508167628
# err (0.008694224610974927-5.823675917604162e-19j)
# eps 8.476243969080364e-05
# base std tensor([8.2124, 4.3820], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 294
# nlml -371236.828502379
# err (0.008694109933242645-5.823348383732164e-19j)
# eps 8.476111044194367e-05
# base std tensor([8.2124, 4.3820], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 295
# nlml -371237.8820853764
# err (0.008694288710972295-5.823798233449223e-19j)
# eps 8.475979589484599e-05
# base std tensor([8.2124, 4.3820], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 296
# nlml -371238.5465703327
# err (0.008694261812300055-5.823518077496899e-19j)
# eps 8.47586792419181e-05
# base std tensor([8.2124, 4.3820], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 297
# nlml -371239.0990291166
# err (0.008694259530373158-5.82356191492141e-19j)
# eps 8.475773812190389e-05
# base std tensor([8.2124, 4.3820], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 298
# nlml -371239.70564611827
# err (0.00869434933544155-5.82387541924016e-19j)
# eps 8.475692758440099e-05
# base std tensor([8.2124, 4.3821], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 299
# nlml -371239.78087500506
# err (0.008694290566057415-5.823445873862365e-19j)
# eps 8.475645105580973e-05
# base std tensor([8.2123, 4.3821], device='cuda:0')
# min,max (tensor(-0.0269, device='cuda:0'), tensor(0.8333, device='cuda:0'))

# %%
st = torch.load("state.pt")
MC_base = st['MC_base']
S_diag = st['S_diag']
eps = st['eps']
# Prediction
#Phi_ = Phi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
#PhiX = Phi(MC_base * 1.j, X.to("cpu"))
#A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
#LA = torch.linalg.cholesky(A)
#alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to(torch.complex128).to("cpu"), upper=False)
#pred = Phi_.H @ torch.linalg.solve_triangular(LA.H, alpha, upper=True)
#pred = pred.real


#pred.detach().cpu().numpy().tofile("pred.dat")
#axis.cpu().numpy().tofile("axis.dat")
#time.cpu().numpy().tofile("time.dat")

# %%
# Prediction
#Phi_ = Phi(MC_base * 1.j, Ps.to(torch.complex128)).to(device)
#Phi_ = Phi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#dtPhi_ = dtPhi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#dxPhi_ = dxPhi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#dyPhi_ = dyPhi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
#Phi_ = torch.cat((Phi_,dtPhi_,dxPhi_,dyPhi_),1)
#Phi_ = torch.cat((Phi_,dtPhi_),1)
PhiX = Phi(MC_base * 1.j, X.to("cpu"))
#dtPhiX = dtPhi(MC_base * 1.j, dtX.to("cpu"))
dxPhiX = dxPhi(MC_base * 1.j, dxX.to("cpu"))
dyPhiX = dyPhi(MC_base * 1.j, dyX.to("cpu"))
PhiX = torch.cat((PhiX,dxPhiX,dyPhiX),1)
#PhiX = torch.cat((PhiX,dtPhiX),1)
A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
LA = torch.linalg.cholesky(A)
alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to("cpu").to(torch.complex128), upper=False)
Phi_ = Phi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
predwave = Phi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
predwave = predwave.real
predwave.detach().cpu().numpy().tofile("predwave.dat")
del Phi_, predwave
dtPhi_ = dtPhi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
preddt = dtPhi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
preddt = preddt.real
preddt.detach().cpu().numpy().tofile("preddt.dat")
del dtPhi_, preddt
dxPhi_ = dxPhi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
preddx = dxPhi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
preddx = preddx.real
preddx.detach().cpu().numpy().tofile("preddx.dat")
del dxPhi_, preddx
dyPhi_ = dyPhi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
preddy = dyPhi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
preddy = preddy.real
preddy.detach().cpu().numpy().tofile("preddy.dat")
del dyPhi_, preddy

#predwave.detach().cpu().numpy().tofile("predwave.dat")
#preddt.detach().cpu().numpy().tofile("preddt.dat")
#preddx.detach().cpu().numpy().tofile("preddx.dat")
#preddy.detach().cpu().numpy().tofile("preddy.dat")
axis.cpu().numpy().tofile("axis.dat")
time.cpu().numpy().tofile("time.dat")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-bc6fe4b0cf69> in <cell line: 17>()
#      15 A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
#      16 LA = torch.linalg.cholesky(A)
# ---> 17 alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to("cpu").to(torch.complex128), upper=False)
#      18 Phi_ = Phi(MC_base * 1.j, Ps.to(torch.complex128).to("cpu"))
#      19 predwave = Phi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1000x40401 and 89445x1)

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !cp predwave.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp preddt.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp preddx.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp preddy.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp axis.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp time.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp state.pt "/content/drive/MyDrive/Colab Notebooks"

# %%
PhiX.shape
