# %% [markdown]
# # Mount with Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Main part

# %%
## Imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import pandas as pd
import math

# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# torch.set_default_dtype(torch.float32)
torch.set_default_dtype(torch.float64)
torch.manual_seed(13)



# Sampling parameters etc
#n_axis = 51
n_axis = 41
#n_time = 131
n_time = 81

axis = torch.linspace(-2,2,n_axis, device=device)
time = torch.linspace(0,4,n_time, device=device)
Ps = torch.cartesian_prod(axis,axis,time)
# Number of points
lP = Ps.shape[0]


# Initial dataset
data_axis = torch.linspace(-5,5, 101, device=device)
data_time = torch.linspace(0,0,1, device=device)
data_Ps = torch.cartesian_prod(data_axis,data_axis,time)

mask = data_Ps[:,2] == 0.
X = data_Ps[mask]
dX = data_Ps[mask]

Y = torch.exp(-(X[:,0]-1)**2*5)+torch.exp(-(X[:,1]-1)**2*5)
#Y = torch.cos((X[:,0]-1)*5)+torch.cos((X[:,1]-1)*5)
Y = Y.view(-1,1)

dY = -2*5*(X[:,0]-1)*torch.exp(-(X[:,0]-1)**2*5)-2*5*(X[:,1]-1)*torch.exp(-(X[:,1]-1)**2*5)
#dtY = -5*(torch.sin((X[:,0]-1)*5)+torch.sin((X[:,1]-1)*5))
dY = dY.view(-1,1)

dX = dX.to(torch.complex128)
dY = dY.to(torch.complex128)
X = X.to(torch.complex128)
Y = Y.to(torch.complex128)
Y = torch.cat((Y,dY),0)
# Out:
# Using cuda device

# %%
Y.shape
# Out:
# torch.Size([20402, 1])

# %%
def getVarietyPoints(base1,base2):
    x1,y1 = base1.unbind(1)
    x2,y2 = base2.unbind(1)
    t1 = torch.sqrt(x1.square() + y1.square())
    t2 = torch.sqrt(x2.square() + y2.square())

    return torch.stack([ torch.stack([x1,y1,t1],1), torch.stack([x2,y2,-t2],1) ])

def Phi(base1, base2, X):
    pts = getVarietyPoints(base1, base2)
    # return (pts.inner(X) * 1.j).exp().mean(0)
    return (pts.inner(X)).exp().mean(0)

def dPhi(base1, base2, X):
    pts = getVarietyPoints(base1, base2)
    return ((pts.inner(X)).exp().mul(pts[:,:,2].unsqueeze(2).repeat(1, 1, pts.inner(X).shape[2])).mean(0))


def train(N):
    for epoch in range(N):
        PhiX = Phi(MC_base1 * 1.j, MC_base2 * 1.j, X)
        dPhiX = dPhi(MC_base1 * 1.j, MC_base2 * 1.j, dX)
        PhiX = torch.cat((PhiX,dPhiX),1)
        A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
        LA = torch.linalg.cholesky(A)
        alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to(torch.complex128), upper=False)

        nlml = 1/(2*eps.exp()) * (Y.norm().square() - alpha.norm().square())
        nlml += (PhiX.shape[1] - PhiX.shape[0])/2 * eps
        nlml += LA.diag().real.log().sum()
        nlml += 0.5*S_diag.sum()

        opt.zero_grad()
        nlml.backward()
        opt.step()

        with torch.no_grad():
            train_pred = PhiX.H @ torch.linalg.solve_triangular(LA.H, alpha, upper=True)
            err = (train_pred.real - Y).square().mean().sqrt()
            print(26*"~" + f'\nepoch {epoch}\n\
nlml {nlml}\n\
err {err}\n\
eps {eps.exp()}\n\
base1 std {MC_base1.std(0)}\n\
base2 std {MC_base2.std(0)}\n\
min,max {train_pred.real.min().detach(),train_pred.real.max().detach()}')

# %%
n_MC = 1000
# MC_axis = torch.linspace(-1,1, n_MC, device=device) * 30
MC_base1 = (torch.randn((n_MC, 2), device=device)).requires_grad_()
MC_base2 = (torch.randn((n_MC, 2), device=device)).requires_grad_()
# MC_base = torch.cartesian_prod(MC_axis,MC_axis).requires_grad_()
S_diag = torch.full((n_MC,), -np.log(n_MC), requires_grad=False, device=device)
# S_diag = torch.full((n_MC**2,), -np.log(n_MC**2), requires_grad=False, device=device)
eps = torch.tensor(np.log(1e-2), requires_grad=True, device=device)

# %%
opt = torch.optim.Adam([
    {'params': [MC_base1, MC_base2], 'lr': 1e-1},
    {'params': eps, 'lr': 1e-2}])
#train(100000)
train(10000)
opt = torch.optim.Adam([
    {'params': [MC_base1, MC_base2], 'lr': 1e-1},
    {'params': eps, 'lr': 1e-2}])
#train(100000)
train(10000)
opt = torch.optim.Adam([
    {'params': [MC_base1, MC_base2], 'lr': 1e-2},
    {'params': [S_diag, eps], 'lr': 1e-2}])
train(1000)
opt = torch.optim.Adam([
    {'params': [MC_base1, MC_base2], 'lr': 1e-3},
    {'params': [S_diag, eps], 'lr': 1e-3}])
train(300)
torch.save({
            'MC_base1': MC_base1.cpu(),
            'MC_base2': MC_base2.cpu(),
            'S_diag': S_diag.cpu(),
            'eps': eps.cpu(),
    }, "state.pt")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 675
# nlml -157844.498029329
# err (8.456739294741224e-05-5.162760732467117e-21j)
# eps 6.740587636175404e-08
# base1 std tensor([3.8158, 3.9239], device='cuda:0')
# base2 std tensor([3.3336, 3.2022], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 676
# nlml -156639.2629832614
# err (0.00010659666098613564-6.483074407168369e-21j)
# eps 6.677201494258897e-08
# base1 std tensor([3.8159, 3.9239], device='cuda:0')
# base2 std tensor([3.3337, 3.2022], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8262, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 677
# nlml -157411.76642251867
# err (9.298103643603217e-05-5.6774296373928096e-21j)
# eps 6.61490448380047e-08
# base1 std tensor([3.8160, 3.9239], device='cuda:0')
# base2 std tensor([3.3338, 3.2022], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 678
# nlml -157026.3447385601
# err (0.0001002946087736168-6.1195707037626565e-21j)
# eps 6.553961276001368e-08
# base1 std tensor([3.8160, 3.9239], device='cuda:0')
# base2 std tensor([3.3339, 3.2022], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8262, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 679
# nlml -157149.76481750864
# err (9.882723378034246e-05-6.005661041285117e-21j)
# eps 6.494232876253772e-08
# base1 std tensor([3.8161, 3.9239], device='cuda:0')
# base2 std tensor([3.3340, 3.2021], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 680
# nlml -157711.49021263854
# err (9.155507701519507e-05-5.590361661429483e-21j)
# eps 6.435292564408061e-08
# base1 std tensor([3.8161, 3.9239], device='cuda:0')
# base2 std tensor([3.3341, 3.2021], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 681
# nlml -157667.81376182655
# err (9.54869706195616e-05-5.853144084695396e-21j)
# eps 6.377194701648579e-08
# base1 std tensor([3.8161, 3.9239], device='cuda:0')
# base2 std tensor([3.3342, 3.2021], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 682
# nlml -157845.0103670886
# err (9.285040501978959e-05-5.6731946675307726e-21j)
# eps 6.319829822070803e-08
# base1 std tensor([3.8161, 3.9239], device='cuda:0')
# base2 std tensor([3.3343, 3.2021], device='cuda:0')
# min,max (tensor(-3.8262, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 683
# nlml -157908.00992616918
# err (9.251902717310867e-05-5.700982237007778e-21j)
# eps 6.263180810796373e-08
# base1 std tensor([3.8161, 3.9239], device='cuda:0')
# base2 std tensor([3.3344, 3.2020], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 684
# nlml -158241.6986144829
# err (8.778726213732604e-05-5.371231301298981e-21j)
# eps 6.20704492104886e-08
# base1 std tensor([3.8161, 3.9239], device='cuda:0')
# base2 std tensor([3.3344, 3.2019], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 685
# nlml -158445.42140129692
# err (8.566432664025919e-05-5.2287340176169956e-21j)
# eps 6.151334493876683e-08
# base1 std tensor([3.8160, 3.9239], device='cuda:0')
# base2 std tensor([3.3344, 3.2019], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 686
# nlml -158563.9910577284
# err (8.576662151502973e-05-5.24133439996437e-21j)
# eps 6.096031835026467e-08
# base1 std tensor([3.8160, 3.9239], device='cuda:0')
# base2 std tensor([3.3344, 3.2019], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 687
# nlml -158618.09284747636
# err (8.52364938251713e-05-5.211835652972047e-21j)
# eps 6.041164367745318e-08
# base1 std tensor([3.8160, 3.9239], device='cuda:0')
# base2 std tensor([3.3344, 3.2019], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 688
# nlml -158673.35312635105
# err (8.526375302421669e-05-5.1968994864857425e-21j)
# eps 5.986754559598336e-08
# base1 std tensor([3.8161, 3.9239], device='cuda:0')
# base2 std tensor([3.3344, 3.2018], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 689
# nlml -158839.92204526407
# err (8.472983536994837e-05-5.1858127062874705e-21j)
# eps 5.932750368317154e-08
# base1 std tensor([3.8161, 3.9238], device='cuda:0')
# base2 std tensor([3.3344, 3.2018], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 690
# nlml -159012.50188516636
# err (8.34390659269047e-05-5.091721199573131e-21j)
# eps 5.879101302383296e-08
# base1 std tensor([3.8161, 3.9238], device='cuda:0')
# base2 std tensor([3.3344, 3.2018], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 691
# nlml -159098.48837211792
# err (8.331675134510655e-05-5.069871105897633e-21j)
# eps 5.825819457702949e-08
# base1 std tensor([3.8161, 3.9237], device='cuda:0')
# base2 std tensor([3.3344, 3.2017], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 692
# nlml -159166.44147665775
# err (8.342710743337125e-05-5.085374480268981e-21j)
# eps 5.772928308413134e-08
# base1 std tensor([3.8162, 3.9237], device='cuda:0')
# base2 std tensor([3.3343, 3.2017], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 693
# nlml -159343.5391284044
# err (8.152766912323759e-05-4.965460715280036e-21j)
# eps 5.720380523214253e-08
# base1 std tensor([3.8162, 3.9237], device='cuda:0')
# base2 std tensor([3.3343, 3.2017], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 694
# nlml -159402.9972933507
# err (8.171758126103758e-05-4.975397849136918e-21j)
# eps 5.668207176629971e-08
# base1 std tensor([3.8162, 3.9237], device='cuda:0')
# base2 std tensor([3.3343, 3.2016], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 695
# nlml -159492.74538545503
# err (8.095446657796834e-05-4.948434950210771e-21j)
# eps 5.6164171041649924e-08
# base1 std tensor([3.8163, 3.9236], device='cuda:0')
# base2 std tensor([3.3343, 3.2016], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 696
# nlml -159587.33075917952
# err (8.080663134084648e-05-4.940600278081885e-21j)
# eps 5.5650158695884804e-08
# base1 std tensor([3.8164, 3.9236], device='cuda:0')
# base2 std tensor([3.3342, 3.2016], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 697
# nlml -159659.99170428098
# err (8.133038985562068e-05-4.967568397265071e-21j)
# eps 5.514020300887297e-08
# base1 std tensor([3.8164, 3.9236], device='cuda:0')
# base2 std tensor([3.3342, 3.2016], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 698
# nlml -159624.86259405862
# err (8.30106319946139e-05-5.0814233679119225e-21j)
# eps 5.463510062616903e-08
# base1 std tensor([3.8165, 3.9236], device='cuda:0')
# base2 std tensor([3.3342, 3.2015], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 699
# nlml -159633.9316772997
# err (8.222511531712262e-05-5.0408421187953305e-21j)
# eps 5.413527391545006e-08
# base1 std tensor([3.8166, 3.9235], device='cuda:0')
# base2 std tensor([3.3342, 3.2014], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 700
# nlml -159866.68040200212
# err (8.045018507263576e-05-4.919290222769988e-21j)
# eps 5.363975638925064e-08
# base1 std tensor([3.8167, 3.9235], device='cuda:0')
# base2 std tensor([3.3342, 3.2014], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 701
# nlml -160048.4158864058
# err (7.829997216593905e-05-4.7832308084093235e-21j)
# eps 5.314801153018858e-08
# base1 std tensor([3.8167, 3.9235], device='cuda:0')
# base2 std tensor([3.3341, 3.2013], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 702
# nlml -160054.9899885904
# err (7.951483898233595e-05-4.856331023840389e-21j)
# eps 5.2660582059653304e-08
# base1 std tensor([3.8168, 3.9235], device='cuda:0')
# base2 std tensor([3.3341, 3.2012], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 703
# nlml -160199.78212449513
# err (7.906522156648135e-05-4.818467721414858e-21j)
# eps 5.2177137033537494e-08
# base1 std tensor([3.8169, 3.9235], device='cuda:0')
# base2 std tensor([3.3341, 3.2012], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 704
# nlml -160308.00727146602
# err (7.773735935070683e-05-4.741712801915889e-21j)
# eps 5.169760223375085e-08
# base1 std tensor([3.8170, 3.9235], device='cuda:0')
# base2 std tensor([3.3341, 3.2011], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 705
# nlml -160240.14339113835
# err (8.047107649432472e-05-4.898989958024001e-21j)
# eps 5.1222888183571825e-08
# base1 std tensor([3.8170, 3.9235], device='cuda:0')
# base2 std tensor([3.3340, 3.2010], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 706
# nlml -160414.58729782805
# err (7.868525865987729e-05-4.805636129638447e-21j)
# eps 5.0752437524505334e-08
# base1 std tensor([3.8171, 3.9235], device='cuda:0')
# base2 std tensor([3.3340, 3.2010], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 707
# nlml -160574.397503106
# err (7.723509480597882e-05-4.7099748465316005e-21j)
# eps 5.028585035120701e-08
# base1 std tensor([3.8171, 3.9234], device='cuda:0')
# base2 std tensor([3.3340, 3.2009], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 708
# nlml -160571.39462726383
# err (7.872614872513281e-05-4.80034301877772e-21j)
# eps 4.982366046517429e-08
# base1 std tensor([3.8171, 3.9234], device='cuda:0')
# base2 std tensor([3.3339, 3.2009], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 709
# nlml -160758.30413154987
# err (7.675949551905003e-05-4.6766657464611696e-21j)
# eps 4.936528759904649e-08
# base1 std tensor([3.8172, 3.9234], device='cuda:0')
# base2 std tensor([3.3339, 3.2008], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 710
# nlml -160775.64194958052
# err (7.769055772825796e-05-4.738406002963808e-21j)
# eps 4.8911141332405125e-08
# base1 std tensor([3.8172, 3.9234], device='cuda:0')
# base2 std tensor([3.3338, 3.2007], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 711
# nlml -160893.41672204412
# err (7.712108402225487e-05-4.707533146109899e-21j)
# eps 4.8461051542905456e-08
# base1 std tensor([3.8173, 3.9234], device='cuda:0')
# base2 std tensor([3.3338, 3.2006], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 712
# nlml -160993.5476952597
# err (7.681794288803479e-05-4.686053515469802e-21j)
# eps 4.80149693965833e-08
# base1 std tensor([3.8173, 3.9234], device='cuda:0')
# base2 std tensor([3.3338, 3.2005], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 713
# nlml -161081.06686346067
# err (7.677758165885698e-05-4.6779270970452234e-21j)
# eps 4.757290218746669e-08
# base1 std tensor([3.8174, 3.9234], device='cuda:0')
# base2 std tensor([3.3337, 3.2005], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 714
# nlml -161171.6934560261
# err (7.634356684521524e-05-4.6522630030400525e-21j)
# eps 4.713482141584933e-08
# base1 std tensor([3.8174, 3.9234], device='cuda:0')
# base2 std tensor([3.3337, 3.2004], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 715
# nlml -161274.09966501984
# err (7.583853911951697e-05-4.6187465393893705e-21j)
# eps 4.6700640449158464e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3336, 3.2004], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 716
# nlml -161336.93235783346
# err (7.627453405336607e-05-4.646906781519825e-21j)
# eps 4.627049564112231e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3335, 3.2003], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 717
# nlml -161437.23572871505
# err (7.585424460033315e-05-4.623564370996016e-21j)
# eps 4.584430866474515e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3335, 3.2002], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 718
# nlml -161530.44240514812
# err (7.556444863012003e-05-4.6013640502842745e-21j)
# eps 4.542204662127699e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3334, 3.2002], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 719
# nlml -161593.69048826446
# err (7.585873031017483e-05-4.617666877388272e-21j)
# eps 4.5003819894103874e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3334, 3.2001], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 720
# nlml -161681.6516076312
# err (7.566305977960792e-05-4.6124698875467e-21j)
# eps 4.4589593438516034e-08
# base1 std tensor([3.8176, 3.9235], device='cuda:0')
# base2 std tensor([3.3333, 3.2001], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 721
# nlml -161774.28133347214
# err (7.545234542395898e-05-4.601608867695889e-21j)
# eps 4.417931750312748e-08
# base1 std tensor([3.8176, 3.9235], device='cuda:0')
# base2 std tensor([3.3333, 3.2000], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 722
# nlml -161834.6986366063
# err (7.577733976042181e-05-4.617018877517803e-21j)
# eps 4.3773090852198716e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3332, 3.2000], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 723
# nlml -161908.0159300346
# err (7.578748437861617e-05-4.615553973411281e-21j)
# eps 4.337093225177748e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3332, 3.2000], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 724
# nlml -162001.78152774635
# err (7.567526964687843e-05-4.606303242643314e-21j)
# eps 4.297276388288495e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3331, 3.1999], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 725
# nlml -162083.28406133677
# err (7.581478955266744e-05-4.62036194099791e-21j)
# eps 4.2578577913045985e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3330, 3.1999], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 726
# nlml -162175.53609234936
# err (7.552798798225003e-05-4.5989870778141e-21j)
# eps 4.2188303239223844e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3330, 3.1999], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 727
# nlml -162255.43359783397
# err (7.556584108570306e-05-4.596342619542773e-21j)
# eps 4.1801934236394215e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3329, 3.1998], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 728
# nlml -162302.64315092628
# err (7.575123873592681e-05-4.610767720740187e-21j)
# eps 4.14196059315707e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3329, 3.1998], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 729
# nlml -162328.56930021645
# err (7.640501929054247e-05-4.65074717922556e-21j)
# eps 4.104152204650136e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3328, 3.1998], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 730
# nlml -162354.43042347836
# err (7.723775956758223e-05-4.709011843103698e-21j)
# eps 4.066786367912012e-08
# base1 std tensor([3.8176, 3.9234], device='cuda:0')
# base2 std tensor([3.3327, 3.1998], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 731
# nlml -162404.45752438693
# err (7.749508605098135e-05-4.716766496870135e-21j)
# eps 4.029863900704074e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3327, 3.1997], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 732
# nlml -162561.18752482207
# err (7.618770573421467e-05-4.644457979096874e-21j)
# eps 3.993338256242864e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3326, 3.1997], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 733
# nlml -162677.08594515163
# err (7.578652928933027e-05-4.6125808172087544e-21j)
# eps 3.9571846047691544e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3326, 3.1997], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 734
# nlml -162716.47299289465
# err (7.704422164982541e-05-4.699925383238187e-21j)
# eps 3.9214154896630894e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3325, 3.1996], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 735
# nlml -162740.07436032285
# err (7.786573694361671e-05-4.745010725603763e-21j)
# eps 3.886048827810301e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3325, 3.1996], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 736
# nlml -162875.60126062212
# err (7.652822632064575e-05-4.665377273767207e-21j)
# eps 3.851050418155791e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3324, 3.1996], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 737
# nlml -162988.56618940996
# err (7.549504407428235e-05-4.591954941020436e-21j)
# eps 3.8164013730014576e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3324, 3.1996], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 738
# nlml -163068.86898573049
# err (7.568160965268048e-05-4.611613927997418e-21j)
# eps 3.782097865550952e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3323, 3.1995], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 739
# nlml -163139.9304853881
# err (7.59333936756707e-05-4.631573470188245e-21j)
# eps 3.7481405284614575e-08
# base1 std tensor([3.8175, 3.9234], device='cuda:0')
# base2 std tensor([3.3323, 3.1995], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 740
# nlml -163178.67902596362
# err (7.58980423285337e-05-4.620405055898139e-21j)
# eps 3.714542972545675e-08
# base1 std tensor([3.8174, 3.9234], device='cuda:0')
# base2 std tensor([3.3322, 3.1995], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 741
# nlml -163259.17982586037
# err (7.580720271639135e-05-4.6254390145909344e-21j)
# eps 3.681298800956613e-08
# base1 std tensor([3.8174, 3.9234], device='cuda:0')
# base2 std tensor([3.3322, 3.1994], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 742
# nlml -163377.49414131115
# err (7.5447857471918e-05-4.595049328174465e-21j)
# eps 3.6483873512656924e-08
# base1 std tensor([3.8174, 3.9234], device='cuda:0')
# base2 std tensor([3.3322, 3.1994], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 743
# nlml -163415.61355496437
# err (7.600210395095675e-05-4.631533447637202e-21j)
# eps 3.6158213777494014e-08
# base1 std tensor([3.8173, 3.9234], device='cuda:0')
# base2 std tensor([3.3321, 3.1993], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 744
# nlml -163423.42542764536
# err (7.673946761418508e-05-4.680287676128575e-21j)
# eps 3.583623956778742e-08
# base1 std tensor([3.8173, 3.9234], device='cuda:0')
# base2 std tensor([3.3321, 3.1993], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 745
# nlml -163485.38173656462
# err (7.703149466932246e-05-4.689203469529707e-21j)
# eps 3.55179375016917e-08
# base1 std tensor([3.8172, 3.9234], device='cuda:0')
# base2 std tensor([3.3320, 3.1992], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 746
# nlml -163525.9897313498
# err (7.748929070497943e-05-4.724678936092738e-21j)
# eps 3.520335157538586e-08
# base1 std tensor([3.8172, 3.9234], device='cuda:0')
# base2 std tensor([3.3320, 3.1992], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 747
# nlml -163382.39451864507
# err (7.95328056967548e-05-4.8540689688698305e-21j)
# eps 3.489323225699686e-08
# base1 std tensor([3.8171, 3.9234], device='cuda:0')
# base2 std tensor([3.3319, 3.1991], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 748
# nlml -163521.53571958307
# err (7.853453553705161e-05-4.781353348394532e-21j)
# eps 3.45871058109054e-08
# base1 std tensor([3.8171, 3.9234], device='cuda:0')
# base2 std tensor([3.3318, 3.1991], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 749
# nlml -163763.75434155154
# err (7.613044489473629e-05-4.627357190101305e-21j)
# eps 3.428417134448282e-08
# base1 std tensor([3.8171, 3.9234], device='cuda:0')
# base2 std tensor([3.3318, 3.1990], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 750
# nlml -163687.7273686948
# err (7.771719955690655e-05-4.727879846074305e-21j)
# eps 3.3984933822664224e-08
# base1 std tensor([3.8171, 3.9234], device='cuda:0')
# base2 std tensor([3.3317, 3.1990], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 751
# nlml -163532.66090507942
# err (8.090469325933978e-05-4.9500965994632235e-21j)
# eps 3.3690133234286427e-08
# base1 std tensor([3.8170, 3.9234], device='cuda:0')
# base2 std tensor([3.3317, 3.1990], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 752
# nlml -163819.05722615225
# err (7.847189909920714e-05-4.785655986565671e-21j)
# eps 3.339874891578743e-08
# base1 std tensor([3.8169, 3.9234], device='cuda:0')
# base2 std tensor([3.3317, 3.1989], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 753
# nlml -163946.2027003033
# err (7.732207508437659e-05-4.7207157275789894e-21j)
# eps 3.3110485784733266e-08
# base1 std tensor([3.8168, 3.9235], device='cuda:0')
# base2 std tensor([3.3316, 3.1989], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 754
# nlml -163836.9463763525
# err (7.892742885040839e-05-4.807695346696501e-21j)
# eps 3.2825938244115814e-08
# base1 std tensor([3.8168, 3.9235], device='cuda:0')
# base2 std tensor([3.3316, 3.1989], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 755
# nlml -163900.37877724663
# err (7.891486714603069e-05-4.813300737942744e-21j)
# eps 3.2544991776486007e-08
# base1 std tensor([3.8168, 3.9235], device='cuda:0')
# base2 std tensor([3.3316, 3.1988], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 756
# nlml -164008.62907971747
# err (7.871362922243856e-05-4.809928518721175e-21j)
# eps 3.2267388783641906e-08
# base1 std tensor([3.8168, 3.9236], device='cuda:0')
# base2 std tensor([3.3317, 3.1988], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 757
# nlml -164253.84899261125
# err (7.619864356917386e-05-4.652302673203236e-21j)
# eps 3.199241572502915e-08
# base1 std tensor([3.8168, 3.9236], device='cuda:0')
# base2 std tensor([3.3317, 3.1987], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 758
# nlml -164379.51516509717
# err (7.560114927338925e-05-4.6025762035490765e-21j)
# eps 3.17198540538307e-08
# base1 std tensor([3.8168, 3.9236], device='cuda:0')
# base2 std tensor([3.3317, 3.1987], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 759
# nlml -164316.48676131945
# err (7.751059078025881e-05-4.724676379996339e-21j)
# eps 3.1450178143479306e-08
# base1 std tensor([3.8168, 3.9236], device='cuda:0')
# base2 std tensor([3.3317, 3.1986], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 760
# nlml -164433.88990881923
# err (7.687803428911845e-05-4.688300619470158e-21j)
# eps 3.118317909273801e-08
# base1 std tensor([3.8168, 3.9236], device='cuda:0')
# base2 std tensor([3.3317, 3.1986], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 761
# nlml -164527.2255612751
# err (7.633380296159422e-05-4.657029969861384e-21j)
# eps 3.091874022981358e-08
# base1 std tensor([3.8168, 3.9236], device='cuda:0')
# base2 std tensor([3.3317, 3.1985], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 762
# nlml -164685.86570690892
# err (7.537095471026278e-05-4.596063328668154e-21j)
# eps 3.065654760319706e-08
# base1 std tensor([3.8168, 3.9236], device='cuda:0')
# base2 std tensor([3.3317, 3.1985], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 763
# nlml -164768.2738466317
# err (7.535096487931318e-05-4.586757036724246e-21j)
# eps 3.039657961747453e-08
# base1 std tensor([3.8168, 3.9236], device='cuda:0')
# base2 std tensor([3.3316, 3.1985], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 764
# nlml -164804.8848638542
# err (7.528056039429229e-05-4.5908311902665936e-21j)
# eps 3.0138976636788274e-08
# base1 std tensor([3.8167, 3.9236], device='cuda:0')
# base2 std tensor([3.3316, 3.1984], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 765
# nlml -164942.7692852876
# err (7.448498056528592e-05-4.535272520702628e-21j)
# eps 2.988351363878552e-08
# base1 std tensor([3.8167, 3.9237], device='cuda:0')
# base2 std tensor([3.3316, 3.1984], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 766
# nlml -165023.47431030762
# err (7.439581059003586e-05-4.531956537714112e-21j)
# eps 2.9630183023236817e-08
# base1 std tensor([3.8167, 3.9237], device='cuda:0')
# base2 std tensor([3.3316, 3.1984], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 767
# nlml -165112.4404508666
# err (7.443880607404115e-05-4.536948847697879e-21j)
# eps 2.93789467853561e-08
# base1 std tensor([3.8167, 3.9237], device='cuda:0')
# base2 std tensor([3.3316, 3.1984], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 768
# nlml -165197.58487465986
# err (7.403813208511804e-05-4.51205573068418e-21j)
# eps 2.9129787877683412e-08
# base1 std tensor([3.8167, 3.9237], device='cuda:0')
# base2 std tensor([3.3316, 3.1983], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 769
# nlml -165231.83713496762
# err (7.424596654862661e-05-4.5192746993547955e-21j)
# eps 2.8882848877054077e-08
# base1 std tensor([3.8166, 3.9237], device='cuda:0')
# base2 std tensor([3.3315, 3.1983], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 770
# nlml -165334.28971969106
# err (7.40334820504387e-05-4.506413962647612e-21j)
# eps 2.8638031596543905e-08
# base1 std tensor([3.8166, 3.9237], device='cuda:0')
# base2 std tensor([3.3315, 3.1983], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 771
# nlml -165405.52500697377
# err (7.400570234387649e-05-4.515997190481242e-21j)
# eps 2.839536227916938e-08
# base1 std tensor([3.8166, 3.9237], device='cuda:0')
# base2 std tensor([3.3315, 3.1983], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 772
# nlml -165478.47551880014
# err (7.37975831078879e-05-4.49839579148563e-21j)
# eps 2.8154852748790213e-08
# base1 std tensor([3.8166, 3.9237], device='cuda:0')
# base2 std tensor([3.3315, 3.1983], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 773
# nlml -165566.81478518486
# err (7.362376227990452e-05-4.475583502598592e-21j)
# eps 2.791645787092427e-08
# base1 std tensor([3.8166, 3.9237], device='cuda:0')
# base2 std tensor([3.3314, 3.1983], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 774
# nlml -165634.6858226855
# err (7.352922782844314e-05-4.473756314575373e-21j)
# eps 2.768019509091924e-08
# base1 std tensor([3.8166, 3.9237], device='cuda:0')
# base2 std tensor([3.3314, 3.1983], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 775
# nlml -165713.00203345285
# err (7.34201789667906e-05-4.468249664257659e-21j)
# eps 2.7446051867497938e-08
# base1 std tensor([3.8166, 3.9238], device='cuda:0')
# base2 std tensor([3.3313, 3.1982], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 776
# nlml -165798.95295631184
# err (7.313175433211922e-05-4.447115351798191e-21j)
# eps 2.7213993302022934e-08
# base1 std tensor([3.8166, 3.9238], device='cuda:0')
# base2 std tensor([3.3313, 3.1982], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 777
# nlml -165901.63893785642
# err (7.284931890777579e-05-4.437971355088333e-21j)
# eps 2.69839375731019e-08
# base1 std tensor([3.8165, 3.9238], device='cuda:0')
# base2 std tensor([3.3312, 3.1982], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 778
# nlml -165964.9966370933
# err (7.2987146637622e-05-4.4503278835366945e-21j)
# eps 2.675593030090361e-08
# base1 std tensor([3.8165, 3.9238], device='cuda:0')
# base2 std tensor([3.3312, 3.1982], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 779
# nlml -166024.84587702854
# err (7.310608733850405e-05-4.449981617011586e-21j)
# eps 2.6530024987945402e-08
# base1 std tensor([3.8165, 3.9238], device='cuda:0')
# base2 std tensor([3.3311, 3.1982], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 780
# nlml -166086.47424472816
# err (7.309960848020582e-05-4.450932868291423e-21j)
# eps 2.6306257251443914e-08
# base1 std tensor([3.8165, 3.9238], device='cuda:0')
# base2 std tensor([3.3311, 3.1982], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 781
# nlml -166133.8714974339
# err (7.323818940498094e-05-4.461525435587664e-21j)
# eps 2.6084686657684602e-08
# base1 std tensor([3.8164, 3.9239], device='cuda:0')
# base2 std tensor([3.3310, 3.1982], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 782
# nlml -166162.22754768812
# err (7.356922120899685e-05-4.486937433177174e-21j)
# eps 2.586542116779409e-08
# base1 std tensor([3.8164, 3.9239], device='cuda:0')
# base2 std tensor([3.3310, 3.1982], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 783
# nlml -166155.63555817623
# err (7.407818629185917e-05-4.51779385576927e-21j)
# eps 2.5648646071840133e-08
# base1 std tensor([3.8164, 3.9239], device='cuda:0')
# base2 std tensor([3.3309, 3.1982], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 784
# nlml -166159.94456743824
# err (7.474378988962212e-05-4.5573616097872755e-21j)
# eps 2.543450105245328e-08
# base1 std tensor([3.8164, 3.9239], device='cuda:0')
# base2 std tensor([3.3308, 3.1982], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 785
# nlml -166191.48990588577
# err (7.515183139640883e-05-4.5811670175147005e-21j)
# eps 2.5223018236119936e-08
# base1 std tensor([3.8164, 3.9239], device='cuda:0')
# base2 std tensor([3.3308, 3.1982], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 786
# nlml -166202.6097625557
# err (7.580262031087419e-05-4.6224184075937314e-21j)
# eps 2.5014272717464146e-08
# base1 std tensor([3.8164, 3.9239], device='cuda:0')
# base2 std tensor([3.3308, 3.1982], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 787
# nlml -166177.41785944262
# err (7.578356274169466e-05-4.621755189027965e-21j)
# eps 2.4808396264095473e-08
# base1 std tensor([3.8164, 3.9239], device='cuda:0')
# base2 std tensor([3.3308, 3.1981], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 788
# nlml -166345.9339201586
# err (7.458148270654414e-05-4.544974991425053e-21j)
# eps 2.4604975494057235e-08
# base1 std tensor([3.8164, 3.9240], device='cuda:0')
# base2 std tensor([3.3308, 3.1981], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 789
# nlml -166509.6965279619
# err (7.345699761852488e-05-4.480360876527515e-21j)
# eps 2.4403661890534494e-08
# base1 std tensor([3.8165, 3.9240], device='cuda:0')
# base2 std tensor([3.3307, 3.1980], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 790
# nlml -166654.98461755316
# err (7.277866545919998e-05-4.425669165138656e-21j)
# eps 2.420419310778191e-08
# base1 std tensor([3.8165, 3.9240], device='cuda:0')
# base2 std tensor([3.3307, 3.1980], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 791
# nlml -166666.17374078443
# err (7.325281083807218e-05-4.4648048913472965e-21j)
# eps 2.4006707418050154e-08
# base1 std tensor([3.8165, 3.9240], device='cuda:0')
# base2 std tensor([3.3306, 3.1980], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 792
# nlml -166664.23044795432
# err (7.374096481606163e-05-4.4821965028833694e-21j)
# eps 2.381136050646835e-08
# base1 std tensor([3.8165, 3.9241], device='cuda:0')
# base2 std tensor([3.3306, 3.1979], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 793
# nlml -166780.60656227736
# err (7.316233621125982e-05-4.451830634600576e-21j)
# eps 2.3617967629692012e-08
# base1 std tensor([3.8166, 3.9241], device='cuda:0')
# base2 std tensor([3.3305, 3.1978], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 794
# nlml -166762.72567657457
# err (7.420180719321757e-05-4.528445061680062e-21j)
# eps 2.3426724336311967e-08
# base1 std tensor([3.8166, 3.9241], device='cuda:0')
# base2 std tensor([3.3304, 3.1978], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 795
# nlml -166694.74597080908
# err (7.49162551213054e-05-4.557421269542569e-21j)
# eps 2.3237920932341027e-08
# base1 std tensor([3.8166, 3.9241], device='cuda:0')
# base2 std tensor([3.3303, 3.1977], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 796
# nlml -166707.43589438603
# err (7.498673593453167e-05-4.575156951179048e-21j)
# eps 2.3051600966562394e-08
# base1 std tensor([3.8166, 3.9242], device='cuda:0')
# base2 std tensor([3.3303, 3.1977], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 797
# nlml -167005.39155691615
# err (7.30237251741573e-05-4.445949337079127e-21j)
# eps 2.286705996287412e-08
# base1 std tensor([3.8166, 3.9242], device='cuda:0')
# base2 std tensor([3.3303, 3.1977], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 798
# nlml -167088.13151090554
# err (7.325037483783217e-05-4.4519072437860755e-21j)
# eps 2.2684233728353184e-08
# base1 std tensor([3.8166, 3.9243], device='cuda:0')
# base2 std tensor([3.3302, 3.1976], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 799
# nlml -167101.25134196444
# err (7.350262180718891e-05-4.483263671417974e-21j)
# eps 2.250324422410535e-08
# base1 std tensor([3.8166, 3.9243], device='cuda:0')
# base2 std tensor([3.3302, 3.1976], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 800
# nlml -167355.20009734787
# err (7.191443960081792e-05-4.384010497391322e-21j)
# eps 2.2323592577179286e-08
# base1 std tensor([3.8166, 3.9243], device='cuda:0')
# base2 std tensor([3.3302, 3.1976], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 801
# nlml -167377.53134017906
# err (7.211010089207634e-05-4.391149227366309e-21j)
# eps 2.214541721298433e-08
# base1 std tensor([3.8166, 3.9244], device='cuda:0')
# base2 std tensor([3.3301, 3.1976], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 802
# nlml -167349.4665728652
# err (7.278464091737722e-05-4.4316060642701375e-21j)
# eps 2.196896419237091e-08
# base1 std tensor([3.8166, 3.9244], device='cuda:0')
# base2 std tensor([3.3301, 3.1975], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 803
# nlml -167579.3878502254
# err (7.13590878550526e-05-4.3468102283833615e-21j)
# eps 2.1793814048509494e-08
# base1 std tensor([3.8166, 3.9244], device='cuda:0')
# base2 std tensor([3.3301, 3.1975], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 804
# nlml -167580.59092313712
# err (7.14736374323776e-05-4.357448384515998e-21j)
# eps 2.162015013252809e-08
# base1 std tensor([3.8165, 3.9244], device='cuda:0')
# base2 std tensor([3.3301, 3.1975], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 805
# nlml -167682.87725057863
# err (7.11617331212158e-05-4.337505418665384e-21j)
# eps 2.1447889245105542e-08
# base1 std tensor([3.8165, 3.9244], device='cuda:0')
# base2 std tensor([3.3301, 3.1975], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 806
# nlml -167774.7906293969
# err (7.08967583306842e-05-4.316277343164848e-21j)
# eps 2.1276981214743717e-08
# base1 std tensor([3.8165, 3.9244], device='cuda:0')
# base2 std tensor([3.3301, 3.1975], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 807
# nlml -167788.53952820814
# err (7.109623750761905e-05-4.33346398481243e-21j)
# eps 2.1107572758252594e-08
# base1 std tensor([3.8165, 3.9245], device='cuda:0')
# base2 std tensor([3.3301, 3.1976], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 808
# nlml -167835.7949448987
# err (7.102362843072222e-05-4.3347949141236614e-21j)
# eps 2.0939707841415868e-08
# base1 std tensor([3.8165, 3.9245], device='cuda:0')
# base2 std tensor([3.3301, 3.1976], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 809
# nlml -167669.9578988967
# err (7.241617161224876e-05-4.417878832889699e-21j)
# eps 2.077393117512338e-08
# base1 std tensor([3.8165, 3.9245], device='cuda:0')
# base2 std tensor([3.3301, 3.1976], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 810
# nlml -167480.46107125422
# err (7.364272233680701e-05-4.489729264822328e-21j)
# eps 2.061076882458658e-08
# base1 std tensor([3.8165, 3.9245], device='cuda:0')
# base2 std tensor([3.3301, 3.1976], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 811
# nlml -167587.82663000879
# err (7.341082336777833e-05-4.482571089964761e-21j)
# eps 2.0449977983498962e-08
# base1 std tensor([3.8165, 3.9246], device='cuda:0')
# base2 std tensor([3.3300, 3.1976], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 812
# nlml -167975.20117850867
# err (7.170552708620597e-05-4.370879196283305e-21j)
# eps 2.0290679603972174e-08
# base1 std tensor([3.8165, 3.9246], device='cuda:0')
# base2 std tensor([3.3300, 3.1977], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 813
# nlml -168122.37312095842
# err (7.162735872304553e-05-4.368021380605081e-21j)
# eps 2.0132674261229452e-08
# base1 std tensor([3.8166, 3.9247], device='cuda:0')
# base2 std tensor([3.3299, 3.1977], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 814
# nlml -167978.59364237942
# err (7.361570741087656e-05-4.489700513824246e-21j)
# eps 1.9976437805735717e-08
# base1 std tensor([3.8166, 3.9247], device='cuda:0')
# base2 std tensor([3.3299, 3.1978], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 815
# nlml -168097.50893408895
# err (7.30101490760637e-05-4.4464664240634256e-21j)
# eps 1.9821793035906157e-08
# base1 std tensor([3.8166, 3.9248], device='cuda:0')
# base2 std tensor([3.3298, 3.1979], device='cuda:0')
# min,max (tensor(-3.8261, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 816
# nlml -168367.53720215894
# err (7.056361475411287e-05-4.302709790625241e-21j)
# eps 1.966824456296877e-08
# base1 std tensor([3.8166, 3.9248], device='cuda:0')
# base2 std tensor([3.3298, 3.1979], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 817
# nlml -168333.23087280395
# err (7.064503655288012e-05-4.309209453373289e-21j)
# eps 1.9516026533536186e-08
# base1 std tensor([3.8166, 3.9248], device='cuda:0')
# base2 std tensor([3.3297, 3.1980], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 818
# nlml -168383.74598375396
# err (7.108224398068306e-05-4.328705756649126e-21j)
# eps 1.9365156761610897e-08
# base1 std tensor([3.8166, 3.9249], device='cuda:0')
# base2 std tensor([3.3297, 3.1980], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 819
# nlml -168545.8639122095
# err (6.9985219749871e-05-4.269044719520799e-21j)
# eps 1.9215414921385787e-08
# base1 std tensor([3.8166, 3.9249], device='cuda:0')
# base2 std tensor([3.3296, 3.1980], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 820
# nlml -168504.466166158
# err (7.040065118654103e-05-4.294163973727732e-21j)
# eps 1.9067055428414024e-08
# base1 std tensor([3.8166, 3.9249], device='cuda:0')
# base2 std tensor([3.3295, 3.1981], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 821
# nlml -168556.0583505638
# err (7.04206328154666e-05-4.2860425354560135e-21j)
# eps 1.8920073845670382e-08
# base1 std tensor([3.8166, 3.9250], device='cuda:0')
# base2 std tensor([3.3294, 3.1980], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 822
# nlml -168553.08812975898
# err (7.080711732474341e-05-4.326929866698063e-21j)
# eps 1.8774593317342763e-08
# base1 std tensor([3.8166, 3.9250], device='cuda:0')
# base2 std tensor([3.3293, 3.1980], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 823
# nlml -168621.49114195225
# err (7.065308499953344e-05-4.297733702498342e-21j)
# eps 1.8630559294088087e-08
# base1 std tensor([3.8166, 3.9251], device='cuda:0')
# base2 std tensor([3.3292, 3.1981], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8261, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 824
# nlml -168656.0754667769
# err (7.059578855910679e-05-4.294747780074015e-21j)
# eps 1.8488002721165245e-08
# base1 std tensor([3.8166, 3.9251], device='cuda:0')
# base2 std tensor([3.3291, 3.1981], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 825
# nlml -168802.323304449
# ...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 250
# nlml -175948.73157225983
# err (4.9635912583415176e-05-3.032450405553851e-21j)
# eps 9.487934954985955e-09
# base1 std tensor([3.7982, 3.9106], device='cuda:0')
# base2 std tensor([3.2916, 3.1620], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 251
# nlml -175923.44210688077
# err (4.973118223323319e-05-3.0373084253857296e-21j)
# eps 9.477884720760199e-09
# base1 std tensor([3.7982, 3.9106], device='cuda:0')
# base2 std tensor([3.2916, 3.1619], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 252
# nlml -175914.37916721014
# err (4.971828745159616e-05-3.0368082776695024e-21j)
# eps 9.467851604992238e-09
# base1 std tensor([3.7982, 3.9106], device='cuda:0')
# base2 std tensor([3.2915, 3.1619], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 253
# nlml -175942.63835505577
# err (4.963876446977243e-05-3.0304750306920865e-21j)
# eps 9.457832120525281e-09
# base1 std tensor([3.7982, 3.9106], device='cuda:0')
# base2 std tensor([3.2915, 3.1618], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 254
# nlml -176016.64670723703
# err (4.924735622030994e-05-3.005894852566927e-21j)
# eps 9.447817231438044e-09
# base1 std tensor([3.7982, 3.9106], device='cuda:0')
# base2 std tensor([3.2914, 3.1618], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 255
# nlml -176003.013771303
# err (4.935176795793675e-05-3.0129344632580936e-21j)
# eps 9.437811193379709e-09
# base1 std tensor([3.7982, 3.9106], device='cuda:0')
# base2 std tensor([3.2914, 3.1617], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 256
# nlml -176060.66690168492
# err (4.90715544901441e-05-2.9960127150463646e-21j)
# eps 9.427807978673426e-09
# base1 std tensor([3.7982, 3.9105], device='cuda:0')
# base2 std tensor([3.2914, 3.1616], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 257
# nlml -176044.22800987735
# err (4.917957774042424e-05-3.0034691873349548e-21j)
# eps 9.417812664059797e-09
# base1 std tensor([3.7982, 3.9105], device='cuda:0')
# base2 std tensor([3.2913, 3.1616], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 258
# nlml -176096.4627123046
# err (4.896127073945682e-05-2.9906257652023582e-21j)
# eps 9.407820487409672e-09
# base1 std tensor([3.7982, 3.9105], device='cuda:0')
# base2 std tensor([3.2913, 3.1615], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 259
# nlml -176099.9277495953
# err (4.8974936899995074e-05-2.9910733406359727e-21j)
# eps 9.397834141783597e-09
# base1 std tensor([3.7982, 3.9105], device='cuda:0')
# base2 std tensor([3.2913, 3.1615], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 260
# nlml -176131.1244595724
# err (4.887597846372025e-05-2.9846580562338397e-21j)
# eps 9.387852511389146e-09
# base1 std tensor([3.7982, 3.9105], device='cuda:0')
# base2 std tensor([3.2912, 3.1614], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 261
# nlml -176151.9287885189
# err (4.882934026901642e-05-2.98102200328808e-21j)
# eps 9.377875634054109e-09
# base1 std tensor([3.7982, 3.9105], device='cuda:0')
# base2 std tensor([3.2912, 3.1614], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 262
# nlml -176173.6578473416
# err (4.8733575220312885e-05-2.975846915117875e-21j)
# eps 9.367902768549515e-09
# base1 std tensor([3.7982, 3.9105], device='cuda:0')
# base2 std tensor([3.2912, 3.1613], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 263
# nlml -176186.4646736412
# err (4.870683316256398e-05-2.975200035579466e-21j)
# eps 9.357934957905896e-09
# base1 std tensor([3.7982, 3.9104], device='cuda:0')
# base2 std tensor([3.2911, 3.1613], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 264
# nlml -176209.24649767223
# err (4.861669128535774e-05-2.969194426946902e-21j)
# eps 9.347971654503969e-09
# base1 std tensor([3.7982, 3.9104], device='cuda:0')
# base2 std tensor([3.2911, 3.1612], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 265
# nlml -176235.20828462
# err (4.853001868833488e-05-2.9638571462509364e-21j)
# eps 9.338012266598073e-09
# base1 std tensor([3.7982, 3.9104], device='cuda:0')
# base2 std tensor([3.2910, 3.1612], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 266
# nlml -176246.33894928277
# err (4.850760482645165e-05-2.962907904557214e-21j)
# eps 9.328058240211397e-09
# base1 std tensor([3.7982, 3.9104], device='cuda:0')
# base2 std tensor([3.2910, 3.1612], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 267
# nlml -176273.33051454916
# err (4.83877028392379e-05-2.9557256551326908e-21j)
# eps 9.318108422745517e-09
# base1 std tensor([3.7982, 3.9103], device='cuda:0')
# base2 std tensor([3.2909, 3.1611], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 268
# nlml -176290.08872672124
# err (4.833746226585544e-05-2.9531992705413314e-21j)
# eps 9.308163647805126e-09
# base1 std tensor([3.7982, 3.9103], device='cuda:0')
# base2 std tensor([3.2909, 3.1611], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 269
# nlml -176310.12152448375
# err (4.828562528445326e-05-2.949972701948236e-21j)
# eps 9.298224300256818e-09
# base1 std tensor([3.7982, 3.9103], device='cuda:0')
# base2 std tensor([3.2909, 3.1610], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 270
# nlml -176319.42858470415
# err (4.823766797265694e-05-2.9469803976448034e-21j)
# eps 9.288291313422501e-09
# base1 std tensor([3.7982, 3.9103], device='cuda:0')
# base2 std tensor([3.2908, 3.1610], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 271
# nlml -176308.01674857616
# err (4.827159916727736e-05-2.9498958558326925e-21j)
# eps 9.278368115256481e-09
# base1 std tensor([3.7981, 3.9102], device='cuda:0')
# base2 std tensor([3.2908, 3.1609], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 272
# nlml -176273.73879741214
# err (4.8414393457050314e-05-2.959448764907174e-21j)
# eps 9.26846138160925e-09
# base1 std tensor([3.7981, 3.9102], device='cuda:0')
# base2 std tensor([3.2908, 3.1609], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 273
# nlml -176300.90632149254
# err (4.833136417812714e-05-2.951509672517938e-21j)
# eps 9.258569274585941e-09
# base1 std tensor([3.7981, 3.9102], device='cuda:0')
# base2 std tensor([3.2908, 3.1608], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 274
# nlml -176362.99665263508
# err (4.806388833333602e-05-2.9360200026293535e-21j)
# eps 9.248685001864943e-09
# base1 std tensor([3.7981, 3.9102], device='cuda:0')
# base2 std tensor([3.2907, 3.1608], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 275
# nlml -176317.95915835092
# err (4.827114593407843e-05-2.950344352902948e-21j)
# eps 9.238816903752004e-09
# base1 std tensor([3.7981, 3.9101], device='cuda:0')
# base2 std tensor([3.2907, 3.1607], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 276
# nlml -176023.677230019
# err (4.9683181351963264e-05-3.0387853622830537e-21j)
# eps 9.229005671157052e-09
# base1 std tensor([3.7982, 3.9101], device='cuda:0')
# base2 std tensor([3.2907, 3.1607], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 277
# nlml -176299.70209636207
# err (4.8393482301774455e-05-2.9543616078593727e-21j)
# eps 9.219209064422841e-09
# base1 std tensor([3.7982, 3.9101], device='cuda:0')
# base2 std tensor([3.2907, 3.1606], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 278
# nlml -176317.93753863696
# err (4.824341779934113e-05-2.947366894971173e-21j)
# eps 9.209424246325672e-09
# base1 std tensor([3.7982, 3.9101], device='cuda:0')
# base2 std tensor([3.2907, 3.1606], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 279
# nlml -176292.24638492562
# err (4.8325974338399203e-05-2.9525461436932715e-21j)
# eps 9.199655592899494e-09
# base1 std tensor([3.7982, 3.9101], device='cuda:0')
# base2 std tensor([3.2907, 3.1605], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 280
# nlml -176307.22615340285
# err (4.8188425896819304e-05-2.944808434396339e-21j)
# eps 9.189900972599515e-09
# base1 std tensor([3.7982, 3.9101], device='cuda:0')
# base2 std tensor([3.2906, 3.1605], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 281
# nlml -176373.44601430942
# err (4.792867110285651e-05-2.927909628745322e-21j)
# eps 9.180152807952338e-09
# base1 std tensor([3.7982, 3.9101], device='cuda:0')
# base2 std tensor([3.2906, 3.1604], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 282
# nlml -176405.4796186395
# err (4.780063137162235e-05-2.9206790386927426e-21j)
# eps 9.170408914906852e-09
# base1 std tensor([3.7982, 3.9100], device='cuda:0')
# base2 std tensor([3.2906, 3.1604], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 283
# nlml -176402.31685649542
# err (4.780513942836771e-05-2.9220885413797844e-21j)
# eps 9.160672358757673e-09
# base1 std tensor([3.7982, 3.9100], device='cuda:0')
# base2 std tensor([3.2905, 3.1603], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 284
# nlml -176390.94982193885
# err (4.7907300343684955e-05-2.9260518640197286e-21j)
# eps 9.150946787079199e-09
# base1 std tensor([3.7982, 3.9100], device='cuda:0')
# base2 std tensor([3.2905, 3.1603], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 285
# nlml -176440.7156334822
# err (4.762840467392535e-05-2.910942956341234e-21j)
# eps 9.141226854992835e-09
# base1 std tensor([3.7982, 3.9100], device='cuda:0')
# base2 std tensor([3.2905, 3.1603], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 286
# nlml -176473.42125086175
# err (4.751062078466451e-05-2.9030021154853307e-21j)
# eps 9.131510095044002e-09
# base1 std tensor([3.7982, 3.9100], device='cuda:0')
# base2 std tensor([3.2905, 3.1602], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 287
# nlml -176481.34248334725
# err (4.7470578255082263e-05-2.9002190978535067e-21j)
# eps 9.121797967779829e-09
# base1 std tensor([3.7982, 3.9099], device='cuda:0')
# base2 std tensor([3.2904, 3.1602], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 288
# nlml -176483.76387796644
# err (4.742676380448603e-05-2.897759073438064e-21j)
# eps 9.112092328136167e-09
# base1 std tensor([3.7982, 3.9099], device='cuda:0')
# base2 std tensor([3.2904, 3.1601], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 289
# nlml -176525.1022118455
# err (4.730358809845611e-05-2.8897294906514928e-21j)
# eps 9.102389946657508e-09
# base1 std tensor([3.7982, 3.9099], device='cuda:0')
# base2 std tensor([3.2904, 3.1601], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 290
# nlml -176549.30632116625
# err (4.722543003815983e-05-2.885143242167999e-21j)
# eps 9.09269026123086e-09
# base1 std tensor([3.7982, 3.9099], device='cuda:0')
# base2 std tensor([3.2903, 3.1600], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 291
# nlml -176564.00252270562
# err (4.718240230333056e-05-2.882501529484489e-21j)
# eps 9.082994215311544e-09
# base1 std tensor([3.7982, 3.9099], device='cuda:0')
# base2 std tensor([3.2903, 3.1600], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 292
# nlml -176573.92043696594
# err (4.7166687081512306e-05-2.881052355710321e-21j)
# eps 9.073303879018544e-09
# base1 std tensor([3.7982, 3.9098], device='cuda:0')
# base2 std tensor([3.2903, 3.1599], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 293
# nlml -176584.68291593372
# err (4.7135411061981954e-05-2.8792466480331364e-21j)
# eps 9.063620340266896e-09
# base1 std tensor([3.7982, 3.9098], device='cuda:0')
# base2 std tensor([3.2902, 3.1598], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 294
# nlml -176611.02665031198
# err (4.70557770081397e-05-2.8732035277593687e-21j)
# eps 9.053942822740033e-09
# base1 std tensor([3.7982, 3.9098], device='cuda:0')
# base2 std tensor([3.2902, 3.1598], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 295
# nlml -176636.7332882095
# err (4.694379900450672e-05-2.8674003221426806e-21j)
# eps 9.044270267938747e-09
# base1 std tensor([3.7982, 3.9098], device='cuda:0')
# base2 std tensor([3.2902, 3.1597], device='cuda:0')
# min,max (tensor(-3.8260, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 296
# nlml -176664.1215417331
# err (4.687269864858236e-05-2.863363579876488e-21j)
# eps 9.034601978485156e-09
# base1 std tensor([3.7982, 3.9097], device='cuda:0')
# base2 std tensor([3.2901, 3.1597], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 297
# nlml -176683.01444297633
# err (4.6822894739173986e-05-2.8601871409516674e-21j)
# eps 9.024938644350002e-09
# base1 std tensor([3.7982, 3.9097], device='cuda:0')
# base2 std tensor([3.2901, 3.1596], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 298
# nlml -176681.03777732677
# err (4.685932763432739e-05-2.862733577676179e-21j)
# eps 9.015283210887172e-09
# base1 std tensor([3.7983, 3.9097], device='cuda:0')
# base2 std tensor([3.2901, 3.1596], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))
# ~~~~~~~~~~~~~~~~~~~~~~~~~~
# epoch 299
# nlml -176700.5998729871
# err (4.678960541065864e-05-2.8593512352538176e-21j)
# eps 9.005635305422742e-09
# base1 std tensor([3.7983, 3.9096], device='cuda:0')
# base2 std tensor([3.2900, 3.1595], device='cuda:0')
# min,max (tensor(-3.8259, device='cuda:0'), tensor(3.8260, device='cuda:0'))

# %%
#torch.save({
#            'MC_base1': MC_base1.cpu(),
#            'MC_base2': MC_base2.cpu(),
#            'S_diag': S_diag.cpu(),
#            'eps': eps.cpu(),
#    }, "state.pt")


st = torch.load("state.pt")
MC_base1 = st['MC_base1']
MC_base2 = st['MC_base2']
S_diag = st['S_diag']
eps = st['eps']

# Prediction
#Phi_ = Phi(MC_base * 1.j, Ps.to(torch.complex128)).to(device)
Phi_ = Phi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
dPhi_ = dPhi(MC_base1 * 1.j, MC_base2 * 1.j, Ps.to(torch.complex128).to("cpu"))
Phi_ = torch.cat((Phi_,dPhi_),1)
PhiX = Phi(MC_base1 * 1.j, MC_base2 * 1.j, X.to("cpu"))
dPhiX = dPhi(MC_base1 * 1.j, MC_base2 * 1.j, dX.to("cpu"))
PhiX = torch.cat((PhiX,dPhiX),1)
A = torch.diag_embed((eps - S_diag).exp()) + PhiX @ PhiX.H
LA = torch.linalg.cholesky(A)
alpha = torch.linalg.solve_triangular(LA, PhiX @ Y.to("cpu").to(torch.complex128), upper=False)
pred = Phi_.H @ torch.linalg.solve_triangular(LA.H, alpha.to("cpu"), upper=True)
pred = pred.real

pred.detach().cpu().numpy().tofile("pred.dat")
axis.cpu().numpy().tofile("axis.dat")
time.cpu().numpy().tofile("time.dat")

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# !cp pred.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp axis.dat "/content/drive/MyDrive/Colab Notebooks"
# !cp time.dat "/content/drive/MyDrive/Colab Notebooks"
